# %%
import time
import os

import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)

from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras import *
tf.__version__
# Out:
# '2.3.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %% [markdown]
# # Model training

# %% [markdown]
# ## hyperparameters

# %%
SCREEN_SIZE = 50
BEST_PATH = './checkpoints/UNet_%dx%d_prevnext' % (SCREEN_SIZE, SCREEN_SIZE)
DISP_STEPS = 100
TRAINING_EPOCHS = 500
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# %% [markdown]
# ## data loading

# %%
l = np.load('./data/tot_dataset_%d_UNet.npz' % SCREEN_SIZE)
raw_input = l['raw_input']
raw_label = l['raw_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']

SCREEN_SIZE = l['SCREEN_SIZE']

# %%
print(raw_input.shape)
print(raw_label.shape)
# Out:
# (134993, 50, 50, 4)
# (134993, 50, 50, 1)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (78263, 50, 50, 4)
# (78263, 50, 50, 1)

# %%
raw_input = raw_input.astype(np.float32)
raw_label = raw_label.astype(np.float32)
test_input = test_input.astype(np.float32)
test_label = test_label.astype(np.float32)

# %%
num_train = int(raw_input.shape[0]*.7)
raw_input, raw_label = shuffle(raw_input, raw_label, random_state=4574)
train_input, train_label = raw_input[:num_train, ...], raw_label[:num_train, ...]
val_input, val_label = raw_input[num_train:, ...], raw_label[num_train:, ...]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((np.delete(train_input, [2, 3], axis=-1), train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
val_dataset = tf.data.Dataset.from_tensor_slices((np.delete(val_input, [2, 3], axis=-1), val_label))
val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((np.delete(test_input, [2, 3], axis=-1), test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
class ConvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, dropout_rate):
        super(ConvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.dropout_rate = dropout_rate
        
        self.conv1 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch1 = layers.BatchNormalization()
        self.drop = layers.Dropout(self.dropout_rate)
        self.conv2 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch2 = layers.BatchNormalization()
        
    def call(self, inp):
        
        inp = self.batch1(self.conv1(inp))
        inp = self.drop(inp)
        inp = self.batch2(self.conv2(inp))
        
        return inp

# %%
class DeconvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, strides):
        super(DeconvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        
        self.deconv1 = layers.Conv2DTranspose(self.filters, self.kernel_size, strides=self.strides, padding='same')
        
    def call(self, inp):
        
        inp = self.deconv1(inp)
        
        return inp

# %%
class UNet(Model):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.conv_block1 = ConvBlock(64, (2, 2), 0.1)
        self.pool1 = layers.MaxPooling2D()
        
        self.conv_block2 = ConvBlock(128, (2, 2), 0.2)
        self.pool2 = layers.MaxPooling2D()
        
        self.conv_block3 = ConvBlock(256, (2, 2), 0.2)
        
        self.deconv_block1 = DeconvBlock(128, (2, 2), (2, 2))
        self.conv_block4 = ConvBlock(128, (2, 2), 0.2)
        
        self.deconv_block2 = DeconvBlock(32, (2, 2), (2, 2))
        self.padding = layers.ZeroPadding2D(((1, 0), (0, 1)))
        self.conv_block5 = ConvBlock(64, (2, 2), 0.1)
        
        self.output_conv = layers.Conv2D(1, (1, 1), activation='sigmoid')
        
    def call(self, inp):
        
        conv1 = self.conv_block1(inp)
        pooled1 = self.pool1(conv1)
        conv2 = self.conv_block2(pooled1)
        pooled2 = self.pool2(conv2)
        
        bottom = self.conv_block3(pooled2)
        
        deconv1 = self.padding(self.deconv_block1(bottom))
        deconv1 = layers.concatenate([deconv1, conv2])
        deconv1 = self.conv_block4(deconv1)
        deconv2 = self.deconv_block2(deconv1)
        deconv2 = layers.concatenate([deconv2, conv1])
        deconv2 = self.conv_block5(deconv2)
        
        return self.output_conv(deconv2)

# %%
#loss inputs should be masked.
loss_object = tf.keras.losses.MeanSquaredError()
def loss_function(model, inp, tar):
    
    masked_real = tar * (1 - inp[..., 1:2])
    masked_pred = model(inp) * (1 - inp[..., 1:2])
    
    return loss_object(masked_real, masked_pred)

# %%
unet_model = UNet()
opt = tf.optimizers.Adam(learning_rate=LEARNING_RATE)

# %%
@tf.function
def train(loss_function, model, opt, inp, tar):
    with tf.GradientTape() as tape:
        gradients = tape.gradient(loss_function(model, inp, tar), model.trainable_variables)
        gradient_variables = zip(gradients, model.trainable_variables)
        opt.apply_gradients(gradient_variables)

# %%
checkpoint_path = BEST_PATH

ckpt = tf.train.Checkpoint(unet_model=unet_model,
                           opt=opt)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=10)

# %%
writer = tf.summary.create_file_writer('tmp')

# %% [markdown]
# # Training

# %%
prev_test_loss = 100.0
early_stop_buffer = 100
with writer.as_default():
    with tf.summary.record_if(True):
        for epoch in range(TRAINING_EPOCHS):
            for step, (inp, tar) in enumerate(train_dataset):
                train(loss_function, unet_model, opt, inp, tar)
                loss_values = loss_function(unet_model, inp, tar)
                tf.summary.scalar('loss', loss_values, step=step)
                
                if step % DISP_STEPS == 0:
                    test_loss = 0
                    for step_, (inp_, tar_) in enumerate(test_dataset):
                        test_loss += loss_function(unet_model, inp_, tar_)
                        
                        if step_ > DISP_STEPS:
                            test_loss /= DISP_STEPS
                            break
                    if test_loss.numpy() < prev_test_loss:
                        ckpt_save_path = ckpt_manager.save()
                        prev_test_loss = test_loss.numpy()
                        print('Saving checkpoint at {}'.format(ckpt_save_path))
                        early_stop_buffer = 100
                    else:
                        early_stop_buffer -= 1
                    print('Epoch {} batch {} train loss: {:.4f} test loss: {:.4f}'
                          .format(epoch, step, loss_values.numpy(), test_loss.numpy()))
                if early_stop_buffer <= 0:
                    print('early stop.')
                    break
            if early_stop_buffer <= 0:
                    break
# Out:
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-1
# Epoch 0 batch 0 train loss: 0.0671 test loss: 0.0736
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-2
# Epoch 0 batch 100 train loss: 0.0136 test loss: 0.0224
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-3
# Epoch 0 batch 200 train loss: 0.0140 test loss: 0.0196
# Epoch 0 batch 300 train loss: 0.0150 test loss: 0.0199
# Epoch 0 batch 400 train loss: 0.0080 test loss: 0.0202
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-4
# Epoch 0 batch 500 train loss: 0.0161 test loss: 0.0194
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-5
# Epoch 0 batch 600 train loss: 0.0091 test loss: 0.0192
# Epoch 0 batch 700 train loss: 0.0162 test loss: 0.0195
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-6
# Epoch 0 batch 800 train loss: 0.0124 test loss: 0.0191
# Epoch 0 batch 900 train loss: 0.0132 test loss: 0.0197
# Epoch 0 batch 1000 train loss: 0.0125 test loss: 0.0194
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-7
# Epoch 0 batch 1100 train loss: 0.0172 test loss: 0.0188
# Epoch 0 batch 1200 train loss: 0.0099 test loss: 0.0188
# Epoch 0 batch 1300 train loss: 0.0150 test loss: 0.0189
# Epoch 0 batch 1400 train loss: 0.0136 test loss: 0.0191
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-8
# Epoch 0 batch 1500 train loss: 0.0150 test loss: 0.0185
# Epoch 0 batch 1600 train loss: 0.0125 test loss: 0.0189
# Epoch 0 batch 1700 train loss: 0.0128 test loss: 0.0186
# Epoch 0 batch 1800 train loss: 0.0190 test loss: 0.0191
# Epoch 0 batch 1900 train loss: 0.0167 test loss: 0.0193
# Epoch 0 batch 2000 train loss: 0.0210 test loss: 0.0192
# Epoch 0 batch 2100 train loss: 0.0093 test loss: 0.0191
# Epoch 0 batch 2200 train loss: 0.0101 test loss: 0.0194
# Epoch 0 batch 2300 train loss: 0.0128 test loss: 0.0186
# Epoch 0 batch 2400 train loss: 0.0140 test loss: 0.0187
# Epoch 0 batch 2500 train loss: 0.0090 test loss: 0.0191
# Epoch 0 batch 2600 train loss: 0.0123 test loss: 0.0188
# Epoch 0 batch 2700 train loss: 0.0122 test loss: 0.0189
# Epoch 0 batch 2800 train loss: 0.0119 test loss: 0.0187
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-9
# Epoch 0 batch 2900 train loss: 0.0089 test loss: 0.0184
# Epoch 1 batch 0 train loss: 0.0073 test loss: 0.0185
# Epoch 1 batch 100 train loss: 0.0134 test loss: 0.0186
# Epoch 1 batch 200 train loss: 0.0129 test loss: 0.0192
# Epoch 1 batch 300 train loss: 0.0195 test loss: 0.0187
# Epoch 1 batch 400 train loss: 0.0200 test loss: 0.0188
# Epoch 1 batch 500 train loss: 0.0151 test loss: 0.0190
# Epoch 1 batch 600 train loss: 0.0122 test loss: 0.0188
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-10
# Epoch 1 batch 700 train loss: 0.0199 test loss: 0.0183
# Epoch 1 batch 800 train loss: 0.0156 test loss: 0.0184
# Epoch 1 batch 900 train loss: 0.0191 test loss: 0.0189
# Epoch 1 batch 1000 train loss: 0.0141 test loss: 0.0191
# Epoch 1 batch 1100 train loss: 0.0105 test loss: 0.0187
# Epoch 1 batch 1200 train loss: 0.0174 test loss: 0.0187
# Epoch 1 batch 1300 train loss: 0.0147 test loss: 0.0188
# Epoch 1 batch 1400 train loss: 0.0101 test loss: 0.0192
# Epoch 1 batch 1500 train loss: 0.0114 test loss: 0.0188
# Epoch 1 batch 1600 train loss: 0.0081 test loss: 0.0185
# Epoch 1 batch 1700 train loss: 0.0100 test loss: 0.0188
# Epoch 1 batch 1800 train loss: 0.0086 test loss: 0.0187
# Epoch 1 batch 1900 train loss: 0.0145 test loss: 0.0186
# Epoch 1 batch 2000 train loss: 0.0130 test loss: 0.0188
# Epoch 1 batch 2100 train loss: 0.0177 test loss: 0.0189
# Epoch 1 batch 2200 train loss: 0.0091 test loss: 0.0193
# Epoch 1 batch 2300 train loss: 0.0085 test loss: 0.0185
# Epoch 1 batch 2400 train loss: 0.0177 test loss: 0.0190
# Epoch 1 batch 2500 train loss: 0.0099 test loss: 0.0185
# Epoch 1 batch 2600 train loss: 0.0130 test loss: 0.0186
# Epoch 1 batch 2700 train loss: 0.0120 test loss: 0.0187
# Saving checkpoint at ./checkpoints/UNet_50x50_prevnext/ckpt-11
# Epoch 1 batch 2800 train loss: 0.0152 test loss: 0.0183
# Epoch 1 batch 2900 train loss: 0.0148 test loss: 0.0184
# Epoch 2 batch 0 train loss: 0.0090 test loss: 0.0188
# Epoch 2 batch 100 train loss: 0.0137 test loss: 0.0191
# Epoch 2 batch 200 train loss: 0.0128 test loss: 0.0188
# Epoch 2 batch 300 train loss: 0.0140 test loss: 0.0185
# Epoch 2 batch 400 train loss: 0.0123 test loss: 0.0184
# Epoch 2 batch 500 train loss: 0.0180 test loss: 0.0189
# Epoch 2 batch 600 train loss: 0.0135 test loss: 0.0186
# Epoch 2 batch 700 train loss: 0.0123 test loss: 0.0188
# Epoch 2 batch 800 train loss: 0.0182 test loss: 0.0190
# Epoch 2 batch 900 train loss: 0.0087 test loss: 0.0189
# Epoch 2 batch 1000 train loss: 0.0153 test loss: 0.0191
# Epoch 2 batch 1100 train loss: 0.0174 test loss: 0.0190
# Epoch 2 batch 1200 train loss: 0.0136 test loss: 0.0186
# Epoch 2 batch 1300 train loss: 0.0150 test loss: 0.0189
# Epoch 2 batch 1400 train loss: 0.0195 test loss: 0.0188
# Epoch 2 batch 1500 train loss: 0.0153 test loss: 0.0185
# Epoch 2 batch 1600 train loss: 0.0189 test loss: 0.0187
# Epoch 2 batch 1700 train loss: 0.0114 test loss: 0.0190
# Epoch 2 batch 1800 train loss: 0.0099 test loss: 0.0188
# Epoch 2 batch 1900 train loss: 0.0127 test loss: 0.0189
# Epoch 2 batch 2000 train loss: 0.0168 test loss: 0.0188
# Epoch 2 batch 2100 train loss: 0.0109 test loss: 0.0189
# Epoch 2 batch 2200 train loss: 0.0128 test loss: 0.0190
# Epoch 2 batch 2300 train loss: 0.0142 test loss: 0.0190
# Epoch 2 batch 2400 train loss: 0.0142 test loss: 0.0186
# Epoch 2 batch 2500 train loss: 0.0194 test loss: 0.0187
# Epoch 2 batch 2600 train loss: 0.0149 test loss: 0.0188
# Epoch 2 batch 2700 train loss: 0.0063 test loss: 0.0194
# Epoch 2 batch 2800 train loss: 0.0117 test loss: 0.0188
# Epoch 2 batch 2900 train loss: 0.0092 test loss: 0.0185
# Epoch 3 batch 0 train loss: 0.0173 test loss: 0.0185
# Epoch 3 batch 100 train loss: 0.0139 test loss: 0.0187
# Epoch 3 batch 200 train loss: 0.0145 test loss: 0.0189
# Epoch 3 batch 300 train loss: 0.0202 test loss: 0.0185
# Epoch 3 batch 400 train loss: 0.0148 test loss: 0.0186
# Epoch 3 batch 500 train loss: 0.0192 test loss: 0.0187
# Epoch 3 batch 600 train loss: 0.0139 test loss: 0.0189
# Epoch 3 batch 700 train loss: 0.0065 test loss: 0.0192
# Epoch 3 batch 800 train loss: 0.0113 test loss: 0.0190
# Epoch 3 batch 900 train loss: 0.0065 test loss: 0.0189
# Epoch 3 batch 1000 train loss: 0.0094 test loss: 0.0186
# Epoch 3 batch 1100 train loss: 0.0113 test loss: 0.0189
# Epoch 3 batch 1200 train loss: 0.0144 test loss: 0.0185
# Epoch 3 batch 1300 train loss: 0.0084 test loss: 0.0186
# Epoch 3 batch 1400 train loss: 0.0170 test loss: 0.0189
# Epoch 3 batch 1500 train loss: 0.0259 test loss: 0.0187
# Epoch 3 batch 1600 train loss: 0.0134 test loss: 0.0186
# Epoch 3 batch 1700 train loss: 0.0125 test loss: 0.0187
# Epoch 3 batch 1800 train loss: 0.0143 test loss: 0.0189
# Epoch 3 batch 1900 train loss: 0.0260 test loss: 0.0189
# Epoch 3 batch 2000 train loss: 0.0159 test loss: 0.0189
# Epoch 3 batch 2100 train loss: 0.0161 test loss: 0.0190
# Epoch 3 batch 2200 train loss: 0.0171 test loss: 0.0187
# Epoch 3 batch 2300 train loss: 0.0190 test loss: 0.0186
# Epoch 3 batch 2400 train loss: 0.0180 test loss: 0.0188
# Epoch 3 batch 2500 train loss: 0.0118 test loss: 0.0185
# Epoch 3 batch 2600 train loss: 0.0170 test loss: 0.0188
# Epoch 3 batch 2700 train loss: 0.0124 test loss: 0.0190
# Epoch 3 batch 2800 train loss: 0.0173 test loss: 0.0189
# Epoch 3 batch 2900 train loss: 0.0130 test loss: 0.0187
# Epoch 4 batch 0 train loss: 0.0162 test loss: 0.0187
# Epoch 4 batch 100 train loss: 0.0155 test loss: 0.0190
# Epoch 4 batch 200 train loss: 0.0112 test loss: 0.0185
# Epoch 4 batch 300 train loss: 0.0076 test loss: 0.0189
# Epoch 4 batch 400 train loss: 0.0160 test loss: 0.0184
# Epoch 4 batch 500 train loss: 0.0141 test loss: 0.0187
# Epoch 4 batch 600 train loss: 0.0169 test loss: 0.0186
# Epoch 4 batch 700 train loss: 0.0056 test loss: 0.0188
# Epoch 4 batch 800 train loss: 0.0143 test loss: 0.0189
# Epoch 4 batch 900 train loss: 0.0147 test loss: 0.0186
# Epoch 4 batch 1000 train loss: 0.0184 test loss: 0.0184
# Epoch 4 batch 1100 train loss: 0.0115 test loss: 0.0187
# Epoch 4 batch 1200 train loss: 0.0178 test loss: 0.0185
# Epoch 4 batch 1300 train loss: 0.0118 test loss: 0.0189
# Epoch 4 batch 1400 train loss: 0.0120 test loss: 0.0188
# Epoch 4 batch 1500 train loss: 0.0087 test loss: 0.0186
# Epoch 4 batch 1600 train loss: 0.0100 test loss: 0.0187
# Epoch 4 batch 1700 train loss: 0.0117 test loss: 0.0187
# Epoch 4 batch 1800 train loss: 0.0103 test loss: 0.0189
# Epoch 4 batch 1900 train loss: 0.0135 test loss: 0.0190
# Epoch 4 batch 2000 train loss: 0.0066 test loss: 0.0188
# Epoch 4 batch 2100 train loss: 0.0125 test loss: 0.0188
# Epoch 4 batch 2200 train loss: 0.0143 test loss: 0.0188
# Epoch 4 batch 2300 train loss: 0.0205 test loss: 0.0187
# Epoch 4 batch 2400 train loss: 0.0177 test loss: 0.0186
# Epoch 4 batch 2500 train loss: 0.0132 test loss: 0.0188
# Epoch 4 batch 2600 train loss: 0.0053 test loss: 0.0186
# Epoch 4 batch 2700 train loss: 0.0145 test loss: 0.0190
# Epoch 4 batch 2800 train loss: 0.0120 test loss: 0.0186
# Epoch 4 batch 2900 train loss: 0.0208 test loss: 0.0186
# Epoch 5 batch 0 train loss: 0.0136 test loss: 0.0185
# Epoch 5 batch 100 train loss: 0.0098 test loss: 0.0188
# Epoch 5 batch 200 train loss: 0.0167 test loss: 0.0186
# Epoch 5 batch 300 train loss: 0.0114 test loss: 0.0187
# Epoch 5 batch 400 train loss: 0.0149 test loss: 0.0188
# Epoch 5 batch 500 train loss: 0.0137 test loss: 0.0188
# Epoch 5 batch 600 train loss: 0.0138 test loss: 0.0188
# Epoch 5 batch 700 train loss: 0.0153 test loss: 0.0187
# Epoch 5 batch 800 train loss: 0.0199 test loss: 0.0190
# early stop.

# %% [markdown]
# # Model evaluation

# %%
i = -1
if ckpt_manager.checkpoints:
    ckpt.restore(ckpt_manager.checkpoints[i])
    print ('Checkpoint ' + ckpt_manager.checkpoints[i][-2:] +' restored!!')
# Out:
# Checkpoint 11 restored!!

# %%
unet_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
test_loss = unet_model.evaluate(test_dataset)
# Out:
# 2446/2446 [==============================] - 25s 10ms/step - loss: 0.0143

# %%
pred_result = unet_model.predict(test_dataset)

# %%
print(pred_result.shape)
print(test_label.shape)
# Out:
# (78263, 50, 50, 1)
# (78263, 50, 50, 1)

# %%
avg_pred = []
OUTLIER = 1
for __ in range(5):
    temp = []
    for _ in range(int(pred_result.shape[1]/5)):
        temp.append(pred_result[..., _*5:(_+1)*5, 0][..., __])
    temp = np.stack(temp, axis=2)
    temp.sort(axis=2)
    avg_pred.append(temp[..., OUTLIER:-OUTLIER].mean(axis=2))
avg_pred = np.stack(avg_pred, axis=2)

# %%
masking = test_input[..., 1]
avg_masking = masking[..., :5]

# %%
masked_pred = np.ma.array(pred_result[..., 0], mask=masking)
masked_avg_pred = np.ma.array(avg_pred, mask=avg_masking)
masked_label = np.ma.array(test_label[..., 0], mask=masking)

# %%
for _ in range(5):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_pred[..., _].reshape(-1))))
# Out:
# 0.06497122
# 0.11237411
# 0.18025288
# 0.13122328
# 0.13566302

# %%
for _ in range(5):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_avg_pred[..., _].reshape(-1))))
# Out:
# 0.06674881
# 0.08682535
# 0.13314171
# 0.0700786
# 0.113699675

# %%
r2 = RSquare()
for _ in range(5):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_pred[..., _][~masked_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.5109122, shape=(), dtype=float32)
# tf.Tensor(0.16894358, shape=(), dtype=float32)
# tf.Tensor(-2.0684304, shape=(), dtype=float32)
# tf.Tensor(-10.629597, shape=(), dtype=float32)
# tf.Tensor(-0.76520133, shape=(), dtype=float32)

# %%
for _ in range(5):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_avg_pred[..., _][~masked_avg_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.47793013, shape=(), dtype=float32)
# tf.Tensor(0.5097153, shape=(), dtype=float32)
# tf.Tensor(-0.66101694, shape=(), dtype=float32)
# tf.Tensor(-2.2317817, shape=(), dtype=float32)
# tf.Tensor(-0.23236942, shape=(), dtype=float32)

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5]).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_pred = ((MAXS[:5]-MINS[:5])*masked_pred[..., :5] + MINS[:5]).reshape(-1, 1)
plot_pred = plot_pred[~plot_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_pred)))
# Out:
# tf.Tensor(-0.5981014, shape=(), dtype=float32)
# 282.68254210345725

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5]).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_avg_pred = ((MAXS[:5]-MINS[:5])*masked_avg_pred[..., :5] + MINS[:5]).reshape(-1, 1)
plot_avg_pred = plot_avg_pred[~plot_avg_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_avg_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_avg_pred)))
# Out:
# tf.Tensor(-0.5981014, shape=(), dtype=float32)
# 174.73959637639075

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (2):

        NUMBERS = np.arange(1, pred_result.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*8, (6/2.54)*8))
        
        i=3
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=1) #measured
            expect1 = plt.plot(x_t, masked_pred[NUMBER, :, i], 'o', c=cmap[5], alpha=1) #estimated
            expect1 = plt.plot(x_t, masked_avg_pred[NUMBER, :, i], 'o', c=cmap[0], alpha=1) #estimated
            expect2 = plt.plot(x_t, pred_result[NUMBER, :, i], c=cmap[2], alpha=1) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1

# %% [markdown]
# # Saving data

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5])
plot_label.fill_value = np.nan
plot_avg_pred = ((MAXS[:5]-MINS[:5])*masked_avg_pred[..., :5] + MINS[:5])
plot_avg_pred.fill_value = np.nan

# %%
f = open('./results/UNet_%sx%s_prevnext.npz' % (SCREEN_SIZE, SCREEN_SIZE), 'wb')
np.savez(f,
         test_label = plot_label.filled(),
         test_pred = plot_avg_pred.filled()
        )
f.close()
