# %%
import time
import os

import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)

from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras import *
tf.__version__
# Out:
# '2.1.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %% [markdown]
# # Model training

# %% [markdown]
# ## hyperparameters

# %%
SIZE = 100
BEST_PATH = './checkpoints/RNN_%dx%d' % (SIZE, SIZE)
DISP_STEPS = 100
TRAINING_EPOCHS = 500
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# %% [markdown]
# ## data loading

# %%
l = np.load('./data/tot_dataset_%dx%d.npz' % (SIZE, SIZE))
raw_input = l['raw_input']
raw_label = l['raw_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']
MAXS = MAXS[:5]
MINS = MINS[:5]

SCREEN_SIZE = l['SCREEN_SIZE']

# %%
print(raw_input.shape)
print(raw_label.shape)
# Out:
# (132143, 100, 100, 4)
# (132143, 100, 100, 1)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (77063, 100, 100, 4)
# (77063, 100, 100, 1)

# %%
raw_input = np.concatenate([raw_input[..., :5, 0], raw_input[..., :5, 1], raw_input[..., :5, 2], raw_input[..., :5, 3]], axis=-1)
raw_label = raw_label[..., :5, 0]
test_input = np.concatenate([test_input[..., :5, 0], test_input[..., :5, 1], test_input[..., :5, 2], test_input[..., :5, 3]], axis=-1)
test_label = test_label[..., :5, 0]

# %%
print(raw_input.shape)
print(raw_label.shape)
# Out:
# (132143, 100, 20)
# (132143, 100, 5)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (77063, 100, 20)
# (77063, 100, 5)

# %%
raw_input = raw_input.astype(np.float32)
raw_label = raw_label.astype(np.float32)
test_input = test_input.astype(np.float32)
test_label = test_label.astype(np.float32)

# %%
num_train = int(raw_input.shape[0]*.7)
raw_input, raw_label = shuffle(raw_input, raw_label, random_state=4574)
train_input, train_label = raw_input[:num_train, ...], raw_label[:num_train, ...]
val_input, val_label = raw_input[num_train:, ...], raw_label[num_train:, ...]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((test_input, test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
class BiLSTMBlock(layers.Layer):
    def __init__(self, num_hidden):
        super(BiLSTMBlock, self).__init__()
        self.num_hidden = num_hidden
        
        self.bilstm = layers.Bidirectional(layers.LSTM(self.num_hidden, return_sequences=True))
        self.layernorm = layers.LayerNormalization()
        
    def call(self, inp):
        
        inp = self.bilstm(inp)
        inp = self.layernorm(inp)
        
        return inp

# %%
class BiLSTM(Model):
    def __init__(self, out_len):
        super(BiLSTM, self).__init__()
        
        self.out_len = out_len
        
        self.bilstm_block1 = BiLSTMBlock(64)
        self.bilstm_block2 = BiLSTMBlock(64)
        self.ffnn = layers.Dense(self.out_len)
        
    def call(self, inp):
        output = self.bilstm_block1(inp)
        output = self.bilstm_block2(inp)
        output = self.ffnn(inp)
        
        return output

# %%
#loss inputs should be masked.
loss_object = tf.keras.losses.MeanSquaredError()
def loss_function(model, inp, tar): #RNN specialized
    
    masked_real = tar * (1 - inp[..., 5:10])
    masked_pred = model(inp) * (1 - inp[..., 5:10])
    
    return loss_object(masked_real, masked_pred)

# %%
bilstm_model = BiLSTM(test_label.shape[-1])
opt = tf.optimizers.Adam(learning_rate=LEARNING_RATE)

# %%
@tf.function
def train(loss_function, model, opt, inp, tar):
    with tf.GradientTape() as tape:
        gradients = tape.gradient(loss_function(model, inp, tar), model.trainable_variables)
        gradient_variables = zip(gradients, model.trainable_variables)
        opt.apply_gradients(gradient_variables)

# %%
checkpoint_path = BEST_PATH

ckpt = tf.train.Checkpoint(bilstm_model=bilstm_model,
                           opt=opt)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=10)

# %%
writer = tf.summary.create_file_writer('tmp')

# %% [markdown]
# # Training

# %%
prev_test_loss = 100.0
with writer.as_default():
    with tf.summary.record_if(True):
        for epoch in range(TRAINING_EPOCHS):
            for step, (inp, tar) in enumerate(train_dataset):
                train(loss_function, bilstm_model, opt, inp, tar)
                loss_values = loss_function(bilstm_model, inp, tar)
                tf.summary.scalar('loss', loss_values, step=step)
                
                if step % DISP_STEPS == 0:
                    test_loss = 0
                    for step_, (inp_, tar_) in enumerate(test_dataset):
                        test_loss += loss_function(bilstm_model, inp_, tar_)
                        
                        if step_ > DISP_STEPS:
                            test_loss /= DISP_STEPS
                            break
                    if test_loss.numpy() < prev_test_loss:
                        ckpt_save_path = ckpt_manager.save()
                        prev_test_loss = test_loss.numpy()
                        print('Saving checkpoint at {}'.format(ckpt_save_path))
                    print('Epoch {} batch {} train loss: {:.4f} test loss: {:.4f}'
                          .format(epoch, step, loss_values.numpy(), test_loss.numpy()))
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['bi_lstm/bi_lstm_block/bidirectional/forward_lstm/kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/forward_lstm/recurrent_kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/forward_lstm/bias:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/recurrent_kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/bias:0', 'bi_lstm/bi_lstm_block/layer_normalization/gamma:0', 'bi_lstm/bi_lstm_block/layer_normalization/beta:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/recurrent_kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/bias:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/recurrent_kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/bias:0', 'bi_lstm/bi_lstm_block_1/layer_normalization_1/gamma:0', 'bi_lstm/bi_lstm_block_1/layer_normalization_1/beta:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['bi_lstm/bi_lstm_block/bidirectional/forward_lstm/kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/forward_lstm/recurrent_kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/forward_lstm/bias:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/recurrent_kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/bias:0', 'bi_lstm/bi_lstm_block/layer_normalization/gamma:0', 'bi_lstm/bi_lstm_block/layer_normalization/beta:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/recurrent_kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/bias:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/recurrent_kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/bias:0', 'bi_lstm/bi_lstm_block_1/layer_normalization_1/gamma:0', 'bi_lstm/bi_lstm_block_1/layer_normalization_1/beta:0'] when minimizing the loss.
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-1
# Epoch 0 batch 0 train loss: 0.2094 test loss: 0.2447
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-2
# Epoch 0 batch 100 train loss: 0.0866 test loss: 0.1169
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-3
# Epoch 0 batch 200 train loss: 0.0736 test loss: 0.0708
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-4
# Epoch 0 batch 300 train loss: 0.0408 test loss: 0.0454
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-5
# Epoch 0 batch 400 train loss: 0.0283 test loss: 0.0311
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-6
# Epoch 0 batch 500 train loss: 0.0194 test loss: 0.0233
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-7
# Epoch 0 batch 600 train loss: 0.0184 test loss: 0.0187
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-8
# Epoch 0 batch 700 train loss: 0.0166 test loss: 0.0158
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-9
# Epoch 0 batch 800 train loss: 0.0136 test loss: 0.0139
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-10
# Epoch 0 batch 900 train loss: 0.0116 test loss: 0.0127
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-11
# Epoch 0 batch 1000 train loss: 0.0106 test loss: 0.0117
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-12
# Epoch 0 batch 1100 train loss: 0.0101 test loss: 0.0108
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-13
# Epoch 0 batch 1200 train loss: 0.0084 test loss: 0.0103
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-14
# Epoch 0 batch 1300 train loss: 0.0072 test loss: 0.0099
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-15
# Epoch 0 batch 1400 train loss: 0.0089 test loss: 0.0095
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-16
# Epoch 0 batch 1500 train loss: 0.0092 test loss: 0.0089
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-17
# Epoch 0 batch 1600 train loss: 0.0077 test loss: 0.0085
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-18
# Epoch 0 batch 1700 train loss: 0.0084 test loss: 0.0085
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-19
# Epoch 0 batch 1800 train loss: 0.0058 test loss: 0.0081
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-20
# Epoch 0 batch 1900 train loss: 0.0073 test loss: 0.0081
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-21
# Epoch 0 batch 2000 train loss: 0.0070 test loss: 0.0078
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-22
# Epoch 0 batch 2100 train loss: 0.0073 test loss: 0.0078
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-23
# Epoch 0 batch 2200 train loss: 0.0068 test loss: 0.0077
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-24
# Epoch 0 batch 2300 train loss: 0.0068 test loss: 0.0074
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-25
# Epoch 0 batch 2400 train loss: 0.0065 test loss: 0.0074
# Epoch 0 batch 2500 train loss: 0.0067 test loss: 0.0075
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-26
# Epoch 0 batch 2600 train loss: 0.0061 test loss: 0.0071
# Epoch 0 batch 2700 train loss: 0.0057 test loss: 0.0072
# Epoch 0 batch 2800 train loss: 0.0071 test loss: 0.0072
# WARNING:tensorflow:Gradients do not exist for variables ['bi_lstm/bi_lstm_block/bidirectional/forward_lstm/kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/forward_lstm/recurrent_kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/forward_lstm/bias:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/recurrent_kernel:0', 'bi_lstm/bi_lstm_block/bidirectional/backward_lstm/bias:0', 'bi_lstm/bi_lstm_block/layer_normalization/gamma:0', 'bi_lstm/bi_lstm_block/layer_normalization/beta:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/recurrent_kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/forward_lstm_1/bias:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/recurrent_kernel:0', 'bi_lstm/bi_lstm_block_1/bidirectional_1/backward_lstm_1/bias:0', 'bi_lstm/bi_lstm_block_1/layer_normalization_1/gamma:0', 'bi_lstm/bi_lstm_block_1/layer_normalization_1/beta:0'] when minimizing the loss.
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-27
# Epoch 1 batch 0 train loss: 0.0059 test loss: 0.0070
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-28
# Epoch 1 batch 100 train loss: 0.0064 test loss: 0.0068
# Epoch 1 batch 200 train loss: 0.0070 test loss: 0.0071
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-29
# Epoch 1 batch 300 train loss: 0.0059 test loss: 0.0068
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-30
# Epoch 1 batch 400 train loss: 0.0065 test loss: 0.0067
# Epoch 1 batch 500 train loss: 0.0062 test loss: 0.0070
# Epoch 1 batch 600 train loss: 0.0061 test loss: 0.0068
# Epoch 1 batch 700 train loss: 0.0053 test loss: 0.0068
# Epoch 1 batch 800 train loss: 0.0064 test loss: 0.0069
# Epoch 1 batch 900 train loss: 0.0065 test loss: 0.0069
# Epoch 1 batch 1000 train loss: 0.0069 test loss: 0.0069
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-31
# Epoch 1 batch 1100 train loss: 0.0055 test loss: 0.0064
# Epoch 1 batch 1200 train loss: 0.0059 test loss: 0.0068
# Epoch 1 batch 1300 train loss: 0.0052 test loss: 0.0067
# Epoch 1 batch 1400 train loss: 0.0060 test loss: 0.0070
# Epoch 1 batch 1500 train loss: 0.0072 test loss: 0.0067
# Epoch 1 batch 1600 train loss: 0.0066 test loss: 0.0069
# Epoch 1 batch 1700 train loss: 0.0056 test loss: 0.0067
# Epoch 1 batch 1800 train loss: 0.0071 test loss: 0.0069
# Epoch 1 batch 1900 train loss: 0.0057 test loss: 0.0066
# Epoch 1 batch 2000 train loss: 0.0067 test loss: 0.0067
# Epoch 1 batch 2100 train loss: 0.0047 test loss: 0.0067
# Epoch 1 batch 2200 train loss: 0.0058 test loss: 0.0065
# Epoch 1 batch 2300 train loss: 0.0062 test loss: 0.0067
# Epoch 1 batch 2400 train loss: 0.0063 test loss: 0.0070
# Epoch 1 batch 2500 train loss: 0.0068 test loss: 0.0065
# Epoch 1 batch 2600 train loss: 0.0069 test loss: 0.0068
# Epoch 1 batch 2700 train loss: 0.0067 test loss: 0.0066
# Epoch 1 batch 2800 train loss: 0.0075 test loss: 0.0066
# Epoch 2 batch 0 train loss: 0.0055 test loss: 0.0066
# Epoch 2 batch 100 train loss: 0.0067 test loss: 0.0070
# Epoch 2 batch 200 train loss: 0.0063 test loss: 0.0064
# Epoch 2 batch 300 train loss: 0.0073 test loss: 0.0066
# Epoch 2 batch 400 train loss: 0.0064 test loss: 0.0065
# Epoch 2 batch 500 train loss: 0.0054 test loss: 0.0067
# Epoch 2 batch 600 train loss: 0.0064 test loss: 0.0069
# Epoch 2 batch 700 train loss: 0.0066 test loss: 0.0069
# Epoch 2 batch 800 train loss: 0.0072 test loss: 0.0067
# Epoch 2 batch 900 train loss: 0.0063 test loss: 0.0070
# Epoch 2 batch 1000 train loss: 0.0066 test loss: 0.0066
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-32
# Epoch 2 batch 1100 train loss: 0.0063 test loss: 0.0063
# Epoch 2 batch 1200 train loss: 0.0083 test loss: 0.0064
# Epoch 2 batch 1300 train loss: 0.0066 test loss: 0.0067
# Epoch 2 batch 1400 train loss: 0.0060 test loss: 0.0069
# Epoch 2 batch 1500 train loss: 0.0050 test loss: 0.0068
# Epoch 2 batch 1600 train loss: 0.0057 test loss: 0.0068
# Epoch 2 batch 1700 train loss: 0.0060 test loss: 0.0067
# Epoch 2 batch 1800 train loss: 0.0070 test loss: 0.0065
# Epoch 2 batch 1900 train loss: 0.0067 test loss: 0.0069
# Epoch 2 batch 2000 train loss: 0.0060 test loss: 0.0067
# Epoch 2 batch 2100 train loss: 0.0061 test loss: 0.0064
# Epoch 2 batch 2200 train loss: 0.0058 test loss: 0.0068
# Epoch 2 batch 2300 train loss: 0.0055 test loss: 0.0069
# Epoch 2 batch 2400 train loss: 0.0049 test loss: 0.0067
# Epoch 2 batch 2500 train loss: 0.0050 test loss: 0.0064
# Epoch 2 batch 2600 train loss: 0.0069 test loss: 0.0064
# Epoch 2 batch 2700 train loss: 0.0054 test loss: 0.0065
# Epoch 2 batch 2800 train loss: 0.0061 test loss: 0.0065
# Epoch 3 batch 0 train loss: 0.0058 test loss: 0.0069
# Epoch 3 batch 100 train loss: 0.0082 test loss: 0.0064
# Epoch 3 batch 200 train loss: 0.0070 test loss: 0.0067
# Epoch 3 batch 300 train loss: 0.0057 test loss: 0.0067
# Epoch 3 batch 400 train loss: 0.0063 test loss: 0.0067
# Epoch 3 batch 500 train loss: 0.0066 test loss: 0.0065
# Epoch 3 batch 600 train loss: 0.0071 test loss: 0.0069
# Epoch 3 batch 700 train loss: 0.0068 test loss: 0.0066
# Epoch 3 batch 800 train loss: 0.0065 test loss: 0.0066
# Epoch 3 batch 900 train loss: 0.0062 test loss: 0.0066
# Epoch 3 batch 1000 train loss: 0.0078 test loss: 0.0067
# Epoch 3 batch 1100 train loss: 0.0059 test loss: 0.0068
# Epoch 3 batch 1200 train loss: 0.0053 test loss: 0.0067
# Epoch 3 batch 1300 train loss: 0.0063 test loss: 0.0064
# Epoch 3 batch 1400 train loss: 0.0054 test loss: 0.0065
# Epoch 3 batch 1500 train loss: 0.0054 test loss: 0.0067
# Epoch 3 batch 1600 train loss: 0.0059 test loss: 0.0069
# Epoch 3 batch 1700 train loss: 0.0061 test loss: 0.0065
# Epoch 3 batch 1800 train loss: 0.0049 test loss: 0.0068
# Epoch 3 batch 1900 train loss: 0.0053 test loss: 0.0068
# Epoch 3 batch 2000 train loss: 0.0062 test loss: 0.0071
# Epoch 3 batch 2100 train loss: 0.0069 test loss: 0.0067
# Epoch 3 batch 2200 train loss: 0.0065 test loss: 0.0066
# Epoch 3 batch 2300 train loss: 0.0059 test loss: 0.0067
# Epoch 3 batch 2400 train loss: 0.0053 test loss: 0.0065
# Epoch 3 batch 2500 train loss: 0.0056 test loss: 0.0066
# Epoch 3 batch 2600 train loss: 0.0055 test loss: 0.0065
# Epoch 3 batch 2700 train loss: 0.0058 test loss: 0.0065
# Epoch 3 batch 2800 train loss: 0.0049 test loss: 0.0068
# Epoch 4 batch 0 train loss: 0.0060 test loss: 0.0064
# Epoch 4 batch 100 train loss: 0.0054 test loss: 0.0066
# Epoch 4 batch 200 train loss: 0.0074 test loss: 0.0067
# Epoch 4 batch 300 train loss: 0.0050 test loss: 0.0065
# Epoch 4 batch 400 train loss: 0.0047 test loss: 0.0068
# Epoch 4 batch 500 train loss: 0.0060 test loss: 0.0068
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-33
# Epoch 4 batch 600 train loss: 0.0061 test loss: 0.0062
# Epoch 4 batch 700 train loss: 0.0054 test loss: 0.0064
# Epoch 4 batch 800 train loss: 0.0055 test loss: 0.0067
# Epoch 4 batch 900 train loss: 0.0057 test loss: 0.0067
# Epoch 4 batch 1000 train loss: 0.0058 test loss: 0.0063
# Epoch 4 batch 1100 train loss: 0.0059 test loss: 0.0064
# Epoch 4 batch 1200 train loss: 0.0083 test loss: 0.0066
# Epoch 4 batch 1300 train loss: 0.0066 test loss: 0.0068
# Epoch 4 batch 1400 train loss: 0.0048 test loss: 0.0067
# Epoch 4 batch 1500 train loss: 0.0057 test loss: 0.0063
# Epoch 4 batch 1600 train loss: 0.0069 test loss: 0.0065
# Epoch 4 batch 1700 train loss: 0.0056 test loss: 0.0068
# Epoch 4 batch 1800 train loss: 0.0072 test loss: 0.0063
# Epoch 4 batch 1900 train loss: 0.0083 test loss: 0.0064
# Epoch 4 batch 2000 train loss: 0.0066 test loss: 0.0065
# Epoch 4 batch 2100 train loss: 0.0067 test loss: 0.0065
# Epoch 4 batch 2200 train loss: 0.0067 test loss: 0.0065
# Epoch 4 batch 2300 train loss: 0.0062 test loss: 0.0067
# Epoch 4 batch 2400 train loss: 0.0060 test loss: 0.0064
# Epoch 4 batch 2500 train loss: 0.0067 test loss: 0.0062
# Epoch 4 batch 2600 train loss: 0.0076 test loss: 0.0069
# Epoch 4 batch 2700 train loss: 0.0068 test loss: 0.0065
# Epoch 4 batch 2800 train loss: 0.0070 test loss: 0.0065
# Epoch 5 batch 0 train loss: 0.0053 test loss: 0.0067
# Epoch 5 batch 100 train loss: 0.0049 test loss: 0.0065
# Epoch 5 batch 200 train loss: 0.0049 test loss: 0.0065
# Epoch 5 batch 300 train loss: 0.0060 test loss: 0.0065
# Epoch 5 batch 400 train loss: 0.0074 test loss: 0.0065
# Epoch 5 batch 500 train loss: 0.0062 test loss: 0.0067
# Epoch 5 batch 600 train loss: 0.0052 test loss: 0.0066
# Epoch 5 batch 700 train loss: 0.0052 test loss: 0.0064
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-34
# Epoch 5 batch 800 train loss: 0.0067 test loss: 0.0061
# Epoch 5 batch 900 train loss: 0.0065 test loss: 0.0070
# Epoch 5 batch 1000 train loss: 0.0061 test loss: 0.0066
# Epoch 5 batch 1100 train loss: 0.0069 test loss: 0.0067
# Epoch 5 batch 1200 train loss: 0.0055 test loss: 0.0067
# Epoch 5 batch 1300 train loss: 0.0073 test loss: 0.0066
# Epoch 5 batch 1400 train loss: 0.0063 test loss: 0.0067
# Epoch 5 batch 1500 train loss: 0.0066 test loss: 0.0064
# Epoch 5 batch 1600 train loss: 0.0060 test loss: 0.0066
# Epoch 5 batch 1700 train loss: 0.0066 test loss: 0.0065
# Epoch 5 batch 1800 train loss: 0.0063 test loss: 0.0064
# Epoch 5 batch 1900 train loss: 0.0049 test loss: 0.0064
# Epoch 5 batch 2000 train loss: 0.0072 test loss: 0.0064
# Epoch 5 batch 2100 train loss: 0.0061 test loss: 0.0067
# Epoch 5 batch 2200 train loss: 0.0066 test loss: 0.0066
# Epoch 5 batch 2300 train loss: 0.0052 test loss: 0.0067
# Epoch 5 batch 2400 train loss: 0.0057 test loss: 0.0069
# Epoch 5 batch 2500 train loss: 0.0058 test loss: 0.0065
# Epoch 5 batch 2600 train loss: 0.0054 test loss: 0.0068
# Epoch 5 batch 2700 train loss: 0.0074 test loss: 0.0064
# Epoch 5 batch 2800 train loss: 0.0060 test loss: 0.0067
# Epoch 6 batch 0 train loss: 0.0049 test loss: 0.0067
# Epoch 6 batch 100 train loss: 0.0067 test loss: 0.0065
# Epoch 6 batch 200 train loss: 0.0068 test loss: 0.0067
# Epoch 6 batch 300 train loss: 0.0062 test loss: 0.0065
# Epoch 6 batch 400 train loss: 0.0059 test loss: 0.0068
# Epoch 6 batch 500 train loss: 0.0071 test loss: 0.0067
# Saving checkpoint at ./checkpoints/RNN_100x100/ckpt-35
# Epoch 6 batch 600 train loss: 0.0059 test loss: 0.0061
# Epoch 6 batch 700 train loss: 0.0067 test loss: 0.0070
# Epoch 6 batch 800 train loss: 0.0059 test loss: 0.0067
# Epoch 6 batch 900 train loss: 0.0062 test loss: 0.0067
# Epoch 6 batch 1000 train loss: 0.0085 test loss: 0.0067
# Epoch 6 batch 1100 train loss: 0.0066 test loss: 0.0064
# Epoch 6 batch 1200 train loss: 0.0069 test loss: 0.0067
# Epoch 6 batch 1300 train loss: 0.0059 test loss: 0.0066
# Epoch 6 batch 1400 train loss: 0.0059 test loss: 0.0066
# Epoch 6 batch 1500 train loss: 0.0064 test loss: 0.0065
# Epoch 6 batch 1600 train loss: 0.0054 test loss: 0.0066
# Epoch 6 batch 1700 train loss: 0.0061 test loss: 0.0066
# Epoch 6 batch 1800 train loss: 0.0059 test loss: 0.0068
# Epoch 6 batch 1900 train loss: 0.0056 test loss: 0.0063
# Epoch 6 batch 2000 train loss: 0.0061 test loss: 0.0067
# Epoch 6 batch 2100 train loss: 0.0062 test loss: 0.0068
# Epoch 6 batch 2200 train loss: 0.0050 test loss: 0.0065
# Epoch 6 batch 2300 train loss: 0.0066 test loss: 0.0065
# Epoch 6 batch 2400 train loss: 0.0057 test loss: 0.0064
# Epoch 6 batch 2500 train loss: 0.0061 test loss: 0.0066
# Epoch 6 batch 2600 train loss: 0.0060 test loss: 0.0064
# Epoch 6 batch 2700 train loss: 0.0051 test loss: 0.0066
# Epoch 6 batch 2800 train loss: 0.0061 test loss: 0.0065
# Epoch 7 batch 0 train loss: 0.0067 test loss: 0.0065
# Epoch 7 batch 100 train loss: 0.0061 test loss: 0.0066
# Epoch 7 batch 200 train loss: 0.0081 test loss: 0.0067
# Epoch 7 batch 300 train loss: 0.0057 test loss: 0.0070
# Epoch 7 batch 400 train loss: 0.0057 test loss: 0.0065
# Epoch 7 batch 500 train loss: 0.0056 test loss: 0.0068
# Epoch 7 batch 600 train loss: 0.0054 test loss: 0.0067
# Epoch 7 batch 700 train loss: 0.0059 test loss: 0.0067
# Epoch 7 batch 800 train loss: 0.0049 test loss: 0.0063
# Epoch 7 batch 900 train loss: 0.0064 test loss: 0.0067
# Epoch 7 batch 1000 train loss: 0.0055 test loss: 0.0066
# Epoch 7 batch 1100 train loss: 0.0064 test loss: 0.0067
# Epoch 7 batch 1200 train loss: 0.0060 test loss: 0.0064
# Epoch 7 batch 1300 train loss: 0.0068 test loss: 0.0068
# Epoch 7 batch 1400 train loss: 0.0060 test loss: 0.0067
# Epoch 7 batch 1500 train loss: 0.0059 test loss: 0.0065
# Epoch 7 batch 1600 train loss: 0.0058 test loss: 0.0066
# Epoch 7 batch 1700 train loss: 0.0054 test loss: 0.0067
# Epoch 7 batch 1800 train loss: 0.0052 test loss: 0.0065
# Epoch 7 batch 1900 train loss: 0.0084 test loss: 0.0064
# Epoch 7 batch 2000 train loss: 0.0053 test loss: 0.0065
# Epoch 7 batch 2100 train loss: 0.0057 test loss: 0.0065
# Epoch 7 batch 2200 train loss: 0.0055 test loss: 0.0069
# Epoch 7 batch 2300 train loss: 0.0051 test loss: 0.0067
# Epoch 7 batch 2400 train loss: 0.0075 test loss: 0.0068
# Epoch 7 batch 2500 train loss: 0.0063 test loss: 0.0065
# Epoch 7 batch 2600 train loss: 0.0057 test loss: 0.0063
# Epoch 7 batch 2700 train loss: 0.0055 test loss: 0.0070
# Epoch 7 batch 2800 train loss: 0.0057 test loss: 0.0065
# Epoch 8 batch 0 train loss: 0.0060 test loss: 0.0065
# Epoch 8 batch 100 train loss: 0.0058 test loss: 0.0068
# Epoch 8 batch 200 train loss: 0.0062 test loss: 0.0070
# Epoch 8 batch 300 train loss: 0.0075 test loss: 0.0068
# Epoch 8 batch 400 train loss: 0.0071 test loss: 0.0067
# Epoch 8 batch 500 train loss: 0.0064 test loss: 0.0069
# Epoch 8 batch 600 train loss: 0.0060 test loss: 0.0063
# Epoch 8 batch 700 train loss: 0.0051 test loss: 0.0068
# Epoch 8 batch 800 train loss: 0.0067 test loss: 0.0062
# Epoch 8 batch 900 train loss: 0.0064 test loss: 0.0067
# Epoch 8 batch 1000 train loss: 0.0054 test loss: 0.0068
# Epoch 8 batch 1100 train loss: 0.0069 test loss: 0.0064
# Epoch 8 batch 1200 train loss: 0.0063 test loss: 0.0065
# Epoch 8 batch 1300 train loss: 0.0063 test loss: 0.0068
# Epoch 8 batch 1400 train loss: 0.0066 test loss: 0.0068
# Epoch 8 batch 1500 train loss: 0.0068 test loss: 0.0067
# Epoch 8 batch 1600 train loss: 0.0058 test loss: 0.0063
# Epoch 8 batch 1700 train loss: 0.0052 test loss: 0.0070
# Epoch 8 batch 1800 train loss: 0.0071 test loss: 0.0064
# Epoch 8 batch 1900 train loss: 0.0057 test loss: 0.0067
# Epoch 8 batch 2000 train loss: 0.0059 test loss: 0.0065
# Epoch 8 batch 2100 train loss: 0.0056 test loss: 0.0067
# Epoch 8 batch 2200 train loss: 0.0076 test loss: 0.0066
# Epoch 8 batch 2300 train loss: 0.0055 test loss: 0.0066
# Epoch 8 batch 2400 train loss: 0.0066 test loss: 0.0067
# Epoch 8 batch 2500 train loss: 0.0050 test loss: 0.0067
# Epoch 8 batch 2600 train loss: 0.0065 test loss: 0.0067
# Epoch 8 batch 2700 train loss: 0.0060 test loss: 0.0065
# Epoch 8 batch 2800 train loss: 0.0070 test loss: 0.0068
# Epoch 9 batch 0 train loss: 0.0053 test loss: 0.0072
# Epoch 9 batch 100 train loss: 0.0059 test loss: 0.0068
# Epoch 9 batch 200 train loss: 0.0072 test loss: 0.0065
# Epoch 9 batch 300 train loss: 0.0073 test loss: 0.0063
# Epoch 9 batch 400 train loss: 0.0057 test loss: 0.0072
# Epoch 9 batch 500 train loss: 0.0054 test loss: 0.0068
# Epoch 9 batch 600 train loss: 0.0073 test loss: 0.0064
# Epoch 9 batch 700 train loss: 0.0065 test loss: 0.0068
# Epoch 9 batch 800 train loss: 0.0059 test loss: 0.0066
# Epoch 9 batch 900 train loss: 0.0077 test loss: 0.0065
# Epoch 9 batch 1000 train loss: 0.0062 test loss: 0.0064
# Epoch 9 batch 1100 train loss: 0.0059 test loss: 0.0066
# Epoch 9 batch 1200 train loss: 0.0053 test loss: 0.0067
# Epoch 9 batch 1300 train loss: 0.0049 test loss: 0.0067
# Epoch 9 batch 1400 train loss: 0.0075 test loss: 0.0066
# Epoch 9 batch 1500 train loss: 0.0064 test loss: 0.0068
# Epoch 9 batch 1600 train loss: 0.0079 test loss: 0.0068
# Epoch 9 batch 1700 train loss: 0.0070 test loss: 0.0067
# Epoch 9 batch 1800 train loss: 0.0058 test loss: 0.0066
# Epoch 9 batch 1900 train loss: 0.0071 test loss: 0.0067
# Epoch 9 batch 2000 train loss: 0.0048 test loss: 0.0066
# Epoch 9 batch 2100 train loss: 0.0075 test loss: 0.0065
# Epoch 9 batch 2200 train loss: 0.0058 test loss: 0.0065
# Epoch 9 batch 2300 train loss: 0.0071 test loss: 0.0067
# Epoch 9 batch 2400 train loss: 0.0057 test loss: 0.0066
# Epoch 9 batch 2500 train loss: 0.0057 test loss: 0.0068
# Epoch 9 batch 2600 train loss: 0.0067 test loss: 0.0068
# Epoch 9 batch 2700 train loss: 0.0077 test loss: 0.0065
# Epoch 9 batch 2800 train loss: 0.0067 test loss: 0.0068
# Epoch 10 batch 0 train loss: 0.0073 test loss: 0.0065
# Epoch 10 batch 100 train loss: 0.0051 test loss: 0.0068
# Epoch 10 batch 200 train loss: 0.0054 test loss: 0.0068
# Epoch 10 batch 300 train loss: 0.0057 test loss: 0.0067
# Epoch 10 batch 400 train loss: 0.0073 test loss: 0.0066
# Epoch 10 batch 500 train loss: 0.0048 test loss: 0.0067
# Epoch 10 batch 600 train loss: 0.0072 test loss: 0.0068
# Epoch 10 batch 700 train loss: 0.0048 test loss: 0.0067
# Epoch 10 batch 800 train loss: 0.0079 test loss: 0.0068
# Epoch 10 batch 900 train loss: 0.0071 test loss: 0.0064
# Epoch 10 batch 1000 train loss: 0.0056 test loss: 0.0070
# Epoch 10 batch 1100 train loss: 0.0070 test loss: 0.0067
# Epoch 10 batch 1200 train loss: 0.0065 test loss: 0.0062
# Epoch 10 batch 1300 train loss: 0.0065 test loss: 0.0071
# Epoch 10 batch 1400 train loss: 0.0060 test loss: 0.0066
# Epoch 10 batch 1500 train loss: 0.0062 test loss: 0.0066
# Epoch 10 batch 1600 train loss: 0.0054 test loss: 0.0067
# Epoch 10 batch 1700 train loss: 0.0050 test loss: 0.0068
# Epoch 10 batch 1800 train loss: 0.0066 test loss: 0.0067
# Epoch 10 batch 1900 train loss: 0.0051 test loss: 0.0065
# Epoch 10 batch 2000 train loss: 0.0062 test loss: 0.0064
# Epoch 10 batch 2100 train loss: 0.0058 test loss: 0.0065
# Epoch 10 batch 2200 train loss: 0.0060 test loss: 0.0064
# Epoch 10 batch 2300 train loss: 0.0064 test loss: 0.0065
# Epoch 10 batch 2400 train loss: 0.0065 test loss: 0.0067
# Epoch 10 batch 2500 train loss: 0.0061 test loss: 0.0070
# Epoch 10 batch 2600 train loss: 0.0061 test loss: 0.0067
# Epoch 10 batch 2700 train loss: 0.0056 test loss: 0.0066
# Epoch 10 batch 2800 train loss: 0.0066 test loss: 0.0067
# Epoch 11 batch 0 train loss: 0.0058 test loss: 0.0067
# Epoch 11 batch 100 train loss: 0.0065 test loss: 0.0066
# Epoch 11 batch 200 train loss: 0.0066 test loss: 0.0071
# Epoch 11 batch 300 train loss: 0.0052 test loss: 0.0065
# Epoch 11 batch 400 train loss: 0.0075 test loss: 0.0068
# Epoch 11 batch 500 train loss: 0.0064 test loss: 0.0071
# Epoch 11 batch 600 train loss: 0.0055 test loss: 0.0064
# Epoch 11 batch 700 train loss: 0.0071 test loss: 0.0065
# Epoch 11 batch 800 train loss: 0.0045 test loss: 0.0066
# Epoch 11 batch 900 train loss: 0.0054 test loss: 0.0068
# Epoch 11 batch 1000 train loss: 0.0059 test loss: 0.0066
# Epoch 11 batch 1100 train loss: 0.0067 test loss: 0.0066
# Epoch 11 batch 1200 train loss: 0.0062 test loss: 0.0066
# Epoch 11 batch 1300 train loss: 0.0076 test loss: 0.0068
# Epoch 11 batch 1400 train loss: 0.0071 test loss: 0.0067
# Epoch 11 batch 1500 train loss: 0.0054 test loss: 0.0069
# Epoch 11 batch 1600 train loss: 0.0056 test loss: 0.0067
# Epoch 11 batch 1700 train loss: 0.0044 test loss: 0.0067
# Epoch 11 batch 1800 train loss: 0.0060 test loss: 0.0066
# Epoch 11 batch 1900 train loss: 0.0064 test loss: 0.0067
# Epoch 11 batch 2000 train loss: 0.0070 test loss: 0.0067
# Epoch 11 batch 2100 train loss: 0.0066 test loss: 0.0068
# Epoch 11 batch 2200 train loss: 0.0059 test loss: 0.0067
# Epoch 11 batch 2300 train loss: 0.0078 test loss: 0.0066
# Epoch 11 batch 2400 train loss: 0.0065 test loss: 0.0067
# Epoch 11 batch 2500 train loss: 0.0060 test loss: 0.0065
# Epoch 11 batch 2600 train loss: 0.0067 test loss: 0.0066
# Epoch 11 batch 2700 train loss: 0.0064 test loss: 0.0066
# Epoch 11 batch 2800 train loss: 0.0063 test loss: 0.0064
# Epoch 12 batch 0 train loss: 0.0080 test loss: 0.0065
# Epoch 12 batch 100 train loss: 0.0058 test loss: 0.0064
# Epoch 12 batch 200 train loss: 0.0063 test loss: 0.0065
# Epoch 12 batch 300 train loss: 0.0068 test loss: 0.0064
# Epoch 12 batch 400 train loss: 0.0057 test loss: 0.0069
# Epoch 12 batch 500 train loss: 0.0056 test loss: 0.0066
# Epoch 12 batch 600 train loss: 0.0067 test loss: 0.0065
# Epoch 12 batch 700 train loss: 0.0056 test loss: 0.0066
# Epoch 12 batch 800 train loss: 0.0064 test loss: 0.0064
# Epoch 12 batch 900 train loss: 0.0049 test loss: 0.0066
# Epoch 12 batch 1000 train loss: 0.0052 test loss: 0.0068
# Epoch 12 batch 1100 train loss: 0.0056 test loss: 0.0064
# Epoch 12 batch 1200 train loss: 0.0060 test loss: 0.0065
# Epoch 12 batch 1300 train loss: 0.0055 test loss: 0.0067
# Epoch 12 batch 1400 train loss: 0.0062 test loss: 0.0067
# Epoch 12 batch 1500 train loss: 0.0064 test loss: 0.0068
# Epoch 12 batch 1600 train loss: 0.0063 test loss: 0.0067
# Epoch 12 batch 1700 train loss: 0.0064 test loss: 0.0068
# Epoch 12 batch 1800 train loss: 0.0061 test loss: 0.0064
# Epoch 12 batch 1900 train loss: 0.0074 test loss: 0.0067
# Epoch 12 batch 2000 train loss: 0.0048 test loss: 0.0068
# Epoch 12 batch 2100 train loss: 0.0065 test loss: 0.0064
# Epoch 12 batch 2200 train loss: 0.0072 test loss: 0.0065
# Epoch 12 batch 2300 train loss: 0.0064 test loss: 0.0066
# Epoch 12 batch 2400 train loss: 0.0087 test loss: 0.0067
# Epoch 12 batch 2500 train loss: 0.0045 test loss: 0.0065
# Epoch 12 batch 2600 train loss: 0.0053 test loss: 0.0066
# Epoch 12 batch 2700 train loss: 0.0058 test loss: 0.0064
# Epoch 12 batch 2800 train loss: 0.0063 test loss: 0.0065
# Epoch 13 batch 0 train loss: 0.0059 test loss: 0.0066
# Epoch 13 batch 100 train loss: 0.0057 test loss: 0.0064
# Epoch 13 batch 200 train loss: 0.0051 test loss: 0.0066
# Epoch 13 batch 300 train loss: 0.0063 test loss: 0.0067
# Epoch 13 batch 400 train loss: 0.0056 test loss: 0.0067
# Epoch 13 batch 500 train loss: 0.0069 test loss: 0.0069
# Epoch 13 batch 600 train loss: 0.0066 test loss: 0.0064
# Epoch 13 batch 700 train loss: 0.0062 test loss: 0.0068
# Epoch 13 batch 800 train loss: 0.0058 test loss: 0.0066
# Epoch 13 batch 900 train loss: 0.0048 test loss: 0.0065
# Epoch 13 batch 1000 train loss: 0.0058 test loss: 0.0065
# Epoch 13 batch 1100 train loss: 0.0053 test loss: 0.0064
# Epoch 13 batch 1200 train loss: 0.0050 test loss: 0.0065
# Epoch 13 batch 1300 train loss: 0.0051 test loss: 0.0065
# Epoch 13 batch 1400 train loss: 0.0059 test loss: 0.0064
# Epoch 13 batch 1500 train loss: 0.0055 test loss: 0.0067
# Epoch 13 batch 1600 train loss: 0.0057 test loss: 0.0065
# Epoch 13 batch 1700 train loss: 0.0060 test loss: 0.0067
# Epoch 13 batch 1800 train loss: 0.0065 test loss: 0.0065
# Epoch 13 batch 1900 train loss: 0.0067 test loss: 0.0070
# Epoch 13 batch 2000 train loss: 0.0076 test loss: 0.0064
# Epoch 13 batch 2100 train loss: 0.0068 test loss: 0.0066
# Epoch 13 batch 2200 train loss: 0.0065 test loss: 0.0068
# Epoch 13 batch 2300 train loss: 0.0053 test loss: 0.0064
# Epoch 13 batch 2400 train loss: 0.0064 test loss: 0.0068
# Epoch 13 batch 2500 train loss: 0.0070 test loss: 0.0065
# Epoch 13 batch 2600 train loss: 0.0062 test loss: 0.0064
# Epoch 13 batch 2700 train loss: 0.0059 test loss: 0.0066
# Epoch 13 batch 2800 train loss: 0.0065 test loss: 0.0067
# Epoch 14 batch 0 train loss: 0.0072 test loss: 0.0066
# Epoch 14 batch 100 train loss: 0.0059 test loss: 0.0065
# Epoch 14 batch 200 train loss: 0.0076 test loss: 0.0069
# Epoch 14 batch 300 train loss: 0.0058 test loss: 0.0064
# Epoch 14 batch 400 train loss: 0.0056 test loss: 0.0066
# Epoch 14 batch 500 train loss: 0.0073 test loss: 0.0067
# Epoch 14 batch 600 train loss: 0.0060 test loss: 0.0063
# Epoch 14 batch 700 train loss: 0.0063 test loss: 0.0068
# Epoch 14 batch 800 train loss: 0.0061 test loss: 0.0066
# Epoch 14 batch 900 train loss: 0.0066 test loss: 0.0065
# Epoch 14 batch 1000 train loss: 0.0068 test loss: 0.0066
# Epoch 14 batch 1100 train loss: 0.0057 test loss: 0.0062
# Epoch 14 batch 1200 train loss: 0.0065 test loss: 0.0062
# Epoch 14 batch 1300 train loss: 0.0058 test loss: 0.0067
# Epoch 14 batch 1400 train loss: 0.0053 test loss: 0.0065
# Epoch 14 batch 1500 train loss: 0.0055 test loss: 0.0065
# Epoch 14 batch 1600 train loss: 0.0063 test loss: 0.0063
# Epoch 14 batch 1700 train loss: 0.0055 test loss: 0.0067
# Epoch 14 batch 1800 train loss: 0.0067 test loss: 0.0066
# Epoch 14 batch 1900 train loss: 0.0086 test loss: 0.0068
# Epoch 14 batch 2000 train loss: 0.0068 test loss: 0.0067
# Epoch 14 batch 2100 train loss: 0.0070 test loss: 0.0065
# Epoch 14 batch 2200 train loss: 0.0064 test loss: 0.0065
# Epoch 14 batch 2300 train loss: 0.0059 test loss: 0.0065
# Epoch 14 batch 2400 train loss: 0.0071 test loss: 0.0068
# Epoch 14 batch 2500 train loss: 0.0061 test loss: 0.0065
# Epoch 14 batch 2600 train loss: 0.0064 test loss: 0.0068
# Epoch 14 batch 2700 train loss: 0.0061 test loss: 0.0064
# Epoch 14 batch 2800 train loss: 0.0064 test loss: 0.0067
# Epoch 15 batch 0 train loss: 0.0057 test loss: 0.0070
# Epoch 15 batch 100 train loss: 0.0079 test loss: 0.0066
# Epoch 15 batch 200 train loss: 0.0069 test loss: 0.0069
# Epoch 15 batch 300 train loss: 0.0054 test loss: 0.0068
# Epoch 15 batch 400 train loss: 0.0055 test loss: 0.0069
# Epoch 15 batch 500 train loss: 0.0052 test loss: 0.0066
# Epoch 15 batch 600 train loss: 0.0076 test loss: 0.0065
# Epoch 15 batch 700 train loss: 0.0070 test loss: 0.0068
# Epoch 15 batch 800 train loss: 0.0054 test loss: 0.0065
# Epoch 15 batch 900 train loss: 0.0054 test loss: 0.0068
# Epoch 15 batch 1000 train loss: 0.0064 test loss: 0.0067
# Epoch 15 batch 1100 train loss: 0.0065 test loss: 0.0063
# Epoch 15 batch 1200 train loss: 0.0084 test loss: 0.0068
# Epoch 15 batch 1300 train loss: 0.0061 test loss: 0.0065
# Epoch 15 batch 1400 train loss: 0.0062 test loss: 0.0066
# Epoch 15 batch 1500 train loss: 0.0077 test loss: 0.0065
# Epoch 15 batch 1600 train loss: 0.0060 test loss: 0.0067
# Epoch 15 batch 1700 train loss: 0.0069 test loss: 0.0068
# Epoch 15 batch 1800 train loss: 0.0046 test loss: 0.0067
# Epoch 15 batch 1900 train loss: 0.0050 test loss: 0.0069
# Epoch 15 batch 2000 train loss: 0.0077 test loss: 0.0065
# Epoch 15 batch 2100 train loss: 0.0074 test loss: 0.0063
# Epoch 15 batch 2200 train loss: 0.0077 test loss: 0.0066
# Epoch 15 batch 2300 train loss: 0.0077 test loss: 0.0065
# Epoch 15 batch 2400 train loss: 0.0070 test loss: 0.0065
# Epoch 15 batch 2500 train loss: 0.0063 test loss: 0.0065
# Epoch 15 batch 2600 train loss: 0.0063 test loss: 0.0067
# Epoch 15 batch 2700 train loss: 0.0051 test loss: 0.0067
# Epoch 15 batch 2800 train loss: 0.0058 test loss: 0.0067
# Epoch 16 batch 0 train loss: 0.0053 test loss: 0.0065
# Epoch 16 batch 100 train loss: 0.0061 test loss: 0.0067
# Epoch 16 batch 200 train loss: 0.0063 test loss: 0.0068
# Epoch 16 batch 300 train loss: 0.0057 test loss: 0.0068
# Epoch 16 batch 400 train loss: 0.0072 test loss: 0.0064
# Epoch 16 batch 500 train loss: 0.0051 test loss: 0.0067
# Epoch 16 batch 600 train loss: 0.0048 test loss: 0.0067
# Epoch 16 batch 700 train loss: 0.0072 test loss: 0.0064
# Epoch 16 batch 800 train loss: 0.0052 test loss: 0.0065
# Epoch 16 batch 900 train loss: 0.0061 test loss: 0.0068
# Epoch 16 batch 1000 train loss: 0.0056 test loss: 0.0065
# Epoch 16 batch 1100 train loss: 0.0059 test loss: 0.0063
# Epoch 16 batch 1200 train loss: 0.0058 test loss: 0.0069
# Epoch 16 batch 1300 train loss: 0.0061 test loss: 0.0067
# Epoch 16 batch 1400 train loss: 0.0068 test loss: 0.0066
# Epoch 16 batch 1500 train loss: 0.0057 test loss: 0.0065
# Epoch 16 batch 1600 train loss: 0.0068 test loss: 0.0068
# Epoch 16 batch 1700 train loss: 0.0064 test loss: 0.0068
# Epoch 16 batch 1800 train loss: 0.0064 test loss: 0.0067
# Epoch 16 batch 1900 train loss: 0.0044 test loss: 0.0065
# Epoch 16 batch 2000 train loss: 0.0070 test loss: 0.0066
# Epoch 16 batch 2100 train loss: 0.0074 test loss: 0.0065
# Epoch 16 batch 2200 train loss: 0.0054 test loss: 0.0067
# Epoch 16 batch 2300 train loss: 0.0057 test loss: 0.0065
# Epoch 16 batch 2400 train loss: 0.0066 test loss: 0.0065
# Epoch 16 batch 2500 train loss: 0.0053 test loss: 0.0063
# Epoch 16 batch 2600 train loss: 0.0054 test loss: 0.0066
# Epoch 16 batch 2700 train loss: 0.0049 test loss: 0.0065
# Epoch 16 batch 2800 train loss: 0.0060 test loss: 0.0068
# Epoch 17 batch 0 train loss: 0.0058 test loss: 0.0064
# Epoch 17 batch 100 train loss: 0.0060 test loss: 0.0069
# Epoch 17 batch 200 train loss: 0.0063 test loss: 0.0065
# Epoch 17 batch 300 train loss: 0.0051 test loss: 0.0065
# Epoch 17 batch 400 train loss: 0.0075 test loss: 0.0067
# Epoch 17 batch 500 train loss: 0.0065 test loss: 0.0069
# Epoch 17 batch 600 train loss: 0.0062 test loss: 0.0063
# Epoch 17 batch 700 train loss: 0.0055 test loss: 0.0067
# Epoch 17 batch 800 train loss: 0.0053 test loss: 0.0067
# Epoch 17 batch 900 train loss: 0.0043 test loss: 0.0067
# Epoch 17 batch 1000 train loss: 0.0073 test loss: 0.0067
# Epoch 17 batch 1100 train loss: 0.0065 test loss: 0.0067
# Epoch 17 batch 1200 train loss: 0.0054 test loss: 0.0065
# Epoch 17 batch 1300 train loss: 0.0053 test loss: 0.0067
# Epoch 17 batch 1400 train loss: 0.0068 test loss: 0.0072
# Epoch 17 batch 1500 train loss: 0.0055 test loss: 0.0064
# Epoch 17 batch 1600 train loss: 0.0059 test loss: 0.0068
# Epoch 17 batch 1700 train loss: 0.0064 test loss: 0.0069
# Epoch 17 batch 1800 train loss: 0.0069 test loss: 0.0063
# Epoch 17 batch 1900 train loss: 0.0065 test loss: 0.0068
# Epoch 17 batch 2000 train loss: 0.0069 test loss: 0.0066
# Epoch 17 batch 2100 train loss: 0.0056 test loss: 0.0069
# Epoch 17 batch 2200 train loss: 0.0052 test loss: 0.0067
# Epoch 17 batch 2300 train loss: 0.0060 test loss: 0.0067
# Epoch 17 batch 2400 train loss: 0.0051 test loss: 0.0064
# Epoch 17 batch 2500 train loss: 0.0063 test loss: 0.0068
# Epoch 17 batch 2600 train loss: 0.0055 test loss: 0.0066
# Epoch 17 batch 2700 train loss: 0.0051 test loss: 0.0065
# Epoch 17 batch 2800 train loss: 0.0069 test loss: 0.0066
# Epoch 18 batch 0 train loss: 0.0067 test loss: 0.0065
# Epoch 18 batch 100 train loss: 0.0055 test loss: 0.0068
# Epoch 18 batch 200 train loss: 0.0048 test loss: 0.0066
# Epoch 18 batch 300 train loss: 0.0048 test loss: 0.0064
# Epoch 18 batch 400 train loss: 0.0064 test loss: 0.0068
# Epoch 18 batch 500 train loss: 0.0060 test loss: 0.0068
# Epoch 18 batch 600 train loss: 0.0062 test loss: 0.0063
# Epoch 18 batch 700 train loss: 0.0070 test loss: 0.0068
# Epoch 18 batch 800 train loss: 0.0071 test loss: 0.0066
# Epoch 18 batch 900 train loss: 0.0074 test loss: 0.0070
# Epoch 18 batch 1000 train loss: 0.0051 test loss: 0.0065
# Epoch 18 batch 1100 train loss: 0.0062 test loss: 0.0066
# Epoch 18 batch 1200 train loss: 0.0069 test loss: 0.0068
# Epoch 18 batch 1300 train loss: 0.0072 test loss: 0.0066
# Epoch 18 batch 1400 train loss: 0.0065 test loss: 0.0064
# Epoch 18 batch 1500 train loss: 0.0066 test loss: 0.0064
# Epoch 18 batch 1600 train loss: 0.0061 test loss: 0.0068
# Epoch 18 batch 1700 train loss: 0.0064 test loss: 0.0067
# Epoch 18 batch 1800 train loss: 0.0064 test loss: 0.0065
# Epoch 18 batch 1900 train loss: 0.0064 test loss: 0.0064
# Epoch 18 batch 2000 train loss: 0.0074 test loss: 0.0067
# Epoch 18 batch 2100 train loss: 0.0063 test loss: 0.0066
# Epoch 18 batch 2200 train loss: 0.0071 test loss: 0.0065
# Epoch 18 batch 2300 train loss: 0.0057 test loss: 0.0066
# Epoch 18 batch 2400 train loss: 0.0063 test loss: 0.0068
# Epoch 18 batch 2500 train loss: 0.0053 test loss: 0.0065
# Epoch 18 batch 2600 train loss: 0.0066 test loss: 0.0064
# Epoch 18 batch 2700 train loss: 0.0052 test loss: 0.0062
# Epoch 18 batch 2800 train loss: 0.0062 test loss: 0.0065
# Epoch 19 batch 0 train loss: 0.0055 test loss: 0.0067
# Epoch 19 batch 100 train loss: 0.0059 test loss: 0.0065
# Epoch 19 batch 200 train loss: 0.0053 test loss: 0.0069
# Epoch 19 batch 300 train loss: 0.0070 test loss: 0.0066
# Epoch 19 batch 400 train loss: 0.0056 test loss: 0.0071
# Epoch 19 batch 500 train loss: 0.0065 test loss: 0.0066
# Epoch 19 batch 600 train loss: 0.0071 test loss: 0.0064
# Epoch 19 batch 700 train loss: 0.0053 test loss: 0.0067
# Epoch 19 batch 800 train loss: 0.0062 test loss: 0.0064
# Epoch 19 batch 900 train loss: 0.0060 test loss: 0.0070
# Epoch 19 batch 1000 train loss: 0.0069 test loss: 0.0066
# Epoch 19 batch 1100 train loss: 0.0058 test loss: 0.0062
# Epoch 19 batch 1200 train loss: 0.0048 test loss: 0.0067
# Epoch 19 batch 1300 train loss: 0.0050 test loss: 0.0066
# Epoch 19 batch 1400 train loss: 0.0062 test loss: 0.0067
# Epoch 19 batch 1500 train loss: 0.0053 test loss: 0.0066
# Epoch 19 batch 1600 train loss: 0.0069 test loss: 0.0067
# Epoch 19 batch 1700 train loss: 0.0056 test loss: 0.0065
# Epoch 19 batch 1800 train loss: 0.0062 test loss: 0.0066
# Epoch 19 batch 1900 train loss: 0.0058 test loss: 0.0064
# Epoch 19 batch 2000 train loss: 0.0058 test loss: 0.0063
# Epoch 19 batch 2100 train loss: 0.0075 test loss: 0.0067
# Epoch 19 batch 2200 train loss: 0.0061 test loss: 0.0065
# Epoch 19 batch 2300 train loss: 0.0060 test loss: 0.0066
# Epoch 19 batch 2400 train loss: 0.0056 test loss: 0.0064
# Epoch 19 batch 2500 train loss: 0.0043 test loss: 0.0065
# Epoch 19 batch 2600 train loss: 0.0061 test loss: 0.0068
# Epoch 19 batch 2700 train loss: 0.0058 test loss: 0.0067
# Epoch 19 batch 2800 train loss: 0.0068 test loss: 0.0063
# Epoch 20 batch 0 train loss: 0.0063 test loss: 0.0064
# Epoch 20 batch 100 train loss: 0.0055 test loss: 0.0065
# Epoch 20 batch 200 train loss: 0.0073 test loss: 0.0064
# Epoch 20 batch 300 train loss: 0.0057 test loss: 0.0069
# Epoch 20 batch 400 train loss: 0.0065 test loss: 0.0070
# Epoch 20 batch 500 train loss: 0.0069 test loss: 0.0065
# Epoch 20 batch 600 train loss: 0.0053 test loss: 0.0061
# Epoch 20 batch 700 train loss: 0.0062 test loss: 0.0068
# Epoch 20 batch 800 train loss: 0.0063 test loss: 0.0064
# Epoch 20 batch 900 train loss: 0.0073 test loss: 0.0064
# Epoch 20 batch 1000 train loss: 0.0061 test loss: 0.0066
# Epoch 20 batch 1100 train loss: 0.0054 test loss: 0.0066
# Epoch 20 batch 1200 train loss: 0.0073 test loss: 0.0064
# Epoch 20 batch 1300 train loss: 0.0059 test loss: 0.0065
# Epoch 20 batch 1400 train loss: 0.0061 test loss: 0.0071
# Epoch 20 batch 1500 train loss: 0.0070 test loss: 0.0070
# Epoch 20 batch 1600 train loss: 0.0066 test loss: 0.0067
# Epoch 20 batch 1700 train loss: 0.0065 test loss: 0.0067
# Epoch 20 batch 1800 train loss: 0.0057 test loss: 0.0065
# Epoch 20 batch 1900 train loss: 0.0059 test loss: 0.0070
# Epoch 20 batch 2000 train loss: 0.0055 test loss: 0.0066
# Epoch 20 batch 2100 train loss: 0.0054 test loss: 0.0067
# Epoch 20 batch 2200 train loss: 0.0061 test loss: 0.0068
# Epoch 20 batch 2300 train loss: 0.0064 test loss: 0.0068
# Epoch 20 batch 2400 train loss: 0.0063 test loss: 0.0066
# Epoch 20 batch 2500 train loss: 0.0052 test loss: 0.0066
# Epoch 20 batch 2600 train loss: 0.0058 test loss: 0.0065
# Epoch 20 batch 2700 train loss: 0.0062 test loss: 0.0066
# Epoch 20 batch 2800 train loss: 0.0063 test loss: 0.0064
# Epoch 21 batch 0 train loss: 0.0064 test loss: 0.0067
# Epoch 21 batch 100 train loss: 0.0052 test loss: 0.0067
# Epoch 21 batch 200 train loss: 0.0065 test loss: 0.0068
# Epoch 21 batch 300 train loss: 0.0055 test loss: 0.0066
# Epoch 21 batch 400 train loss: 0.0065 test loss: 0.0067
# Epoch 21 batch 500 train loss: 0.0070 test loss: 0.0069
# Epoch 21 batch 600 train loss: 0.0070 test loss: 0.0066
# Epoch 21 batch 700 train loss: 0.0061 test loss: 0.0067
# Epoch 21 batch 800 train loss: 0.0055 test loss: 0.0067
# Epoch 21 batch 900 train loss: 0.0065 test loss: 0.0068
# Epoch 21 batch 1000 train loss: 0.0061 test loss: 0.0068
# Epoch 21 batch 1100 train loss: 0.0068 test loss: 0.0066
# Epoch 21 batch 1200 train loss: 0.0073 test loss: 0.0068
# Epoch 21 batch 1300 train loss: 0.0063 test loss: 0.0068
# Epoch 21 batch 1400 train loss: 0.0064 test loss: 0.0064
# Epoch 21 batch 1500 train loss: 0.0050 test loss: 0.0067
# Epoch 21 batch 1600 train loss: 0.0056 test loss: 0.0066
# Epoch 21 batch 1700 train loss: 0.0060 test loss: 0.0067
# Epoch 21 batch 1800 train loss: 0.0050 test loss: 0.0068
# Epoch 21 batch 1900 train loss: 0.0058 test loss: 0.0066
# Epoch 21 batch 2000 train loss: 0.0073 test loss: 0.0066
# Epoch 21 batch 2100 train loss: 0.0058 test loss: 0.0066
# Epoch 21 batch 2200 train loss: 0.0062 test loss: 0.0066
# Epoch 21 batch 2300 train loss: 0.0050 test loss: 0.0066
# Epoch 21 batch 2400 train loss: 0.0072 test loss: 0.0066
# Epoch 21 batch 2500 train loss: 0.0067 test loss: 0.0064
# Epoch 21 batch 2600 train loss: 0.0053 test loss: 0.0066
# Epoch 21 batch 2700 train loss: 0.0056 test loss: 0.0065
# Epoch 21 batch 2800 train loss: 0.0065 test loss: 0.0068
# Epoch 22 batch 0 train loss: 0.0064 test loss: 0.0065
# Epoch 22 batch 100 train loss: 0.0077 test loss: 0.0066
# Epoch 22 batch 200 train loss: 0.0059 test loss: 0.0067
# Epoch 22 batch 300 train loss: 0.0066 test loss: 0.0069
# Epoch 22 batch 400 train loss: 0.0063 test loss: 0.0064
# Epoch 22 batch 500 train loss: 0.0058 test loss: 0.0070
# Epoch 22 batch 600 train loss: 0.0067 test loss: 0.0067
# Epoch 22 batch 700 train loss: 0.0070 test loss: 0.0064
# Epoch 22 batch 800 train loss: 0.0058 test loss: 0.0071
# Epoch 22 batch 900 train loss: 0.0053 test loss: 0.0066
# Epoch 22 batch 1000 train loss: 0.0051 test loss: 0.0065
# Epoch 22 batch 1100 train loss: 0.0071 test loss: 0.0065
# Epoch 22 batch 1200 train loss: 0.0061 test loss: 0.0065
# Epoch 22 batch 1300 train loss: 0.0071 test loss: 0.0066
# Epoch 22 batch 1400 train loss: 0.0063 test loss: 0.0069
# Epoch 22 batch 1500 train loss: 0.0054 test loss: 0.0066
# Epoch 22 batch 1600 train loss: 0.0055 test loss: 0.0065
# Epoch 22 batch 1700 train loss: 0.0056 test loss: 0.0066
# Epoch 22 batch 1800 train loss: 0.0048 test loss: 0.0066
# Epoch 22 batch 1900 train loss: 0.0051 test loss: 0.0065
# Epoch 22 batch 2000 train loss: 0.0065 test loss: 0.0066
# Epoch 22 batch 2100 train loss: 0.0050 test loss: 0.0065
# Epoch 22 batch 2200 train loss: 0.0060 test loss: 0.0067
# Epoch 22 batch 2300 train loss: 0.0068 test loss: 0.0065
# Epoch 22 batch 2400 train loss: 0.0067 test loss: 0.0066
# Epoch 22 batch 2500 train loss: 0.0068 test loss: 0.0066
# Epoch 22 batch 2600 train loss: 0.0073 test loss: 0.0066
# Epoch 22 batch 2700 train loss: 0.0048 test loss: 0.0065
# Epoch 22 batch 2800 train loss: 0.0051 test loss: 0.0065
# Epoch 23 batch 0 train loss: 0.0060 test loss: 0.0064
# Epoch 23 batch 100 train loss: 0.0054 test loss: 0.0066
# Epoch 23 batch 200 train loss: 0.0053 test loss: 0.0069
# Epoch 23 batch 300 train loss: 0.0065 test loss: 0.0064
# Epoch 23 batch 400 train loss: 0.0056 test loss: 0.0069
# Epoch 23 batch 500 train loss: 0.0055 test loss: 0.0068
# Epoch 23 batch 600 train loss: 0.0063 test loss: 0.0064
# Epoch 23 batch 700 train loss: 0.0043 test loss: 0.0068
# Epoch 23 batch 800 train loss: 0.0067 test loss: 0.0066
# Epoch 23 batch 900 train loss: 0.0065 test loss: 0.0068
# Epoch 23 batch 1000 train loss: 0.0059 test loss: 0.0066
# Epoch 23 batch 1100 train loss: 0.0061 test loss: 0.0064
# Epoch 23 batch 1200 train loss: 0.0046 test loss: 0.0065
# Epoch 23 batch 1300 train loss: 0.0048 test loss: 0.0069
# Epoch 23 batch 1400 train loss: 0.0061 test loss: 0.0064
# Epoch 23 batch 1500 train loss: 0.0060 test loss: 0.0067
# Epoch 23 batch 1600 train loss: 0.0061 test loss: 0.0066
# Epoch 23 batch 1700 train loss: 0.0061 test loss: 0.0065
# Epoch 23 batch 1800 train loss: 0.0059 test loss: 0.0067
# Epoch 23 batch 1900 train loss: 0.0068 test loss: 0.0067
# Epoch 23 batch 2000 train loss: 0.0065 test loss: 0.0067
# Epoch 23 batch 2100 train loss: 0.0049 test loss: 0.0067
# Epoch 23 batch 2200 train loss: 0.0056 test loss: 0.0065
# Epoch 23 batch 2300 train loss: 0.0064 test loss: 0.0068
# Epoch 23 batch 2400 train loss: 0.0066 test loss: 0.0068
# Epoch 23 batch 2500 train loss: 0.0067 test loss: 0.0066
# Epoch 23 batch 2600 train loss: 0.0068 test loss: 0.0065
# Epoch 23 batch 2700 train loss: 0.0050 test loss: 0.0067
# Epoch 23 batch 2800 train loss: 0.0045 test loss: 0.0066
# Epoch 24 batch 0 train loss: 0.0066 test loss: 0.0068
# Epoch 24 batch 100 train loss: 0.0073 test loss: 0.0066
# Epoch 24 batch 200 train loss: 0.0072 test loss: 0.0068
# Epoch 24 batch 300 train loss: 0.0066 test loss: 0.0067
# Epoch 24 batch 400 train loss: 0.0062 test loss: 0.0069
# Epoch 24 batch 500 train loss: 0.0044 test loss: 0.0066
# Epoch 24 batch 600 train loss: 0.0060 test loss: 0.0066
# Epoch 24 batch 700 train loss: 0.0056 test loss: 0.0067
# Epoch 24 batch 800 train loss: 0.0057 test loss: 0.0061
# Epoch 24 batch 900 train loss: 0.0061 test loss: 0.0069
# Epoch 24 batch 1000 train loss: 0.0062 test loss: 0.0067
# Epoch 24 batch 1100 train loss: 0.0053 test loss: 0.0066
# Epoch 24 batch 1200 train loss: 0.0063 test loss: 0.0065
# Epoch 24 batch 1300 train loss: 0.0065 test loss: 0.0068
# Epoch 24 batch 1400 train loss: 0.0057 test loss: 0.0066
# Epoch 24 batch 1500 train loss: 0.0062 test loss: 0.0068
# Epoch 24 batch 1600 train loss: 0.0070 test loss: 0.0067
# Epoch 24 batch 1700 train loss: 0.0062 test loss: 0.0066
# Epoch 24 batch 1800 train loss: 0.0056 test loss: 0.0064
# Epoch 24 batch 1900 train loss: 0.0055 test loss: 0.0066
# Epoch 24 batch 2000 train loss: 0.0058 test loss: 0.0068
# Epoch 24 batch 2100 train loss: 0.0053 test loss: 0.0066
# Epoch 24 batch 2200 train loss: 0.0061 test loss: 0.0067
# Epoch 24 batch 2300 train loss: 0.0064 test loss: 0.0064
# Epoch 24 batch 2400 train loss: 0.0073 test loss: 0.0069
# Epoch 24 batch 2500 train loss: 0.0065 test loss: 0.0070
# Epoch 24 batch 2600 train loss: 0.0060 test loss: 0.0068
# Epoch 24 batch 2700 train loss: 0.0054 test loss: 0.0064
# Epoch 24 batch 2800 train loss: 0.0054 test loss: 0.0067
# Epoch 25 batch 0 train loss: 0.0066 test loss: 0.0065
# Epoch 25 batch 100 train loss: 0.0064 test loss: 0.0068
# Epoch 25 batch 200 train loss: 0.0073 test loss: 0.0063
# Epoch 25 batch 300 train loss: 0.0067 test loss: 0.0069
# Epoch 25 batch 400 train loss: 0.0072 test loss: 0.0066
# Epoch 25 batch 500 train loss: 0.0053 test loss: 0.0063
# Epoch 25 batch 600 train loss: 0.0064 test loss: 0.0067
# Epoch 25 batch 700 train loss: 0.0054 test loss: 0.0067
# Epoch 25 batch 800 train loss: 0.0060 test loss: 0.0066
# Epoch 25 batch 900 train loss: 0.0060 test loss: 0.0067
# Epoch 25 batch 1000 train loss: 0.0056 test loss: 0.0069
# Epoch 25 batch 1100 train loss: 0.0076 test loss: 0.0062
# Epoch 25 batch 1200 train loss: 0.0055 test loss: 0.0064
# Epoch 25 batch 1300 train loss: 0.0067 test loss: 0.0069
# Epoch 25 batch 1400 train loss: 0.0066 test loss: 0.0067
# Epoch 25 batch 1500 train loss: 0.0069 test loss: 0.0066
# Epoch 25 batch 1600 train loss: 0.0078 test loss: 0.0065
# Epoch 25 batch 1700 train loss: 0.0051 test loss: 0.0064
# Epoch 25 batch 1800 train loss: 0.0062 test loss: 0.0068
# Epoch 25 batch 1900 train loss: 0.0072 test loss: 0.0063
# Epoch 25 batch 2000 train loss: 0.0065 test loss: 0.0065
# Epoch 25 batch 2100 train loss: 0.0058 test loss: 0.0067
# Epoch 25 batch 2200 train loss: 0.0070 test loss: 0.0068
# Epoch 25 batch 2300 train loss: 0.0071 test loss: 0.0063
# Epoch 25 batch 2400 train loss: 0.0051 test loss: 0.0064
# Epoch 25 batch 2500 train loss: 0.0053 test loss: 0.0068
# Epoch 25 batch 2600 train loss: 0.0047 test loss: 0.0067
# Epoch 25 batch 2700 train loss: 0.0059 test loss: 0.0066
# Epoch 25 batch 2800 train loss: 0.0048 test loss: 0.0067
# Epoch 26 batch 0 train loss: 0.0059 test loss: 0.0066
# Epoch 26 batch 100 train loss: 0.0067 test loss: 0.0065
# Epoch 26 batch 200 train loss: 0.0072 test loss: 0.0070
# Epoch 26 batch 300 train loss: 0.0064 test loss: 0.0064
# Epoch 26 batch 400 train loss: 0.0066 test loss: 0.0067
# Epoch 26 batch 500 train loss: 0.0059 test loss: 0.0070
# ...
# Epoch 114 batch 2700 train loss: 0.0052 test loss: 0.0065
# Epoch 114 batch 2800 train loss: 0.0065 test loss: 0.0068
# Epoch 115 batch 0 train loss: 0.0051 test loss: 0.0064
# Epoch 115 batch 100 train loss: 0.0065 test loss: 0.0067
# Epoch 115 batch 200 train loss: 0.0066 test loss: 0.0068
# Epoch 115 batch 300 train loss: 0.0065 test loss: 0.0068
# Epoch 115 batch 400 train loss: 0.0068 test loss: 0.0066
# Epoch 115 batch 500 train loss: 0.0052 test loss: 0.0067
# Epoch 115 batch 600 train loss: 0.0059 test loss: 0.0067
# Epoch 115 batch 700 train loss: 0.0059 test loss: 0.0066
# Epoch 115 batch 800 train loss: 0.0056 test loss: 0.0068
# Epoch 115 batch 900 train loss: 0.0068 test loss: 0.0069
# Epoch 115 batch 1000 train loss: 0.0058 test loss: 0.0068
# Epoch 115 batch 1100 train loss: 0.0061 test loss: 0.0064
# Epoch 115 batch 1200 train loss: 0.0061 test loss: 0.0063
# Epoch 115 batch 1300 train loss: 0.0067 test loss: 0.0068
# Epoch 115 batch 1400 train loss: 0.0065 test loss: 0.0071
# Epoch 115 batch 1500 train loss: 0.0064 test loss: 0.0066
# Epoch 115 batch 1600 train loss: 0.0060 test loss: 0.0067
# Epoch 115 batch 1700 train loss: 0.0072 test loss: 0.0066
# Epoch 115 batch 1800 train loss: 0.0052 test loss: 0.0066
# Epoch 115 batch 1900 train loss: 0.0055 test loss: 0.0064
# Epoch 115 batch 2000 train loss: 0.0075 test loss: 0.0069
# Epoch 115 batch 2100 train loss: 0.0054 test loss: 0.0065
# Epoch 115 batch 2200 train loss: 0.0072 test loss: 0.0067
# Epoch 115 batch 2300 train loss: 0.0057 test loss: 0.0067
# Epoch 115 batch 2400 train loss: 0.0072 test loss: 0.0064
# Epoch 115 batch 2500 train loss: 0.0058 test loss: 0.0064
# Epoch 115 batch 2600 train loss: 0.0056 test loss: 0.0064
# Epoch 115 batch 2700 train loss: 0.0060 test loss: 0.0066
# Epoch 115 batch 2800 train loss: 0.0047 test loss: 0.0066
# Epoch 116 batch 0 train loss: 0.0056 test loss: 0.0065
# Epoch 116 batch 100 train loss: 0.0067 test loss: 0.0065
# Epoch 116 batch 200 train loss: 0.0062 test loss: 0.0067
# Epoch 116 batch 300 train loss: 0.0056 test loss: 0.0068
# Epoch 116 batch 400 train loss: 0.0070 test loss: 0.0071
# Epoch 116 batch 500 train loss: 0.0075 test loss: 0.0070
# Epoch 116 batch 600 train loss: 0.0056 test loss: 0.0066
# Epoch 116 batch 700 train loss: 0.0060 test loss: 0.0067
# Epoch 116 batch 800 train loss: 0.0062 test loss: 0.0068
# Epoch 116 batch 900 train loss: 0.0052 test loss: 0.0065
# Epoch 116 batch 1000 train loss: 0.0060 test loss: 0.0067
# Epoch 116 batch 1100 train loss: 0.0064 test loss: 0.0063
# Epoch 116 batch 1200 train loss: 0.0061 test loss: 0.0067
# Epoch 116 batch 1300 train loss: 0.0077 test loss: 0.0065
# Epoch 116 batch 1400 train loss: 0.0059 test loss: 0.0068
# Epoch 116 batch 1500 train loss: 0.0056 test loss: 0.0064
# Epoch 116 batch 1600 train loss: 0.0070 test loss: 0.0064
# Epoch 116 batch 1700 train loss: 0.0058 test loss: 0.0064
# Epoch 116 batch 1800 train loss: 0.0067 test loss: 0.0066
# Epoch 116 batch 1900 train loss: 0.0049 test loss: 0.0067
# Epoch 116 batch 2000 train loss: 0.0057 test loss: 0.0067
# Epoch 116 batch 2100 train loss: 0.0053 test loss: 0.0067
# Epoch 116 batch 2200 train loss: 0.0060 test loss: 0.0067
# Epoch 116 batch 2300 train loss: 0.0056 test loss: 0.0068
# Epoch 116 batch 2400 train loss: 0.0056 test loss: 0.0065
# Epoch 116 batch 2500 train loss: 0.0062 test loss: 0.0066
# Epoch 116 batch 2600 train loss: 0.0075 test loss: 0.0066
# Epoch 116 batch 2700 train loss: 0.0061 test loss: 0.0066
# Epoch 116 batch 2800 train loss: 0.0063 test loss: 0.0068
# Epoch 117 batch 0 train loss: 0.0060 test loss: 0.0068
# Epoch 117 batch 100 train loss: 0.0060 test loss: 0.0065
# Epoch 117 batch 200 train loss: 0.0055 test loss: 0.0064
# Epoch 117 batch 300 train loss: 0.0060 test loss: 0.0067
# Epoch 117 batch 400 train loss: 0.0060 test loss: 0.0065
# Epoch 117 batch 500 train loss: 0.0061 test loss: 0.0068
# Epoch 117 batch 600 train loss: 0.0067 test loss: 0.0066
# Epoch 117 batch 700 train loss: 0.0060 test loss: 0.0066
# Epoch 117 batch 800 train loss: 0.0060 test loss: 0.0064
# Epoch 117 batch 900 train loss: 0.0054 test loss: 0.0067
# Epoch 117 batch 1000 train loss: 0.0060 test loss: 0.0064
# Epoch 117 batch 1100 train loss: 0.0069 test loss: 0.0066
# Epoch 117 batch 1200 train loss: 0.0060 test loss: 0.0063
# Epoch 117 batch 1300 train loss: 0.0060 test loss: 0.0066
# Epoch 117 batch 1400 train loss: 0.0056 test loss: 0.0069
# Epoch 117 batch 1500 train loss: 0.0056 test loss: 0.0067
# Epoch 117 batch 1600 train loss: 0.0054 test loss: 0.0067
# Epoch 117 batch 1700 train loss: 0.0065 test loss: 0.0068
# Epoch 117 batch 1800 train loss: 0.0057 test loss: 0.0070
# Epoch 117 batch 1900 train loss: 0.0063 test loss: 0.0063
# Epoch 117 batch 2000 train loss: 0.0058 test loss: 0.0064
# Epoch 117 batch 2100 train loss: 0.0052 test loss: 0.0062
# Epoch 117 batch 2200 train loss: 0.0084 test loss: 0.0064
# Epoch 117 batch 2300 train loss: 0.0066 test loss: 0.0068
# Epoch 117 batch 2400 train loss: 0.0065 test loss: 0.0065
# Epoch 117 batch 2500 train loss: 0.0049 test loss: 0.0066
# Epoch 117 batch 2600 train loss: 0.0058 test loss: 0.0066
# Epoch 117 batch 2700 train loss: 0.0063 test loss: 0.0063
# Epoch 117 batch 2800 train loss: 0.0051 test loss: 0.0069
# Epoch 118 batch 0 train loss: 0.0064 test loss: 0.0067
# Epoch 118 batch 100 train loss: 0.0055 test loss: 0.0065
# Epoch 118 batch 200 train loss: 0.0070 test loss: 0.0067
# Epoch 118 batch 300 train loss: 0.0064 test loss: 0.0066
# Epoch 118 batch 400 train loss: 0.0071 test loss: 0.0063
# Epoch 118 batch 500 train loss: 0.0062 test loss: 0.0068
# Epoch 118 batch 600 train loss: 0.0061 test loss: 0.0065
# Epoch 118 batch 700 train loss: 0.0053 test loss: 0.0065
# Epoch 118 batch 800 train loss: 0.0068 test loss: 0.0065
# Epoch 118 batch 900 train loss: 0.0071 test loss: 0.0065
# Epoch 118 batch 1000 train loss: 0.0060 test loss: 0.0067
# Epoch 118 batch 1100 train loss: 0.0071 test loss: 0.0068
# Epoch 118 batch 1200 train loss: 0.0050 test loss: 0.0065
# Epoch 118 batch 1300 train loss: 0.0054 test loss: 0.0065
# Epoch 118 batch 1400 train loss: 0.0067 test loss: 0.0068
# Epoch 118 batch 1500 train loss: 0.0062 test loss: 0.0066
# Epoch 118 batch 1600 train loss: 0.0062 test loss: 0.0066
# Epoch 118 batch 1700 train loss: 0.0062 test loss: 0.0065
# Epoch 118 batch 1800 train loss: 0.0052 test loss: 0.0068
# Epoch 118 batch 1900 train loss: 0.0061 test loss: 0.0063
# Epoch 118 batch 2000 train loss: 0.0066 test loss: 0.0067
# Epoch 118 batch 2100 train loss: 0.0054 test loss: 0.0066
# Epoch 118 batch 2200 train loss: 0.0057 test loss: 0.0069
# Epoch 118 batch 2300 train loss: 0.0070 test loss: 0.0069
# Epoch 118 batch 2400 train loss: 0.0066 test loss: 0.0064
# Epoch 118 batch 2500 train loss: 0.0065 test loss: 0.0064
# Epoch 118 batch 2600 train loss: 0.0062 test loss: 0.0066
# Epoch 118 batch 2700 train loss: 0.0061 test loss: 0.0065
# Epoch 118 batch 2800 train loss: 0.0056 test loss: 0.0066
# Epoch 119 batch 0 train loss: 0.0058 test loss: 0.0067
# Epoch 119 batch 100 train loss: 0.0062 test loss: 0.0062
# Epoch 119 batch 200 train loss: 0.0057 test loss: 0.0067
# Epoch 119 batch 300 train loss: 0.0057 test loss: 0.0064
# Epoch 119 batch 400 train loss: 0.0056 test loss: 0.0066
# Epoch 119 batch 500 train loss: 0.0070 test loss: 0.0064
# Epoch 119 batch 600 train loss: 0.0065 test loss: 0.0064
# Epoch 119 batch 700 train loss: 0.0064 test loss: 0.0067
# Epoch 119 batch 800 train loss: 0.0056 test loss: 0.0067
# Epoch 119 batch 900 train loss: 0.0054 test loss: 0.0068
# Epoch 119 batch 1000 train loss: 0.0051 test loss: 0.0065
# Epoch 119 batch 1100 train loss: 0.0053 test loss: 0.0065
# Epoch 119 batch 1200 train loss: 0.0060 test loss: 0.0066
# Epoch 119 batch 1300 train loss: 0.0064 test loss: 0.0070
# Epoch 119 batch 1400 train loss: 0.0056 test loss: 0.0067
# Epoch 119 batch 1500 train loss: 0.0056 test loss: 0.0063
# Epoch 119 batch 1600 train loss: 0.0060 test loss: 0.0069
# Epoch 119 batch 1700 train loss: 0.0072 test loss: 0.0063
# Epoch 119 batch 1800 train loss: 0.0071 test loss: 0.0061
# Epoch 119 batch 1900 train loss: 0.0068 test loss: 0.0066
# Epoch 119 batch 2000 train loss: 0.0065 test loss: 0.0063
# Epoch 119 batch 2100 train loss: 0.0054 test loss: 0.0066
# Epoch 119 batch 2200 train loss: 0.0058 test loss: 0.0065
# Epoch 119 batch 2300 train loss: 0.0065 test loss: 0.0067
# Epoch 119 batch 2400 train loss: 0.0067 test loss: 0.0065
# Epoch 119 batch 2500 train loss: 0.0047 test loss: 0.0068
# Epoch 119 batch 2600 train loss: 0.0064 test loss: 0.0067
# Epoch 119 batch 2700 train loss: 0.0073 test loss: 0.0067
# Epoch 119 batch 2800 train loss: 0.0068 test loss: 0.0066
# Epoch 120 batch 0 train loss: 0.0059 test loss: 0.0067
# Epoch 120 batch 100 train loss: 0.0057 test loss: 0.0066
# Epoch 120 batch 200 train loss: 0.0064 test loss: 0.0071
# Epoch 120 batch 300 train loss: 0.0057 test loss: 0.0067
# Epoch 120 batch 400 train loss: 0.0050 test loss: 0.0068
# Epoch 120 batch 500 train loss: 0.0058 test loss: 0.0065
# Epoch 120 batch 600 train loss: 0.0062 test loss: 0.0068
# Epoch 120 batch 700 train loss: 0.0056 test loss: 0.0069
# Epoch 120 batch 800 train loss: 0.0064 test loss: 0.0065
# Epoch 120 batch 900 train loss: 0.0063 test loss: 0.0070
# Epoch 120 batch 1000 train loss: 0.0063 test loss: 0.0065
# Epoch 120 batch 1100 train loss: 0.0069 test loss: 0.0063
# Epoch 120 batch 1200 train loss: 0.0053 test loss: 0.0067
# Epoch 120 batch 1300 train loss: 0.0053 test loss: 0.0067
# Epoch 120 batch 1400 train loss: 0.0065 test loss: 0.0064
# Epoch 120 batch 1500 train loss: 0.0069 test loss: 0.0066
# Epoch 120 batch 1600 train loss: 0.0052 test loss: 0.0066
# Epoch 120 batch 1700 train loss: 0.0068 test loss: 0.0061
# Epoch 120 batch 1800 train loss: 0.0060 test loss: 0.0067
# Epoch 120 batch 1900 train loss: 0.0070 test loss: 0.0066
# Epoch 120 batch 2000 train loss: 0.0053 test loss: 0.0064
# Epoch 120 batch 2100 train loss: 0.0058 test loss: 0.0067
# Epoch 120 batch 2200 train loss: 0.0060 test loss: 0.0066
# Epoch 120 batch 2300 train loss: 0.0057 test loss: 0.0068
# Epoch 120 batch 2400 train loss: 0.0058 test loss: 0.0067
# Epoch 120 batch 2500 train loss: 0.0066 test loss: 0.0065
# Epoch 120 batch 2600 train loss: 0.0049 test loss: 0.0064
# Epoch 120 batch 2700 train loss: 0.0058 test loss: 0.0067
# Epoch 120 batch 2800 train loss: 0.0062 test loss: 0.0066
# Epoch 121 batch 0 train loss: 0.0058 test loss: 0.0065
# Epoch 121 batch 100 train loss: 0.0058 test loss: 0.0064
# Epoch 121 batch 200 train loss: 0.0059 test loss: 0.0067
# Epoch 121 batch 300 train loss: 0.0061 test loss: 0.0069
# Epoch 121 batch 400 train loss: 0.0060 test loss: 0.0067
# Epoch 121 batch 500 train loss: 0.0066 test loss: 0.0068
# Epoch 121 batch 600 train loss: 0.0055 test loss: 0.0063
# Epoch 121 batch 700 train loss: 0.0060 test loss: 0.0065
# Epoch 121 batch 800 train loss: 0.0065 test loss: 0.0065
# Epoch 121 batch 900 train loss: 0.0070 test loss: 0.0070
# Epoch 121 batch 1000 train loss: 0.0064 test loss: 0.0063
# Epoch 121 batch 1100 train loss: 0.0068 test loss: 0.0065
# Epoch 121 batch 1200 train loss: 0.0055 test loss: 0.0068
# Epoch 121 batch 1300 train loss: 0.0049 test loss: 0.0068
# Epoch 121 batch 1400 train loss: 0.0088 test loss: 0.0067
# Epoch 121 batch 1500 train loss: 0.0067 test loss: 0.0064
# Epoch 121 batch 1600 train loss: 0.0060 test loss: 0.0066
# Epoch 121 batch 1700 train loss: 0.0058 test loss: 0.0064
# Epoch 121 batch 1800 train loss: 0.0052 test loss: 0.0065
# Epoch 121 batch 1900 train loss: 0.0060 test loss: 0.0067
# Epoch 121 batch 2000 train loss: 0.0062 test loss: 0.0068
# Epoch 121 batch 2100 train loss: 0.0058 test loss: 0.0065
# Epoch 121 batch 2200 train loss: 0.0066 test loss: 0.0066
# Epoch 121 batch 2300 train loss: 0.0062 test loss: 0.0066
# Epoch 121 batch 2400 train loss: 0.0046 test loss: 0.0067
# Epoch 121 batch 2500 train loss: 0.0054 test loss: 0.0063
# Epoch 121 batch 2600 train loss: 0.0070 test loss: 0.0066
# Epoch 121 batch 2700 train loss: 0.0066 test loss: 0.0064
# Epoch 121 batch 2800 train loss: 0.0071 test loss: 0.0069
# Epoch 122 batch 0 train loss: 0.0065 test loss: 0.0066
# Epoch 122 batch 100 train loss: 0.0066 test loss: 0.0064
# Epoch 122 batch 200 train loss: 0.0060 test loss: 0.0068
# Epoch 122 batch 300 train loss: 0.0062 test loss: 0.0065
# Epoch 122 batch 400 train loss: 0.0069 test loss: 0.0067
# Epoch 122 batch 500 train loss: 0.0063 test loss: 0.0063
# Epoch 122 batch 600 train loss: 0.0054 test loss: 0.0066
# Epoch 122 batch 700 train loss: 0.0047 test loss: 0.0067
# Epoch 122 batch 800 train loss: 0.0070 test loss: 0.0064
# Epoch 122 batch 900 train loss: 0.0051 test loss: 0.0065
# Epoch 122 batch 1000 train loss: 0.0061 test loss: 0.0064
# Epoch 122 batch 1100 train loss: 0.0072 test loss: 0.0066
# Epoch 122 batch 1200 train loss: 0.0068 test loss: 0.0062
# Epoch 122 batch 1300 train loss: 0.0070 test loss: 0.0065
# Epoch 122 batch 1400 train loss: 0.0055 test loss: 0.0069
# Epoch 122 batch 1500 train loss: 0.0060 test loss: 0.0067
# Epoch 122 batch 1600 train loss: 0.0055 test loss: 0.0066
# Epoch 122 batch 1700 train loss: 0.0056 test loss: 0.0067
# Epoch 122 batch 1800 train loss: 0.0062 test loss: 0.0065
# Epoch 122 batch 1900 train loss: 0.0060 test loss: 0.0065
# Epoch 122 batch 2000 train loss: 0.0068 test loss: 0.0068
# Epoch 122 batch 2100 train loss: 0.0062 test loss: 0.0066
# Epoch 122 batch 2200 train loss: 0.0074 test loss: 0.0068
# Epoch 122 batch 2300 train loss: 0.0053 test loss: 0.0064
# Epoch 122 batch 2400 train loss: 0.0061 test loss: 0.0067
# Epoch 122 batch 2500 train loss: 0.0062 test loss: 0.0066
# Epoch 122 batch 2600 train loss: 0.0073 test loss: 0.0066
# Epoch 122 batch 2700 train loss: 0.0057 test loss: 0.0065
# Epoch 122 batch 2800 train loss: 0.0060 test loss: 0.0065
# Epoch 123 batch 0 train loss: 0.0045 test loss: 0.0066
# Epoch 123 batch 100 train loss: 0.0058 test loss: 0.0064
# Epoch 123 batch 200 train loss: 0.0048 test loss: 0.0068
# Epoch 123 batch 300 train loss: 0.0063 test loss: 0.0066
# Epoch 123 batch 400 train loss: 0.0060 test loss: 0.0065
# Epoch 123 batch 500 train loss: 0.0060 test loss: 0.0065
# Epoch 123 batch 600 train loss: 0.0069 test loss: 0.0067
# Epoch 123 batch 700 train loss: 0.0048 test loss: 0.0064
# Epoch 123 batch 800 train loss: 0.0060 test loss: 0.0065
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-671cc88f93bc> in <module>()
#       5             for step, (inp, tar) in enumerate(train_dataset):
#       6                 train(loss_function, bilstm_model, opt, inp, tar)
# ----> 7                 loss_values = loss_function(bilstm_model, inp, tar)
#       8                 tf.summary.scalar('loss', loss_values, step=step)
#       9
#
# <ipython-input-18-11bb93462f56> in loss_function(model, inp, tar)
#       3 def loss_function(model, inp, tar): #RNN specialized
#       4
# ----> 5     masked_real = tar * (1 - inp[..., 5:10])
#       6     masked_pred = model(inp) * (1 - inp[..., 5:10])
#       7
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     896         ellipsis_mask=ellipsis_mask,
#     897         var=var,
# --> 898         name=name)
#     899
#     900
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1062       ellipsis_mask=ellipsis_mask,
#    1063       new_axis_mask=new_axis_mask,
# -> 1064       shrink_axis_mask=shrink_axis_mask)
#    1065
#    1066   parent_name = name
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#    9499         tld.op_callbacks, input, begin, end, strides, "begin_mask",
#    9500         begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
# -> 9501         "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#    9502       return _result
#    9503     except _core._FallbackException:
#
# KeyboardInterrupt:

# %% [markdown]
# # Model evaluation

# %%
i = -1
if ckpt_manager.checkpoints:
    ckpt.restore(ckpt_manager.checkpoints[i])
    print ('Checkpoint ' + ckpt_manager.checkpoints[i][-2:] +' restored!!')
# Out:
# Checkpoint 37 restored!!

# %%
bilstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
test_loss = bilstm_model.evaluate(test_dataset)
# Out:
# 2409/2409 [==============================] - 34s 14ms/step - loss: 0.1047

# %%
pred_result = bilstm_model.predict(test_dataset)

# %%
print(pred_result.shape)
print(test_label.shape)
# Out:
# (77063, 100, 5)
# (77063, 100, 5)

# %%
masking = test_input[..., 5:10]

# %%
masked_pred = np.ma.array(pred_result, mask=masking)
masked_label = np.ma.array(test_label, mask=masking)

# %%
for _ in range(test_label.shape[-1]):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_pred[..., _].reshape(-1))))
# Out:
# 0.21644133
# 0.4653137
# 0.3820055
# 0.27388903
# 0.19828805

# %%
r2 = RSquare()
for _ in range(test_label.shape[-1]):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_pred[..., _][~masked_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.2101962, shape=(), dtype=float32)
# tf.Tensor(0.23918527, shape=(), dtype=float32)
# tf.Tensor(0.028532088, shape=(), dtype=float32)
# tf.Tensor(0.12618464, shape=(), dtype=float32)
# WARNING:tensorflow:5 out of the last 5 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7fc804687048>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.15877914, shape=(), dtype=float32)

# %%
plot_label = ((MAXS-MINS)*masked_label + MINS).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_pred = ((MAXS-MINS)*masked_pred + MINS).reshape(-1, 1)
plot_pred = plot_pred[~plot_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_pred)))
# Out:
# tf.Tensor(0.7142039, shape=(), dtype=float32)
# 119.66149535950201

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (3):

        NUMBERS = np.arange(1, pred_result.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*8, (6/2.54)*8))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=0.8) #measured
            expect1 = plt.plot(x_t, masked_pred[NUMBER, :, i], 'o', c=cmap[5], alpha=0.4) #estimated
            expect1 = plt.plot(x_t, pred_result[NUMBER, :, i], c=cmap[2], alpha=0.4) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1

# %% [markdown]
# # Saving data

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5])
plot_label.fill_value = np.nan
plot_pred = ((MAXS[:5]-MINS[:5])*masked_pred[..., :5] + MINS[:5])
plot_pred.fill_value = np.nan

# %%
f = open('./results/RNN_%d.npz' % SCREEN_SIZE, 'wb')
np.savez(f,
         test_label = plot_label.filled(),
         test_pred = plot_pred.filled()
        )
f.close()
