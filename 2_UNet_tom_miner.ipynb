# %%
import time
import os

import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)

from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras import *
tf.__version__
# Out:
# '2.1.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %% [markdown]
# # Model training

# %% [markdown]
# ## hyperparameters

# %%
BEST_PATH = './checkpoints/UNet_tom_32'
DISP_STEPS = 100
TRAINING_EPOCHS = 500
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# %% [markdown]
# ## data loading

# %%
l = np.load('./data/tom_dataset.npz')
raw_input = l['raw_input']
raw_label = l['raw_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']

SCREEN_SIZE = l['SCREEN_SIZE']

# %%
print(raw_input.shape)
print(raw_label.shape)
# Out:
# (78509, 10, 10, 4)
# (78509, 10, 10, 1)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (47088, 10, 10, 4)
# (47088, 10, 10, 1)

# %%
raw_input = raw_input.astype(np.float32)
raw_label = raw_label.astype(np.float32)
test_input = test_input.astype(np.float32)
test_label = test_label.astype(np.float32)

# %%
num_train = int(raw_input.shape[0]*.7)
raw_input, raw_label = shuffle(raw_input, raw_label, random_state=4574)
train_input, train_label = raw_input[:num_train, ...], raw_label[:num_train, ...]
val_input, val_label = raw_input[num_train:, ...], raw_label[num_train:, ...]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((test_input, test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
class ConvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, dropout_rate):
        super(ConvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.dropout_rate = dropout_rate
        
        self.conv1 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch1 = layers.BatchNormalization()
        self.drop = layers.Dropout(self.dropout_rate)
        self.conv2 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch2 = layers.BatchNormalization()
        
    def call(self, inp):
        
        inp = self.batch1(self.conv1(inp))
        inp = self.drop(inp)
        inp = self.batch2(self.conv2(inp))
        
        return inp

# %%
class DeconvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, strides):
        super(DeconvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        
        self.deconv1 = layers.Conv2DTranspose(self.filters, self.kernel_size, strides=self.strides, padding='same')
        
    def call(self, inp):
        
        inp = self.deconv1(inp)
        
        return inp

# %%
class UNet(Model):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.conv_block1 = ConvBlock(32, (2, 2), 0.1)
        self.pool1 = layers.MaxPooling2D()
        
        self.conv_block2 = ConvBlock(64, (2, 2), 0.2)
        self.pool2 = layers.MaxPooling2D()
        
        self.conv_block3 = ConvBlock(128, (2, 2), 0.2)
        
        self.deconv_block1 = DeconvBlock(64, (2, 2), (2, 2))
        self.padding = layers.ZeroPadding2D(((1, 0), (0, 1)))
        self.conv_block4 = ConvBlock(63, (2, 2), 0.2)
        
        self.deconv_block2 = DeconvBlock(32, (2, 2), (2, 2))
        self.conv_block5 = ConvBlock(32, (2, 2), 0.1)
        
        self.output_conv = layers.Conv2D(1, (1, 1), activation='sigmoid')
        
    def call(self, inp):
        
        conv1 = self.conv_block1(inp)
        pooled1 = self.pool1(conv1)
        conv2 = self.conv_block2(pooled1)
        pooled2 = self.pool2(conv2)
        
        bottom = self.conv_block3(pooled2)
        
        deconv1 = self.padding(self.deconv_block1(bottom))
        deconv1 = layers.concatenate([deconv1, conv2])
        deconv1 = self.conv_block4(deconv1)
        deconv2 = self.deconv_block2(deconv1)
        deconv2 = layers.concatenate([deconv2, conv1])
        deconv2 = self.conv_block5(deconv2)
        
        return self.output_conv(deconv2)

# %%
#loss inputs should be masked.
loss_object = tf.keras.losses.MeanSquaredError()
def loss_function(model, inp, tar):
    
    masked_real = tar * (1 - inp[..., 1:2])
    masked_pred = model(inp) * (1 - inp[..., 1:2])
    
    return loss_object(masked_real, masked_pred)

# %%
unet_model = UNet()
opt = tf.optimizers.Adam(learning_rate=LEARNING_RATE)

# %%
@tf.function
def train(loss_function, model, opt, inp, tar):
    with tf.GradientTape() as tape:
        gradients = tape.gradient(loss_function(model, inp, tar), model.trainable_variables)
        gradient_variables = zip(gradients, model.trainable_variables)
        opt.apply_gradients(gradient_variables)

# %%
checkpoint_path = BEST_PATH

ckpt = tf.train.Checkpoint(unet_model=unet_model,
                           opt=opt)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=10)

# %%
writer = tf.summary.create_file_writer('tmp')

# %%
prev_test_loss = 100.0
with writer.as_default():
    with tf.summary.record_if(True):
        for epoch in range(TRAINING_EPOCHS):
            for step, (inp, tar) in enumerate(train_dataset):
                train(loss_function, unet_model, opt, inp, tar)
                loss_values = loss_function(unet_model, inp, tar)
                tf.summary.scalar('loss', loss_values, step=step)
                
                if step % DISP_STEPS == 0:
                    test_loss = 0
                    for step_, (inp_, tar_) in enumerate(test_dataset):
                        test_loss += loss_function(unet_model, inp_, tar_)
                        
                        if step_ > DISP_STEPS:
                            test_loss /= DISP_STEPS
                            break
                    if test_loss.numpy() < prev_test_loss:
                        ckpt_save_path = ckpt_manager.save()
                        prev_test_loss = test_loss.numpy()
                        print('Saving checkpoint at {}'.format(ckpt_save_path))
                    print('Epoch {} batch {} train loss: {:.4f} test loss: {:.4f}'
                          .format(epoch, step, loss_values.numpy(), test_loss.numpy()))
# Out:
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-1
# Epoch 0 batch 0 train loss: 0.0424 test loss: 0.0475
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-2
# Epoch 0 batch 100 train loss: 0.0056 test loss: 0.0058
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-3
# Epoch 0 batch 200 train loss: 0.0027 test loss: 0.0027
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-4
# Epoch 0 batch 300 train loss: 0.0021 test loss: 0.0023
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-5
# Epoch 0 batch 400 train loss: 0.0024 test loss: 0.0019
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-6
# Epoch 0 batch 500 train loss: 0.0017 test loss: 0.0015
# Epoch 0 batch 600 train loss: 0.0017 test loss: 0.0016
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-7
# Epoch 0 batch 700 train loss: 0.0014 test loss: 0.0012
# Epoch 0 batch 800 train loss: 0.0010 test loss: 0.0013
# Epoch 0 batch 900 train loss: 0.0015 test loss: 0.0012
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-8
# Epoch 0 batch 1000 train loss: 0.0009 test loss: 0.0011
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-9
# Epoch 0 batch 1100 train loss: 0.0013 test loss: 0.0010
# Epoch 0 batch 1200 train loss: 0.0013 test loss: 0.0011
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-10
# Epoch 0 batch 1300 train loss: 0.0010 test loss: 0.0009
# Epoch 0 batch 1400 train loss: 0.0009 test loss: 0.0012
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-11
# Epoch 0 batch 1500 train loss: 0.0008 test loss: 0.0009
# Epoch 0 batch 1600 train loss: 0.0010 test loss: 0.0009
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-12
# Epoch 0 batch 1700 train loss: 0.0009 test loss: 0.0007
# Epoch 1 batch 0 train loss: 0.0011 test loss: 0.0008
# Epoch 1 batch 100 train loss: 0.0007 test loss: 0.0008
# Epoch 1 batch 200 train loss: 0.0009 test loss: 0.0008
# Epoch 1 batch 300 train loss: 0.0007 test loss: 0.0009
# Epoch 1 batch 400 train loss: 0.0007 test loss: 0.0009
# Epoch 1 batch 500 train loss: 0.0008 test loss: 0.0008
# Epoch 1 batch 600 train loss: 0.0011 test loss: 0.0008
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-13
# Epoch 1 batch 700 train loss: 0.0009 test loss: 0.0007
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-14
# Epoch 1 batch 800 train loss: 0.0010 test loss: 0.0007
# Epoch 1 batch 900 train loss: 0.0009 test loss: 0.0007
# Epoch 1 batch 1000 train loss: 0.0006 test loss: 0.0008
# Epoch 1 batch 1100 train loss: 0.0009 test loss: 0.0007
# Epoch 1 batch 1200 train loss: 0.0008 test loss: 0.0008
# Epoch 1 batch 1300 train loss: 0.0008 test loss: 0.0010
# Epoch 1 batch 1400 train loss: 0.0008 test loss: 0.0007
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-15
# Epoch 1 batch 1500 train loss: 0.0007 test loss: 0.0007
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-16
# Epoch 1 batch 1600 train loss: 0.0010 test loss: 0.0007
# Epoch 1 batch 1700 train loss: 0.0008 test loss: 0.0007
# Epoch 2 batch 0 train loss: 0.0007 test loss: 0.0007
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-17
# Epoch 2 batch 100 train loss: 0.0007 test loss: 0.0006
# Epoch 2 batch 200 train loss: 0.0007 test loss: 0.0006
# Epoch 2 batch 300 train loss: 0.0011 test loss: 0.0007
# Epoch 2 batch 400 train loss: 0.0006 test loss: 0.0008
# Epoch 2 batch 500 train loss: 0.0008 test loss: 0.0006
# Epoch 2 batch 600 train loss: 0.0007 test loss: 0.0007
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-18
# Epoch 2 batch 700 train loss: 0.0006 test loss: 0.0006
# Epoch 2 batch 800 train loss: 0.0007 test loss: 0.0006
# Epoch 2 batch 900 train loss: 0.0007 test loss: 0.0006
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-19
# Epoch 2 batch 1000 train loss: 0.0008 test loss: 0.0006
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-20
# Epoch 2 batch 1100 train loss: 0.0004 test loss: 0.0006
# Epoch 2 batch 1200 train loss: 0.0007 test loss: 0.0006
# Epoch 2 batch 1300 train loss: 0.0005 test loss: 0.0006
# Epoch 2 batch 1400 train loss: 0.0009 test loss: 0.0006
# Epoch 2 batch 1500 train loss: 0.0006 test loss: 0.0006
# Epoch 2 batch 1600 train loss: 0.0005 test loss: 0.0006
# Epoch 2 batch 1700 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 0 train loss: 0.0005 test loss: 0.0006
# Epoch 3 batch 100 train loss: 0.0004 test loss: 0.0006
# Epoch 3 batch 200 train loss: 0.0009 test loss: 0.0007
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-21
# Epoch 3 batch 300 train loss: 0.0007 test loss: 0.0005
# Epoch 3 batch 400 train loss: 0.0007 test loss: 0.0005
# Epoch 3 batch 500 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 600 train loss: 0.0007 test loss: 0.0006
# Epoch 3 batch 700 train loss: 0.0005 test loss: 0.0006
# Epoch 3 batch 800 train loss: 0.0005 test loss: 0.0006
# Epoch 3 batch 900 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 1000 train loss: 0.0005 test loss: 0.0006
# Epoch 3 batch 1100 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 1200 train loss: 0.0005 test loss: 0.0005
# Epoch 3 batch 1300 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 1400 train loss: 0.0005 test loss: 0.0006
# Epoch 3 batch 1500 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 1600 train loss: 0.0006 test loss: 0.0006
# Epoch 3 batch 1700 train loss: 0.0006 test loss: 0.0006
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-22
# Epoch 4 batch 0 train loss: 0.0006 test loss: 0.0005
# Epoch 4 batch 100 train loss: 0.0009 test loss: 0.0005
# Epoch 4 batch 200 train loss: 0.0004 test loss: 0.0006
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-23
# Epoch 4 batch 300 train loss: 0.0006 test loss: 0.0005
# Epoch 4 batch 400 train loss: 0.0006 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-24
# Epoch 4 batch 500 train loss: 0.0007 test loss: 0.0005
# Epoch 4 batch 600 train loss: 0.0006 test loss: 0.0005
# Epoch 4 batch 700 train loss: 0.0006 test loss: 0.0005
# Epoch 4 batch 800 train loss: 0.0004 test loss: 0.0006
# Epoch 4 batch 900 train loss: 0.0005 test loss: 0.0006
# Epoch 4 batch 1000 train loss: 0.0005 test loss: 0.0005
# Epoch 4 batch 1100 train loss: 0.0010 test loss: 0.0005
# Epoch 4 batch 1200 train loss: 0.0006 test loss: 0.0005
# Epoch 4 batch 1300 train loss: 0.0003 test loss: 0.0005
# Epoch 4 batch 1400 train loss: 0.0005 test loss: 0.0006
# Epoch 4 batch 1500 train loss: 0.0009 test loss: 0.0006
# Epoch 4 batch 1600 train loss: 0.0007 test loss: 0.0005
# Epoch 4 batch 1700 train loss: 0.0006 test loss: 0.0005
# Epoch 5 batch 0 train loss: 0.0004 test loss: 0.0005
# Epoch 5 batch 100 train loss: 0.0007 test loss: 0.0005
# Epoch 5 batch 200 train loss: 0.0004 test loss: 0.0006
# Epoch 5 batch 300 train loss: 0.0007 test loss: 0.0005
# Epoch 5 batch 400 train loss: 0.0004 test loss: 0.0005
# Epoch 5 batch 500 train loss: 0.0006 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-25
# Epoch 5 batch 600 train loss: 0.0005 test loss: 0.0005
# Epoch 5 batch 700 train loss: 0.0011 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-26
# Epoch 5 batch 800 train loss: 0.0004 test loss: 0.0005
# Epoch 5 batch 900 train loss: 0.0004 test loss: 0.0005
# Epoch 5 batch 1000 train loss: 0.0005 test loss: 0.0005
# Epoch 5 batch 1100 train loss: 0.0005 test loss: 0.0005
# Epoch 5 batch 1200 train loss: 0.0005 test loss: 0.0005
# Epoch 5 batch 1300 train loss: 0.0006 test loss: 0.0005
# Epoch 5 batch 1400 train loss: 0.0005 test loss: 0.0005
# Epoch 5 batch 1500 train loss: 0.0003 test loss: 0.0005
# Epoch 5 batch 1600 train loss: 0.0005 test loss: 0.0005
# Epoch 5 batch 1700 train loss: 0.0004 test loss: 0.0005
# Epoch 6 batch 0 train loss: 0.0006 test loss: 0.0005
# Epoch 6 batch 100 train loss: 0.0007 test loss: 0.0005
# Epoch 6 batch 200 train loss: 0.0006 test loss: 0.0005
# Epoch 6 batch 300 train loss: 0.0004 test loss: 0.0005
# Epoch 6 batch 400 train loss: 0.0004 test loss: 0.0005
# Epoch 6 batch 500 train loss: 0.0004 test loss: 0.0005
# Epoch 6 batch 600 train loss: 0.0006 test loss: 0.0005
# Epoch 6 batch 700 train loss: 0.0007 test loss: 0.0005
# Epoch 6 batch 800 train loss: 0.0004 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-27
# Epoch 6 batch 900 train loss: 0.0003 test loss: 0.0005
# Epoch 6 batch 1000 train loss: 0.0006 test loss: 0.0005
# Epoch 6 batch 1100 train loss: 0.0004 test loss: 0.0005
# Epoch 6 batch 1200 train loss: 0.0005 test loss: 0.0005
# Epoch 6 batch 1300 train loss: 0.0006 test loss: 0.0005
# Epoch 6 batch 1400 train loss: 0.0005 test loss: 0.0006
# Epoch 6 batch 1500 train loss: 0.0004 test loss: 0.0005
# Epoch 6 batch 1600 train loss: 0.0003 test loss: 0.0005
# Epoch 6 batch 1700 train loss: 0.0003 test loss: 0.0005
# Epoch 7 batch 0 train loss: 0.0005 test loss: 0.0005
# Epoch 7 batch 100 train loss: 0.0004 test loss: 0.0005
# Epoch 7 batch 200 train loss: 0.0006 test loss: 0.0005
# Epoch 7 batch 300 train loss: 0.0005 test loss: 0.0005
# Epoch 7 batch 400 train loss: 0.0005 test loss: 0.0005
# Epoch 7 batch 500 train loss: 0.0005 test loss: 0.0005
# Epoch 7 batch 600 train loss: 0.0007 test loss: 0.0005
# Epoch 7 batch 700 train loss: 0.0006 test loss: 0.0005
# Epoch 7 batch 800 train loss: 0.0003 test loss: 0.0005
# Epoch 7 batch 900 train loss: 0.0004 test loss: 0.0005
# Epoch 7 batch 1000 train loss: 0.0004 test loss: 0.0005
# Epoch 7 batch 1100 train loss: 0.0003 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-28
# Epoch 7 batch 1200 train loss: 0.0006 test loss: 0.0004
# Epoch 7 batch 1300 train loss: 0.0003 test loss: 0.0005
# Epoch 7 batch 1400 train loss: 0.0003 test loss: 0.0005
# Epoch 7 batch 1500 train loss: 0.0004 test loss: 0.0005
# Epoch 7 batch 1600 train loss: 0.0003 test loss: 0.0005
# Epoch 7 batch 1700 train loss: 0.0006 test loss: 0.0005
# Epoch 8 batch 0 train loss: 0.0003 test loss: 0.0005
# Epoch 8 batch 100 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 200 train loss: 0.0003 test loss: 0.0005
# Epoch 8 batch 300 train loss: 0.0007 test loss: 0.0005
# Epoch 8 batch 400 train loss: 0.0005 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-29
# Epoch 8 batch 500 train loss: 0.0003 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-30
# Epoch 8 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 8 batch 700 train loss: 0.0003 test loss: 0.0005
# Epoch 8 batch 800 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 900 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 1000 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 1100 train loss: 0.0005 test loss: 0.0005
# Epoch 8 batch 1200 train loss: 0.0005 test loss: 0.0005
# Epoch 8 batch 1300 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 1400 train loss: 0.0005 test loss: 0.0005
# Epoch 8 batch 1500 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 1600 train loss: 0.0004 test loss: 0.0005
# Epoch 8 batch 1700 train loss: 0.0005 test loss: 0.0005
# Epoch 9 batch 0 train loss: 0.0004 test loss: 0.0005
# Epoch 9 batch 100 train loss: 0.0003 test loss: 0.0005
# Epoch 9 batch 200 train loss: 0.0007 test loss: 0.0005
# Epoch 9 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 9 batch 400 train loss: 0.0004 test loss: 0.0005
# Epoch 9 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 9 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 9 batch 700 train loss: 0.0004 test loss: 0.0006
# Epoch 9 batch 800 train loss: 0.0003 test loss: 0.0005
# Epoch 9 batch 900 train loss: 0.0005 test loss: 0.0005
# Epoch 9 batch 1000 train loss: 0.0007 test loss: 0.0005
# Epoch 9 batch 1100 train loss: 0.0005 test loss: 0.0004
# Epoch 9 batch 1200 train loss: 0.0005 test loss: 0.0005
# Epoch 9 batch 1300 train loss: 0.0005 test loss: 0.0005
# Epoch 9 batch 1400 train loss: 0.0005 test loss: 0.0005
# Epoch 9 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 9 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 9 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 10 batch 0 train loss: 0.0004 test loss: 0.0005
# Epoch 10 batch 100 train loss: 0.0005 test loss: 0.0005
# Epoch 10 batch 200 train loss: 0.0005 test loss: 0.0004
# Epoch 10 batch 300 train loss: 0.0005 test loss: 0.0005
# Epoch 10 batch 400 train loss: 0.0004 test loss: 0.0005
# Epoch 10 batch 500 train loss: 0.0004 test loss: 0.0005
# Epoch 10 batch 600 train loss: 0.0005 test loss: 0.0005
# Epoch 10 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 10 batch 800 train loss: 0.0006 test loss: 0.0005
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-31
# Epoch 10 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 10 batch 1000 train loss: 0.0003 test loss: 0.0005
# Epoch 10 batch 1100 train loss: 0.0006 test loss: 0.0005
# Epoch 10 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 10 batch 1300 train loss: 0.0004 test loss: 0.0005
# Epoch 10 batch 1400 train loss: 0.0003 test loss: 0.0005
# Epoch 10 batch 1500 train loss: 0.0005 test loss: 0.0004
# Epoch 10 batch 1600 train loss: 0.0005 test loss: 0.0004
# Epoch 10 batch 1700 train loss: 0.0004 test loss: 0.0005
# Epoch 11 batch 0 train loss: 0.0003 test loss: 0.0005
# Epoch 11 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 11 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 11 batch 300 train loss: 0.0004 test loss: 0.0005
# Epoch 11 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 11 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 11 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 11 batch 700 train loss: 0.0003 test loss: 0.0005
# Epoch 11 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 11 batch 900 train loss: 0.0005 test loss: 0.0004
# Epoch 11 batch 1000 train loss: 0.0004 test loss: 0.0005
# Epoch 11 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 11 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 11 batch 1300 train loss: 0.0005 test loss: 0.0005
# Epoch 11 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 11 batch 1500 train loss: 0.0002 test loss: 0.0005
# Epoch 11 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 11 batch 1700 train loss: 0.0004 test loss: 0.0005
# Epoch 12 batch 0 train loss: 0.0006 test loss: 0.0005
# Epoch 12 batch 100 train loss: 0.0007 test loss: 0.0004
# Epoch 12 batch 200 train loss: 0.0006 test loss: 0.0005
# Epoch 12 batch 300 train loss: 0.0005 test loss: 0.0005
# Epoch 12 batch 400 train loss: 0.0005 test loss: 0.0004
# Epoch 12 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 12 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 12 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 12 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 12 batch 900 train loss: 0.0005 test loss: 0.0004
# Epoch 12 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 12 batch 1100 train loss: 0.0004 test loss: 0.0005
# Epoch 12 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 12 batch 1300 train loss: 0.0005 test loss: 0.0005
# Epoch 12 batch 1400 train loss: 0.0004 test loss: 0.0005
# Epoch 12 batch 1500 train loss: 0.0003 test loss: 0.0005
# Epoch 12 batch 1600 train loss: 0.0005 test loss: 0.0004
# Epoch 12 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 13 batch 0 train loss: 0.0004 test loss: 0.0005
# Epoch 13 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 13 batch 200 train loss: 0.0005 test loss: 0.0004
# Epoch 13 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 600 train loss: 0.0005 test loss: 0.0004
# Epoch 13 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 13 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 13 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 13 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 13 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 1400 train loss: 0.0005 test loss: 0.0004
# Epoch 13 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 13 batch 1600 train loss: 0.0005 test loss: 0.0005
# Epoch 13 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 14 batch 0 train loss: 0.0005 test loss: 0.0004
# Epoch 14 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 14 batch 200 train loss: 0.0005 test loss: 0.0005
# Epoch 14 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 14 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 14 batch 500 train loss: 0.0005 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-32
# Epoch 14 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 14 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 14 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 14 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 14 batch 1000 train loss: 0.0005 test loss: 0.0005
# Epoch 14 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 14 batch 1200 train loss: 0.0008 test loss: 0.0004
# Epoch 14 batch 1300 train loss: 0.0010 test loss: 0.0005
# Epoch 14 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 14 batch 1500 train loss: 0.0004 test loss: 0.0005
# Epoch 14 batch 1600 train loss: 0.0005 test loss: 0.0004
# Epoch 14 batch 1700 train loss: 0.0006 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-33
# Epoch 15 batch 0 train loss: 0.0004 test loss: 0.0004
# Epoch 15 batch 100 train loss: 0.0005 test loss: 0.0005
# Epoch 15 batch 200 train loss: 0.0002 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-34
# Epoch 15 batch 300 train loss: 0.0006 test loss: 0.0004
# Epoch 15 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 15 batch 500 train loss: 0.0005 test loss: 0.0004
# Epoch 15 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 15 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 15 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 15 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 15 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 15 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 15 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 15 batch 1300 train loss: 0.0006 test loss: 0.0004
# Epoch 15 batch 1400 train loss: 0.0003 test loss: 0.0005
# Epoch 15 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 15 batch 1600 train loss: 0.0005 test loss: 0.0004
# Epoch 15 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 16 batch 0 train loss: 0.0003 test loss: 0.0005
# Epoch 16 batch 100 train loss: 0.0005 test loss: 0.0004
# Epoch 16 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 16 batch 300 train loss: 0.0005 test loss: 0.0004
# Epoch 16 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 500 train loss: 0.0005 test loss: 0.0004
# Epoch 16 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 700 train loss: 0.0005 test loss: 0.0004
# Epoch 16 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 1000 train loss: 0.0005 test loss: 0.0004
# Epoch 16 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 16 batch 1500 train loss: 0.0005 test loss: 0.0004
# Epoch 16 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 16 batch 1700 train loss: 0.0006 test loss: 0.0004
# Epoch 17 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 100 train loss: 0.0005 test loss: 0.0004
# Epoch 17 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 17 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 17 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 17 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 17 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 1300 train loss: 0.0005 test loss: 0.0004
# Epoch 17 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 17 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 17 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 17 batch 1700 train loss: 0.0012 test loss: 0.0004
# Epoch 18 batch 0 train loss: 0.0005 test loss: 0.0004
# Epoch 18 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 18 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 18 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 18 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 18 batch 500 train loss: 0.0005 test loss: 0.0004
# Epoch 18 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 18 batch 700 train loss: 0.0005 test loss: 0.0004
# Epoch 18 batch 800 train loss: 0.0006 test loss: 0.0004
# Epoch 18 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 18 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 18 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 18 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 18 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 18 batch 1400 train loss: 0.0005 test loss: 0.0005
# Epoch 18 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 18 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 18 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 19 batch 0 train loss: 0.0005 test loss: 0.0004
# Epoch 19 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 19 batch 200 train loss: 0.0005 test loss: 0.0004
# Epoch 19 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 19 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 19 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 19 batch 600 train loss: 0.0011 test loss: 0.0004
# Epoch 19 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 19 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 19 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 19 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 19 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 19 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 19 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 19 batch 1400 train loss: 0.0008 test loss: 0.0004
# Epoch 19 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 19 batch 1600 train loss: 0.0003 test loss: 0.0005
# Epoch 19 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 0 train loss: 0.0004 test loss: 0.0004
# Epoch 20 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 20 batch 200 train loss: 0.0005 test loss: 0.0004
# Epoch 20 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 500 train loss: 0.0006 test loss: 0.0004
# Epoch 20 batch 600 train loss: 0.0005 test loss: 0.0004
# Epoch 20 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 20 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 1000 train loss: 0.0005 test loss: 0.0004
# Epoch 20 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 20 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 20 batch 1400 train loss: 0.0006 test loss: 0.0004
# Epoch 20 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 20 batch 1600 train loss: 0.0004 test loss: 0.0005
# Epoch 20 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 100 train loss: 0.0004 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-35
# Epoch 21 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 300 train loss: 0.0005 test loss: 0.0004
# Epoch 21 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 1400 train loss: 0.0004 test loss: 0.0004
# Epoch 21 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 21 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 22 batch 0 train loss: 0.0005 test loss: 0.0004
# Epoch 22 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 22 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 22 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 22 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 700 train loss: 0.0005 test loss: 0.0004
# Epoch 22 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 22 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 1000 train loss: 0.0005 test loss: 0.0004
# Epoch 22 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 1200 train loss: 0.0005 test loss: 0.0005
# Epoch 22 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 22 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 22 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 22 batch 1700 train loss: 0.0005 test loss: 0.0004
# Epoch 23 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 23 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 23 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 23 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 23 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 23 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 700 train loss: 0.0004 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-36
# Epoch 23 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 1300 train loss: 0.0006 test loss: 0.0004
# Epoch 23 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 23 batch 1500 train loss: 0.0005 test loss: 0.0004
# Epoch 23 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 23 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 0 train loss: 0.0005 test loss: 0.0004
# Epoch 24 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 24 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 1400 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 24 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 24 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 25 batch 0 train loss: 0.0004 test loss: 0.0004
# Epoch 25 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 25 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 25 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 25 batch 400 train loss: 0.0005 test loss: 0.0004
# Epoch 25 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 25 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 25 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 25 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 25 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 25 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 25 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 25 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 25 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 25 batch 1400 train loss: 0.0005 test loss: 0.0004
# Epoch 25 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 25 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 25 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 26 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 26 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 300 train loss: 0.0005 test loss: 0.0004
# Epoch 26 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 700 train loss: 0.0005 test loss: 0.0004
# Epoch 26 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 26 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 26 batch 1100 train loss: 0.0006 test loss: 0.0004
# Epoch 26 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 1400 train loss: 0.0004 test loss: 0.0004
# Epoch 26 batch 1500 train loss: 0.0005 test loss: 0.0004
# Epoch 26 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 26 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 27 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 27 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 27 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 27 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 27 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 27 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 27 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 27 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 27 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 27 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 27 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 27 batch 1100 train loss: 0.0006 test loss: 0.0004
# Epoch 27 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 27 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 27 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 27 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 27 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 27 batch 1700 train loss: 0.0004 test loss: 0.0004
# Epoch 28 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 400 train loss: 0.0005 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-37
# Epoch 28 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 28 batch 600 train loss: 0.0005 test loss: 0.0004
# Epoch 28 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 800 train loss: 0.0005 test loss: 0.0004
# Epoch 28 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 28 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 28 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 28 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 28 batch 1600 train loss: 0.0003 test loss: 0.0005
# Epoch 28 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 29 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 29 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 29 batch 300 train loss: 0.0005 test loss: 0.0004
# Epoch 29 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 29 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 29 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 29 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 29 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 29 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 29 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 29 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 29 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 30 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 30 batch 100 train loss: 0.0003 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-38
# Epoch 30 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 30 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 30 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 30 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 30 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 30 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 30 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 30 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 30 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 31 batch 0 train loss: 0.0004 test loss: 0.0004
# Epoch 31 batch 100 train loss: 0.0006 test loss: 0.0004
# Epoch 31 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 31 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 31 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 31 batch 500 train loss: 0.0003 test loss: 0.0004
# Saving checkpoint at ./checkpoints/UNet_tom_32/ckpt-39
# Epoch 31 batch 600 train loss: 0.0006 test loss: 0.0004
# Epoch 31 batch 700 train loss: 0.0005 test loss: 0.0004
# Epoch 31 batch 800 train loss: 0.0004 test loss: 0.0004
# Epoch 31 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 31 batch 1000 train loss: 0.0005 test loss: 0.0004
# Epoch 31 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 31 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 31 batch 1300 train loss: 0.0003 test loss: 0.0005
# Epoch 31 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 31 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 31 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 31 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 32 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 32 batch 100 train loss: 0.0004 test loss: 0.0004
# Epoch 32 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 32 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 32 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 32 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 32 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 32 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 32 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 32 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 32 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 32 batch 1700 train loss: 0.0005 test loss: 0.0004
# Epoch 33 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 33 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 33 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 33 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 33 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 33 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 33 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 33 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 33 batch 1600 train loss: 0.0005 test loss: 0.0004
# Epoch 33 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 34 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 34 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 34 batch 300 train loss: 0.0006 test loss: 0.0004
# Epoch 34 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 34 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 34 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 34 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 34 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 34 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 1400 train loss: 0.0004 test loss: 0.0004
# Epoch 34 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 34 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 34 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 35 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 35 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 1100 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 1200 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 1400 train loss: 0.0004 test loss: 0.0005
# Epoch 35 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 35 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 35 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 36 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 36 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 36 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 700 train loss: 0.0005 test loss: 0.0004
# Epoch 36 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 1000 train loss: 0.0007 test loss: 0.0004
# Epoch 36 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 36 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 36 batch 1300 train loss: 0.0004 test loss: 0.0004
# Epoch 36 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 36 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 36 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 36 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 37 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 200 train loss: 0.0004 test loss: 0.0004
# Epoch 37 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 37 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 600 train loss: 0.0004 test loss: 0.0004
# Epoch 37 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 37 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 37 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 37 batch 1400 train loss: 0.0005 test loss: 0.0004
# Epoch 37 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 37 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 37 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 38 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 100 train loss: 0.0005 test loss: 0.0004
# Epoch 38 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 38 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 38 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 38 batch 800 train loss: 0.0001 test loss: 0.0004
# Epoch 38 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 38 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 1400 train loss: 0.0005 test loss: 0.0004
# Epoch 38 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 38 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 38 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 100 train loss: 0.0005 test loss: 0.0004
# Epoch 39 batch 200 train loss: 0.0005 test loss: 0.0004
# Epoch 39 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 39 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 600 train loss: 0.0005 test loss: 0.0004
# Epoch 39 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 39 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 39 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 39 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 39 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 39 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 39 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 39 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 39 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 100 train loss: 0.0005 test loss: 0.0004
# Epoch 40 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 40 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 600 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 900 train loss: 0.0004 test loss: 0.0004
# Epoch 40 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 40 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 40 batch 1600 train loss: 0.0004 test loss: 0.0004
# Epoch 40 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 41 batch 0 train loss: 0.0004 test loss: 0.0004
# Epoch 41 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 41 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 41 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 41 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 41 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 41 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 41 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 42 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 100 train loss: 0.0006 test loss: 0.0004
# Epoch 42 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 42 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 600 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 700 train loss: 0.0004 test loss: 0.0004
# Epoch 42 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 42 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 42 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 42 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 42 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 42 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 42 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 500 train loss: 0.0004 test loss: 0.0004
# Epoch 43 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 800 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 43 batch 1500 train loss: 0.0004 test loss: 0.0004
# Epoch 43 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 43 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 44 batch 0 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 44 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 44 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 600 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 700 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 44 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 44 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 44 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 44 batch 1600 train loss: 0.0006 test loss: 0.0004
# Epoch 44 batch 1700 train loss: 0.0003 test loss: 0.0004
# Epoch 45 batch 0 train loss: 0.0004 test loss: 0.0004
# Epoch 45 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 45 batch 200 train loss: 0.0003 test loss: 0.0004
# Epoch 45 batch 300 train loss: 0.0004 test loss: 0.0004
# Epoch 45 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 45 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 45 batch 600 train loss: 0.0003 test loss: 0.0004
# ...
# Epoch 484 batch 1000 train loss: 0.0003 test loss: 0.0004
# Epoch 484 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 484 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 484 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 484 batch 1400 train loss: 0.0002 test loss: 0.0005
# Epoch 484 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 484 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 484 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 400 train loss: 0.0001 test loss: 0.0005
# Epoch 485 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 485 batch 600 train loss: 0.0001 test loss: 0.0005
# Epoch 485 batch 700 train loss: 0.0002 test loss: 0.0005
# Epoch 485 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 485 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 1200 train loss: 0.0002 test loss: 0.0005
# Epoch 485 batch 1300 train loss: 0.0003 test loss: 0.0005
# Epoch 485 batch 1400 train loss: 0.0001 test loss: 0.0004
# Epoch 485 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 485 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 486 batch 0 train loss: 0.0002 test loss: 0.0005
# Epoch 486 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 486 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 486 batch 300 train loss: 0.0001 test loss: 0.0004
# Epoch 486 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 486 batch 500 train loss: 0.0001 test loss: 0.0004
# Epoch 486 batch 600 train loss: 0.0001 test loss: 0.0005
# Epoch 486 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 486 batch 800 train loss: 0.0002 test loss: 0.0005
# Epoch 486 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 486 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 486 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 486 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 486 batch 1300 train loss: 0.0001 test loss: 0.0005
# Epoch 486 batch 1400 train loss: 0.0002 test loss: 0.0005
# Epoch 486 batch 1500 train loss: 0.0001 test loss: 0.0005
# Epoch 486 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 486 batch 1700 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 0 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 100 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 487 batch 300 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 400 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 487 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 487 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 487 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 487 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 1200 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 1300 train loss: 0.0002 test loss: 0.0005
# Epoch 487 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 487 batch 1500 train loss: 0.0003 test loss: 0.0004
# Epoch 487 batch 1600 train loss: 0.0001 test loss: 0.0004
# Epoch 487 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 0 train loss: 0.0001 test loss: 0.0005
# Epoch 488 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 400 train loss: 0.0002 test loss: 0.0005
# Epoch 488 batch 500 train loss: 0.0002 test loss: 0.0005
# Epoch 488 batch 600 train loss: 0.0001 test loss: 0.0005
# Epoch 488 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 488 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 488 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 1400 train loss: 0.0003 test loss: 0.0004
# Epoch 488 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 488 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 0 train loss: 0.0001 test loss: 0.0004
# Epoch 489 batch 100 train loss: 0.0002 test loss: 0.0005
# Epoch 489 batch 200 train loss: 0.0002 test loss: 0.0005
# Epoch 489 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 489 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 489 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 489 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 489 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 1400 train loss: 0.0001 test loss: 0.0004
# Epoch 489 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 489 batch 1700 train loss: 0.0001 test loss: 0.0004
# Epoch 490 batch 0 train loss: 0.0001 test loss: 0.0004
# Epoch 490 batch 100 train loss: 0.0002 test loss: 0.0005
# Epoch 490 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 300 train loss: 0.0001 test loss: 0.0004
# Epoch 490 batch 400 train loss: 0.0001 test loss: 0.0005
# Epoch 490 batch 500 train loss: 0.0003 test loss: 0.0005
# Epoch 490 batch 600 train loss: 0.0003 test loss: 0.0005
# Epoch 490 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 800 train loss: 0.0001 test loss: 0.0004
# Epoch 490 batch 900 train loss: 0.0002 test loss: 0.0005
# Epoch 490 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 1300 train loss: 0.0001 test loss: 0.0004
# Epoch 490 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 1500 train loss: 0.0001 test loss: 0.0004
# Epoch 490 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 490 batch 1700 train loss: 0.0002 test loss: 0.0005
# Epoch 491 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 100 train loss: 0.0002 test loss: 0.0005
# Epoch 491 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 300 train loss: 0.0001 test loss: 0.0004
# Epoch 491 batch 400 train loss: 0.0004 test loss: 0.0004
# Epoch 491 batch 500 train loss: 0.0002 test loss: 0.0005
# Epoch 491 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 491 batch 700 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 800 train loss: 0.0001 test loss: 0.0004
# Epoch 491 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 491 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 1100 train loss: 0.0001 test loss: 0.0005
# Epoch 491 batch 1200 train loss: 0.0003 test loss: 0.0004
# Epoch 491 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 1400 train loss: 0.0001 test loss: 0.0005
# Epoch 491 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 491 batch 1700 train loss: 0.0002 test loss: 0.0005
# Epoch 492 batch 0 train loss: 0.0001 test loss: 0.0005
# Epoch 492 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 200 train loss: 0.0002 test loss: 0.0005
# Epoch 492 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 400 train loss: 0.0001 test loss: 0.0004
# Epoch 492 batch 500 train loss: 0.0003 test loss: 0.0004
# Epoch 492 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 492 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 492 batch 800 train loss: 0.0002 test loss: 0.0005
# Epoch 492 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 492 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 492 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 1300 train loss: 0.0001 test loss: 0.0004
# Epoch 492 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 492 batch 1700 train loss: 0.0001 test loss: 0.0005
# Epoch 493 batch 0 train loss: 0.0001 test loss: 0.0005
# Epoch 493 batch 100 train loss: 0.0003 test loss: 0.0004
# Epoch 493 batch 200 train loss: 0.0002 test loss: 0.0004
# Epoch 493 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 493 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 493 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 493 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 493 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 493 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 493 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 493 batch 1000 train loss: 0.0004 test loss: 0.0004
# Epoch 493 batch 1100 train loss: 0.0003 test loss: 0.0004
# Epoch 493 batch 1200 train loss: 0.0001 test loss: 0.0004
# Epoch 493 batch 1300 train loss: 0.0002 test loss: 0.0005
# Epoch 493 batch 1400 train loss: 0.0001 test loss: 0.0004
# Epoch 493 batch 1500 train loss: 0.0001 test loss: 0.0004
# Epoch 493 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 493 batch 1700 train loss: 0.0001 test loss: 0.0004
# Epoch 494 batch 0 train loss: 0.0002 test loss: 0.0005
# Epoch 494 batch 100 train loss: 0.0002 test loss: 0.0005
# Epoch 494 batch 200 train loss: 0.0001 test loss: 0.0005
# Epoch 494 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 494 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 494 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 494 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 494 batch 700 train loss: 0.0002 test loss: 0.0005
# Epoch 494 batch 800 train loss: 0.0002 test loss: 0.0005
# Epoch 494 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 494 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 494 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 494 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 494 batch 1300 train loss: 0.0001 test loss: 0.0004
# Epoch 494 batch 1400 train loss: 0.0001 test loss: 0.0005
# Epoch 494 batch 1500 train loss: 0.0001 test loss: 0.0004
# Epoch 494 batch 1600 train loss: 0.0001 test loss: 0.0004
# Epoch 494 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 200 train loss: 0.0001 test loss: 0.0005
# Epoch 495 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 400 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 500 train loss: 0.0003 test loss: 0.0005
# Epoch 495 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 495 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 495 batch 800 train loss: 0.0001 test loss: 0.0005
# Epoch 495 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 495 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 495 batch 1200 train loss: 0.0001 test loss: 0.0004
# Epoch 495 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 1400 train loss: 0.0002 test loss: 0.0005
# Epoch 495 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 495 batch 1600 train loss: 0.0003 test loss: 0.0004
# Epoch 495 batch 1700 train loss: 0.0002 test loss: 0.0005
# Epoch 496 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 100 train loss: 0.0002 test loss: 0.0005
# Epoch 496 batch 200 train loss: 0.0002 test loss: 0.0005
# Epoch 496 batch 300 train loss: 0.0003 test loss: 0.0004
# Epoch 496 batch 400 train loss: 0.0001 test loss: 0.0005
# Epoch 496 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 600 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 496 batch 800 train loss: 0.0001 test loss: 0.0004
# Epoch 496 batch 900 train loss: 0.0001 test loss: 0.0004
# Epoch 496 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 496 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 496 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 1600 train loss: 0.0002 test loss: 0.0004
# Epoch 496 batch 1700 train loss: 0.0002 test loss: 0.0004
# Epoch 497 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 497 batch 100 train loss: 0.0002 test loss: 0.0005
# Epoch 497 batch 200 train loss: 0.0001 test loss: 0.0005
# Epoch 497 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 497 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 497 batch 500 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 600 train loss: 0.0003 test loss: 0.0005
# Epoch 497 batch 700 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 800 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 497 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 1200 train loss: 0.0002 test loss: 0.0004
# Epoch 497 batch 1300 train loss: 0.0003 test loss: 0.0004
# Epoch 497 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 497 batch 1500 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 1600 train loss: 0.0001 test loss: 0.0004
# Epoch 497 batch 1700 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 0 train loss: 0.0002 test loss: 0.0004
# Epoch 498 batch 100 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 200 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 498 batch 400 train loss: 0.0003 test loss: 0.0004
# Epoch 498 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 498 batch 600 train loss: 0.0002 test loss: 0.0005
# Epoch 498 batch 700 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 800 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 900 train loss: 0.0002 test loss: 0.0004
# Epoch 498 batch 1000 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 1100 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 1200 train loss: 0.0002 test loss: 0.0005
# Epoch 498 batch 1300 train loss: 0.0003 test loss: 0.0005
# Epoch 498 batch 1400 train loss: 0.0002 test loss: 0.0004
# Epoch 498 batch 1500 train loss: 0.0002 test loss: 0.0004
# Epoch 498 batch 1600 train loss: 0.0001 test loss: 0.0004
# Epoch 498 batch 1700 train loss: 0.0001 test loss: 0.0004
# Epoch 499 batch 0 train loss: 0.0001 test loss: 0.0004
# Epoch 499 batch 100 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 200 train loss: 0.0002 test loss: 0.0005
# Epoch 499 batch 300 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 400 train loss: 0.0004 test loss: 0.0005
# Epoch 499 batch 500 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 600 train loss: 0.0003 test loss: 0.0005
# Epoch 499 batch 700 train loss: 0.0001 test loss: 0.0005
# Epoch 499 batch 800 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 900 train loss: 0.0003 test loss: 0.0004
# Epoch 499 batch 1000 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 1100 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 1200 train loss: 0.0002 test loss: 0.0005
# Epoch 499 batch 1300 train loss: 0.0002 test loss: 0.0004
# Epoch 499 batch 1400 train loss: 0.0001 test loss: 0.0005
# Epoch 499 batch 1500 train loss: 0.0001 test loss: 0.0004
# Epoch 499 batch 1600 train loss: 0.0001 test loss: 0.0004
# Epoch 499 batch 1700 train loss: 0.0002 test loss: 0.0004

# %% [markdown]
# # Model evaluation

# %%
i = -1
if ckpt_manager.checkpoints:
    ckpt.restore(ckpt_manager.checkpoints[i])
    print ('Checkpoint ' + ckpt_manager.checkpoints[i][-2:] +' restored!!')
# Out:
# Checkpoint 40 restored!!

# %%
unet_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
test_loss = unet_model.evaluate(test_dataset)
# Out:
# 1472/1472 [==============================] - 4s 3ms/step - loss: 0.0014

# %%
pred_result = unet_model.predict(test_dataset)

# %%
print(pred_result.shape)
print(test_label.shape)
# Out:
# (47088, 10, 10, 1)
# (47088, 10, 10, 1)

# %%
masking = test_input[..., 1]

# %%
masked_pred = np.ma.array(pred_result[..., 0], mask=masking)
masked_label = np.ma.array(test_label[..., 0], mask=masking)

# %%
for _ in range(test_label.shape[-2]):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_pred[..., _].reshape(-1))))
# Out:
# 0.05745939
# 0.023401735
# 0.02770268
# 0.024162846
# 0.02961146
# 0.055311725
# 0.024413332
# 0.033077165
# 0.029471142
# 0.046101235

# %%
r2 = RSquare()
for _ in range(test_label.shape[-2]):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_pred[..., _][~masked_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.82978445, shape=(), dtype=float32)
# tf.Tensor(0.98378485, shape=(), dtype=float32)
# tf.Tensor(0.9372744, shape=(), dtype=float32)
# tf.Tensor(0.90097815, shape=(), dtype=float32)
# WARNING:tensorflow:5 out of the last 5 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f736c512da0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.9403979, shape=(), dtype=float32)
# WARNING:tensorflow:6 out of the last 6 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f736c512da0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.8180961, shape=(), dtype=float32)
# WARNING:tensorflow:7 out of the last 7 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f736c512da0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.9815762, shape=(), dtype=float32)
# WARNING:tensorflow:8 out of the last 8 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f736c512da0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.909508, shape=(), dtype=float32)
# WARNING:tensorflow:9 out of the last 9 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f736c512da0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.8084607, shape=(), dtype=float32)
# WARNING:tensorflow:10 out of the last 10 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f736c512da0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.83649796, shape=(), dtype=float32)

# %%
plot_label = ((MAXS-MINS)*masked_label + MINS).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_pred = ((MAXS-MINS)*masked_pred + MINS).reshape(-1, 1)
plot_pred = plot_pred[~plot_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_pred)))
# Out:
# tf.Tensor(0.9601118, shape=(), dtype=float32)
# 44.698439041663995

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (6):

        NUMBERS = np.arange(1, pred_result.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*8, (6/2.54)*8))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=0.8) #measured
            expect1 = plt.plot(x_t, masked_pred[NUMBER, :, i], 'o', c=cmap[5], alpha=0.4) #estimated
            expect1 = plt.plot(x_t, pred_result[NUMBER, :, i], c=cmap[2], alpha=0.4) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1
