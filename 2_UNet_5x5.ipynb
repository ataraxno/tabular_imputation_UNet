# %%
import time
import os

import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)

from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras import *
tf.__version__
# Out:
# '2.1.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %% [markdown]
# # Model training

# %% [markdown]
# ## hyperparameters

# %%
SIZE = 5
BEST_PATH = './checkpoints/UNet_%dx%d' % (SIZE, SIZE)
DISP_STEPS = 100
TRAINING_EPOCHS = 500
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# %% [markdown]
# ## data loading

# %%
l = np.load('./data/tot_dataset_%dx%d.npz' % (SIZE, SIZE))
raw_input = l['raw_input']
raw_label = l['raw_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']

SCREEN_SIZE = l['SCREEN_SIZE']

# %%
print(raw_input.shape)
print(raw_label.shape)
# Out:
# (137558, 5, 5, 4)
# (137558, 5, 5, 1)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (79343, 5, 5, 4)
# (79343, 5, 5, 1)

# %%
raw_input = raw_input.astype(np.float32)
raw_label = raw_label.astype(np.float32)
test_input = test_input.astype(np.float32)
test_label = test_label.astype(np.float32)

# %%
num_train = int(raw_input.shape[0]*.7)
raw_input, raw_label = shuffle(raw_input, raw_label, random_state=4574)
train_input, train_label = raw_input[:num_train, ...], raw_label[:num_train, ...]
val_input, val_label = raw_input[num_train:, ...], raw_label[num_train:, ...]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((test_input, test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
class ConvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, dropout_rate):
        super(ConvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.dropout_rate = dropout_rate
        
        self.conv1 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch1 = layers.BatchNormalization()
        self.drop = layers.Dropout(self.dropout_rate)
        self.conv2 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch2 = layers.BatchNormalization()
        
    def call(self, inp):
        
        inp = self.batch1(self.conv1(inp))
        inp = self.drop(inp)
        inp = self.batch2(self.conv2(inp))
        
        return inp

# %%
class DeconvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, strides):
        super(DeconvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        
        self.deconv1 = layers.Conv2DTranspose(self.filters, self.kernel_size, strides=self.strides, padding='same')
        
    def call(self, inp):
        
        inp = self.deconv1(inp)
        
        return inp

# %%
class UNet(Model):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.conv_block1 = ConvBlock(64, (2, 2), 0.1)
        self.pool1 = layers.MaxPooling2D()
        
        self.conv_block2 = ConvBlock(128, (2, 2), 0.2)
        self.pool2 = layers.MaxPooling2D()
        
        self.conv_block3 = ConvBlock(256, (2, 2), 0.2)
        
        self.deconv_block1 = DeconvBlock(128, (2, 2), (2, 2))
        self.conv_block4 = ConvBlock(128, (2, 2), 0.2)
        
        self.deconv_block2 = DeconvBlock(32, (2, 2), (2, 2))
        self.padding = layers.ZeroPadding2D(((1, 0), (0, 1)))
        self.conv_block5 = ConvBlock(64, (2, 2), 0.1)
        
        self.output_conv = layers.Conv2D(1, (1, 1), activation='sigmoid')
        
    def call(self, inp):
        
        conv1 = self.conv_block1(inp)
        pooled1 = self.pool1(conv1)
        conv2 = self.conv_block2(pooled1)
        pooled2 = self.pool2(conv2)
        
        bottom = self.conv_block3(pooled2)
        
        deconv1 = self.deconv_block1(bottom)
        deconv1 = layers.concatenate([deconv1, conv2])
        deconv1 = self.conv_block4(deconv1)
        deconv2 = self.padding(self.deconv_block2(deconv1))
        deconv2 = layers.concatenate([deconv2, conv1])
        deconv2 = self.conv_block5(deconv2)
        
        return self.output_conv(deconv2)

# %%
#loss inputs should be masked.
loss_object = tf.keras.losses.MeanSquaredError()
def loss_function(model, inp, tar):
    
    masked_real = tar * (1 - inp[..., 1:2])
    masked_pred = model(inp) * (1 - inp[..., 1:2])
    
    return loss_object(masked_real, masked_pred)

# %%
unet_model = UNet()
opt = tf.optimizers.Adam(learning_rate=LEARNING_RATE)

# %%
@tf.function
def train(loss_function, model, opt, inp, tar):
    with tf.GradientTape() as tape:
        gradients = tape.gradient(loss_function(model, inp, tar), model.trainable_variables)
        gradient_variables = zip(gradients, model.trainable_variables)
        opt.apply_gradients(gradient_variables)

# %%
checkpoint_path = BEST_PATH

ckpt = tf.train.Checkpoint(unet_model=unet_model,
                           opt=opt)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=10)

# %%
writer = tf.summary.create_file_writer('tmp')

# %% [markdown]
# # Training

# %%
prev_test_loss = 100.0
with writer.as_default():
    with tf.summary.record_if(True):
        for epoch in range(TRAINING_EPOCHS):
            for step, (inp, tar) in enumerate(train_dataset):
                train(loss_function, unet_model, opt, inp, tar)
                loss_values = loss_function(unet_model, inp, tar)
                tf.summary.scalar('loss', loss_values, step=step)
                
                if step % DISP_STEPS == 0:
                    test_loss = 0
                    for step_, (inp_, tar_) in enumerate(test_dataset):
                        test_loss += loss_function(unet_model, inp_, tar_)
                        
                        if step_ > DISP_STEPS:
                            test_loss /= DISP_STEPS
                            break
                    if test_loss.numpy() < prev_test_loss:
                        ckpt_save_path = ckpt_manager.save()
                        prev_test_loss = test_loss.numpy()
                        print('Saving checkpoint at {}'.format(ckpt_save_path))
                    print('Epoch {} batch {} train loss: {:.4f} test loss: {:.4f}'
                          .format(epoch, step, loss_values.numpy(), test_loss.numpy()))
# Out:
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-1
# Epoch 0 batch 0 train loss: 0.0542 test loss: 0.0561
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-2
# Epoch 0 batch 100 train loss: 0.0053 test loss: 0.0066
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-3
# Epoch 0 batch 200 train loss: 0.0046 test loss: 0.0055
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-4
# Epoch 0 batch 300 train loss: 0.0066 test loss: 0.0046
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-5
# Epoch 0 batch 400 train loss: 0.0040 test loss: 0.0042
# Epoch 0 batch 500 train loss: 0.0094 test loss: 0.0049
# Epoch 0 batch 600 train loss: 0.0028 test loss: 0.0047
# Epoch 0 batch 700 train loss: 0.0047 test loss: 0.0057
# Epoch 0 batch 800 train loss: 0.0059 test loss: 0.0043
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-6
# Epoch 0 batch 900 train loss: 0.0070 test loss: 0.0041
# Epoch 0 batch 1000 train loss: 0.0034 test loss: 0.0044
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-7
# Epoch 0 batch 1100 train loss: 0.0070 test loss: 0.0041
# Epoch 0 batch 1200 train loss: 0.0053 test loss: 0.0043
# Epoch 0 batch 1300 train loss: 0.0044 test loss: 0.0045
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-8
# Epoch 0 batch 1400 train loss: 0.0058 test loss: 0.0036
# Epoch 0 batch 1500 train loss: 0.0030 test loss: 0.0042
# Epoch 0 batch 1600 train loss: 0.0042 test loss: 0.0045
# Epoch 0 batch 1700 train loss: 0.0077 test loss: 0.0041
# Epoch 0 batch 1800 train loss: 0.0059 test loss: 0.0046
# Epoch 0 batch 1900 train loss: 0.0050 test loss: 0.0042
# Epoch 0 batch 2000 train loss: 0.0059 test loss: 0.0041
# Epoch 0 batch 2100 train loss: 0.0029 test loss: 0.0046
# Epoch 0 batch 2200 train loss: 0.0051 test loss: 0.0045
# Epoch 0 batch 2300 train loss: 0.0039 test loss: 0.0038
# Epoch 0 batch 2400 train loss: 0.0025 test loss: 0.0041
# Epoch 0 batch 2500 train loss: 0.0041 test loss: 0.0036
# Epoch 0 batch 2600 train loss: 0.0030 test loss: 0.0039
# Epoch 0 batch 2700 train loss: 0.0046 test loss: 0.0041
# Epoch 0 batch 2800 train loss: 0.0048 test loss: 0.0043
# Epoch 0 batch 2900 train loss: 0.0034 test loss: 0.0042
# Epoch 0 batch 3000 train loss: 0.0040 test loss: 0.0041
# Epoch 1 batch 0 train loss: 0.0041 test loss: 0.0041
# Epoch 1 batch 100 train loss: 0.0047 test loss: 0.0040
# Epoch 1 batch 200 train loss: 0.0043 test loss: 0.0052
# Epoch 1 batch 300 train loss: 0.0049 test loss: 0.0039
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-9
# Epoch 1 batch 400 train loss: 0.0039 test loss: 0.0036
# Epoch 1 batch 500 train loss: 0.0037 test loss: 0.0043
# Epoch 1 batch 600 train loss: 0.0030 test loss: 0.0042
# Epoch 1 batch 700 train loss: 0.0030 test loss: 0.0043
# Epoch 1 batch 800 train loss: 0.0052 test loss: 0.0041
# Epoch 1 batch 900 train loss: 0.0086 test loss: 0.0043
# Epoch 1 batch 1000 train loss: 0.0036 test loss: 0.0045
# Epoch 1 batch 1100 train loss: 0.0042 test loss: 0.0040
# Epoch 1 batch 1200 train loss: 0.0040 test loss: 0.0048
# Epoch 1 batch 1300 train loss: 0.0028 test loss: 0.0042
# Epoch 1 batch 1400 train loss: 0.0023 test loss: 0.0040
# Epoch 1 batch 1500 train loss: 0.0036 test loss: 0.0038
# Epoch 1 batch 1600 train loss: 0.0040 test loss: 0.0040
# Epoch 1 batch 1700 train loss: 0.0089 test loss: 0.0041
# Epoch 1 batch 1800 train loss: 0.0046 test loss: 0.0045
# Epoch 1 batch 1900 train loss: 0.0025 test loss: 0.0037
# Epoch 1 batch 2000 train loss: 0.0039 test loss: 0.0041
# Epoch 1 batch 2100 train loss: 0.0054 test loss: 0.0042
# Epoch 1 batch 2200 train loss: 0.0048 test loss: 0.0042
# Epoch 1 batch 2300 train loss: 0.0049 test loss: 0.0043
# Epoch 1 batch 2400 train loss: 0.0027 test loss: 0.0041
# Epoch 1 batch 2500 train loss: 0.0031 test loss: 0.0038
# Epoch 1 batch 2600 train loss: 0.0064 test loss: 0.0040
# Epoch 1 batch 2700 train loss: 0.0032 test loss: 0.0040
# Epoch 1 batch 2800 train loss: 0.0056 test loss: 0.0038
# Epoch 1 batch 2900 train loss: 0.0022 test loss: 0.0042
# Epoch 1 batch 3000 train loss: 0.0022 test loss: 0.0038
# Epoch 2 batch 0 train loss: 0.0101 test loss: 0.0041
# Epoch 2 batch 100 train loss: 0.0048 test loss: 0.0044
# Epoch 2 batch 200 train loss: 0.0035 test loss: 0.0038
# Epoch 2 batch 300 train loss: 0.0034 test loss: 0.0037
# Epoch 2 batch 400 train loss: 0.0081 test loss: 0.0040
# Epoch 2 batch 500 train loss: 0.0069 test loss: 0.0042
# Epoch 2 batch 600 train loss: 0.0050 test loss: 0.0046
# Epoch 2 batch 700 train loss: 0.0084 test loss: 0.0038
# Epoch 2 batch 800 train loss: 0.0049 test loss: 0.0040
# Epoch 2 batch 900 train loss: 0.0027 test loss: 0.0039
# Epoch 2 batch 1000 train loss: 0.0069 test loss: 0.0040
# Epoch 2 batch 1100 train loss: 0.0063 test loss: 0.0042
# Epoch 2 batch 1200 train loss: 0.0037 test loss: 0.0041
# Epoch 2 batch 1300 train loss: 0.0021 test loss: 0.0044
# Epoch 2 batch 1400 train loss: 0.0045 test loss: 0.0039
# Epoch 2 batch 1500 train loss: 0.0039 test loss: 0.0042
# Epoch 2 batch 1600 train loss: 0.0038 test loss: 0.0040
# Epoch 2 batch 1700 train loss: 0.0038 test loss: 0.0039
# Epoch 2 batch 1800 train loss: 0.0045 test loss: 0.0040
# Epoch 2 batch 1900 train loss: 0.0057 test loss: 0.0039
# Epoch 2 batch 2000 train loss: 0.0043 test loss: 0.0041
# Epoch 2 batch 2100 train loss: 0.0034 test loss: 0.0039
# Epoch 2 batch 2200 train loss: 0.0044 test loss: 0.0044
# Epoch 2 batch 2300 train loss: 0.0025 test loss: 0.0040
# Epoch 2 batch 2400 train loss: 0.0083 test loss: 0.0041
# Epoch 2 batch 2500 train loss: 0.0028 test loss: 0.0040
# Epoch 2 batch 2600 train loss: 0.0077 test loss: 0.0039
# Epoch 2 batch 2700 train loss: 0.0036 test loss: 0.0039
# Epoch 2 batch 2800 train loss: 0.0019 test loss: 0.0041
# Epoch 2 batch 2900 train loss: 0.0026 test loss: 0.0043
# Epoch 2 batch 3000 train loss: 0.0042 test loss: 0.0041
# Epoch 3 batch 0 train loss: 0.0042 test loss: 0.0048
# Epoch 3 batch 100 train loss: 0.0028 test loss: 0.0040
# Epoch 3 batch 200 train loss: 0.0030 test loss: 0.0036
# Epoch 3 batch 300 train loss: 0.0033 test loss: 0.0037
# Epoch 3 batch 400 train loss: 0.0027 test loss: 0.0038
# Epoch 3 batch 500 train loss: 0.0038 test loss: 0.0038
# Epoch 3 batch 600 train loss: 0.0026 test loss: 0.0042
# Epoch 3 batch 700 train loss: 0.0098 test loss: 0.0040
# Epoch 3 batch 800 train loss: 0.0037 test loss: 0.0042
# Epoch 3 batch 900 train loss: 0.0021 test loss: 0.0037
# Epoch 3 batch 1000 train loss: 0.0057 test loss: 0.0041
# Epoch 3 batch 1100 train loss: 0.0022 test loss: 0.0040
# Epoch 3 batch 1200 train loss: 0.0049 test loss: 0.0039
# Epoch 3 batch 1300 train loss: 0.0025 test loss: 0.0040
# Epoch 3 batch 1400 train loss: 0.0032 test loss: 0.0038
# Epoch 3 batch 1500 train loss: 0.0040 test loss: 0.0038
# Epoch 3 batch 1600 train loss: 0.0055 test loss: 0.0043
# Epoch 3 batch 1700 train loss: 0.0054 test loss: 0.0038
# Epoch 3 batch 1800 train loss: 0.0027 test loss: 0.0045
# Epoch 3 batch 1900 train loss: 0.0050 test loss: 0.0037
# Epoch 3 batch 2000 train loss: 0.0039 test loss: 0.0041
# Epoch 3 batch 2100 train loss: 0.0051 test loss: 0.0037
# Epoch 3 batch 2200 train loss: 0.0061 test loss: 0.0039
# Epoch 3 batch 2300 train loss: 0.0036 test loss: 0.0039
# Epoch 3 batch 2400 train loss: 0.0032 test loss: 0.0043
# Epoch 3 batch 2500 train loss: 0.0078 test loss: 0.0038
# Epoch 3 batch 2600 train loss: 0.0063 test loss: 0.0042
# Epoch 3 batch 2700 train loss: 0.0031 test loss: 0.0038
# Epoch 3 batch 2800 train loss: 0.0038 test loss: 0.0038
# Epoch 3 batch 2900 train loss: 0.0022 test loss: 0.0038
# Epoch 3 batch 3000 train loss: 0.0019 test loss: 0.0040
# Epoch 4 batch 0 train loss: 0.0024 test loss: 0.0037
# Epoch 4 batch 100 train loss: 0.0044 test loss: 0.0039
# Epoch 4 batch 200 train loss: 0.0032 test loss: 0.0036
# Epoch 4 batch 300 train loss: 0.0017 test loss: 0.0038
# Epoch 4 batch 400 train loss: 0.0012 test loss: 0.0038
# Epoch 4 batch 500 train loss: 0.0059 test loss: 0.0042
# Epoch 4 batch 600 train loss: 0.0041 test loss: 0.0039
# Epoch 4 batch 700 train loss: 0.0050 test loss: 0.0039
# Epoch 4 batch 800 train loss: 0.0017 test loss: 0.0044
# Epoch 4 batch 900 train loss: 0.0042 test loss: 0.0040
# Epoch 4 batch 1000 train loss: 0.0068 test loss: 0.0042
# Epoch 4 batch 1100 train loss: 0.0053 test loss: 0.0040
# Epoch 4 batch 1200 train loss: 0.0068 test loss: 0.0038
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-10
# Epoch 4 batch 1300 train loss: 0.0037 test loss: 0.0035
# Epoch 4 batch 1400 train loss: 0.0089 test loss: 0.0039
# Epoch 4 batch 1500 train loss: 0.0030 test loss: 0.0037
# Epoch 4 batch 1600 train loss: 0.0061 test loss: 0.0039
# Epoch 4 batch 1700 train loss: 0.0019 test loss: 0.0037
# Epoch 4 batch 1800 train loss: 0.0026 test loss: 0.0037
# Epoch 4 batch 1900 train loss: 0.0034 test loss: 0.0039
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-11
# Epoch 4 batch 2000 train loss: 0.0046 test loss: 0.0035
# Epoch 4 batch 2100 train loss: 0.0036 test loss: 0.0040
# Epoch 4 batch 2200 train loss: 0.0059 test loss: 0.0038
# Epoch 4 batch 2300 train loss: 0.0023 test loss: 0.0039
# Epoch 4 batch 2400 train loss: 0.0043 test loss: 0.0039
# Epoch 4 batch 2500 train loss: 0.0029 test loss: 0.0041
# Epoch 4 batch 2600 train loss: 0.0053 test loss: 0.0041
# Epoch 4 batch 2700 train loss: 0.0068 test loss: 0.0036
# Epoch 4 batch 2800 train loss: 0.0034 test loss: 0.0038
# Epoch 4 batch 2900 train loss: 0.0016 test loss: 0.0046
# Epoch 4 batch 3000 train loss: 0.0030 test loss: 0.0040
# Epoch 5 batch 0 train loss: 0.0033 test loss: 0.0038
# Epoch 5 batch 100 train loss: 0.0022 test loss: 0.0041
# Epoch 5 batch 200 train loss: 0.0035 test loss: 0.0038
# Epoch 5 batch 300 train loss: 0.0036 test loss: 0.0038
# Epoch 5 batch 400 train loss: 0.0080 test loss: 0.0040
# Epoch 5 batch 500 train loss: 0.0062 test loss: 0.0040
# Epoch 5 batch 600 train loss: 0.0043 test loss: 0.0041
# Epoch 5 batch 700 train loss: 0.0048 test loss: 0.0040
# Epoch 5 batch 800 train loss: 0.0028 test loss: 0.0042
# Epoch 5 batch 900 train loss: 0.0077 test loss: 0.0038
# Epoch 5 batch 1000 train loss: 0.0036 test loss: 0.0038
# Epoch 5 batch 1100 train loss: 0.0036 test loss: 0.0042
# Epoch 5 batch 1200 train loss: 0.0062 test loss: 0.0038
# Epoch 5 batch 1300 train loss: 0.0034 test loss: 0.0039
# Epoch 5 batch 1400 train loss: 0.0056 test loss: 0.0042
# Epoch 5 batch 1500 train loss: 0.0028 test loss: 0.0038
# Epoch 5 batch 1600 train loss: 0.0017 test loss: 0.0041
# Epoch 5 batch 1700 train loss: 0.0028 test loss: 0.0040
# Epoch 5 batch 1800 train loss: 0.0045 test loss: 0.0040
# Epoch 5 batch 1900 train loss: 0.0033 test loss: 0.0036
# Epoch 5 batch 2000 train loss: 0.0028 test loss: 0.0040
# Epoch 5 batch 2100 train loss: 0.0028 test loss: 0.0039
# Epoch 5 batch 2200 train loss: 0.0052 test loss: 0.0040
# Epoch 5 batch 2300 train loss: 0.0038 test loss: 0.0039
# Epoch 5 batch 2400 train loss: 0.0046 test loss: 0.0039
# Epoch 5 batch 2500 train loss: 0.0026 test loss: 0.0040
# Epoch 5 batch 2600 train loss: 0.0033 test loss: 0.0037
# Epoch 5 batch 2700 train loss: 0.0029 test loss: 0.0038
# Epoch 5 batch 2800 train loss: 0.0041 test loss: 0.0037
# Epoch 5 batch 2900 train loss: 0.0035 test loss: 0.0040
# Epoch 5 batch 3000 train loss: 0.0048 test loss: 0.0040
# Epoch 6 batch 0 train loss: 0.0057 test loss: 0.0036
# Epoch 6 batch 100 train loss: 0.0029 test loss: 0.0038
# Epoch 6 batch 200 train loss: 0.0028 test loss: 0.0037
# Epoch 6 batch 300 train loss: 0.0049 test loss: 0.0037
# Epoch 6 batch 400 train loss: 0.0020 test loss: 0.0038
# Epoch 6 batch 500 train loss: 0.0058 test loss: 0.0038
# Epoch 6 batch 600 train loss: 0.0026 test loss: 0.0039
# Epoch 6 batch 700 train loss: 0.0052 test loss: 0.0038
# Epoch 6 batch 800 train loss: 0.0032 test loss: 0.0042
# Epoch 6 batch 900 train loss: 0.0076 test loss: 0.0039
# Epoch 6 batch 1000 train loss: 0.0019 test loss: 0.0042
# Epoch 6 batch 1100 train loss: 0.0063 test loss: 0.0038
# Epoch 6 batch 1200 train loss: 0.0046 test loss: 0.0042
# Epoch 6 batch 1300 train loss: 0.0022 test loss: 0.0039
# Epoch 6 batch 1400 train loss: 0.0041 test loss: 0.0038
# Epoch 6 batch 1500 train loss: 0.0030 test loss: 0.0038
# Epoch 6 batch 1600 train loss: 0.0080 test loss: 0.0037
# Epoch 6 batch 1700 train loss: 0.0059 test loss: 0.0036
# Epoch 6 batch 1800 train loss: 0.0047 test loss: 0.0038
# Epoch 6 batch 1900 train loss: 0.0031 test loss: 0.0038
# Epoch 6 batch 2000 train loss: 0.0033 test loss: 0.0035
# Epoch 6 batch 2100 train loss: 0.0034 test loss: 0.0036
# Epoch 6 batch 2200 train loss: 0.0066 test loss: 0.0038
# Epoch 6 batch 2300 train loss: 0.0043 test loss: 0.0038
# Epoch 6 batch 2400 train loss: 0.0029 test loss: 0.0039
# Epoch 6 batch 2500 train loss: 0.0024 test loss: 0.0037
# Epoch 6 batch 2600 train loss: 0.0029 test loss: 0.0037
# Epoch 6 batch 2700 train loss: 0.0049 test loss: 0.0041
# Epoch 6 batch 2800 train loss: 0.0023 test loss: 0.0039
# Epoch 6 batch 2900 train loss: 0.0038 test loss: 0.0041
# Epoch 6 batch 3000 train loss: 0.0040 test loss: 0.0039
# Epoch 7 batch 0 train loss: 0.0036 test loss: 0.0037
# Epoch 7 batch 100 train loss: 0.0020 test loss: 0.0039
# Epoch 7 batch 200 train loss: 0.0073 test loss: 0.0038
# Epoch 7 batch 300 train loss: 0.0024 test loss: 0.0038
# Epoch 7 batch 400 train loss: 0.0043 test loss: 0.0038
# Epoch 7 batch 500 train loss: 0.0040 test loss: 0.0037
# Epoch 7 batch 600 train loss: 0.0029 test loss: 0.0041
# Epoch 7 batch 700 train loss: 0.0083 test loss: 0.0037
# Epoch 7 batch 800 train loss: 0.0026 test loss: 0.0039
# Epoch 7 batch 900 train loss: 0.0053 test loss: 0.0039
# Epoch 7 batch 1000 train loss: 0.0029 test loss: 0.0039
# Epoch 7 batch 1100 train loss: 0.0031 test loss: 0.0038
# Epoch 7 batch 1200 train loss: 0.0042 test loss: 0.0036
# Epoch 7 batch 1300 train loss: 0.0039 test loss: 0.0038
# Epoch 7 batch 1400 train loss: 0.0050 test loss: 0.0038
# Epoch 7 batch 1500 train loss: 0.0027 test loss: 0.0038
# Epoch 7 batch 1600 train loss: 0.0025 test loss: 0.0037
# Epoch 7 batch 1700 train loss: 0.0045 test loss: 0.0041
# Epoch 7 batch 1800 train loss: 0.0057 test loss: 0.0037
# Epoch 7 batch 1900 train loss: 0.0040 test loss: 0.0036
# Epoch 7 batch 2000 train loss: 0.0020 test loss: 0.0039
# Epoch 7 batch 2100 train loss: 0.0021 test loss: 0.0037
# Epoch 7 batch 2200 train loss: 0.0018 test loss: 0.0038
# Epoch 7 batch 2300 train loss: 0.0028 test loss: 0.0038
# Epoch 7 batch 2400 train loss: 0.0028 test loss: 0.0038
# Epoch 7 batch 2500 train loss: 0.0025 test loss: 0.0037
# Epoch 7 batch 2600 train loss: 0.0020 test loss: 0.0038
# Epoch 7 batch 2700 train loss: 0.0031 test loss: 0.0036
# Epoch 7 batch 2800 train loss: 0.0064 test loss: 0.0037
# Epoch 7 batch 2900 train loss: 0.0046 test loss: 0.0039
# Epoch 7 batch 3000 train loss: 0.0056 test loss: 0.0036
# Epoch 8 batch 0 train loss: 0.0042 test loss: 0.0036
# Epoch 8 batch 100 train loss: 0.0031 test loss: 0.0039
# Epoch 8 batch 200 train loss: 0.0031 test loss: 0.0036
# Epoch 8 batch 300 train loss: 0.0029 test loss: 0.0037
# Epoch 8 batch 400 train loss: 0.0040 test loss: 0.0037
# Epoch 8 batch 500 train loss: 0.0039 test loss: 0.0038
# Epoch 8 batch 600 train loss: 0.0029 test loss: 0.0038
# Epoch 8 batch 700 train loss: 0.0054 test loss: 0.0038
# Epoch 8 batch 800 train loss: 0.0018 test loss: 0.0040
# Epoch 8 batch 900 train loss: 0.0019 test loss: 0.0038
# Epoch 8 batch 1000 train loss: 0.0034 test loss: 0.0039
# Epoch 8 batch 1100 train loss: 0.0045 test loss: 0.0039
# Epoch 8 batch 1200 train loss: 0.0053 test loss: 0.0038
# Epoch 8 batch 1300 train loss: 0.0032 test loss: 0.0036
# Epoch 8 batch 1400 train loss: 0.0102 test loss: 0.0036
# Epoch 8 batch 1500 train loss: 0.0053 test loss: 0.0037
# Epoch 8 batch 1600 train loss: 0.0024 test loss: 0.0040
# Epoch 8 batch 1700 train loss: 0.0037 test loss: 0.0043
# Epoch 8 batch 1800 train loss: 0.0019 test loss: 0.0040
# Epoch 8 batch 1900 train loss: 0.0054 test loss: 0.0037
# Epoch 8 batch 2000 train loss: 0.0046 test loss: 0.0036
# Epoch 8 batch 2100 train loss: 0.0027 test loss: 0.0038
# Epoch 8 batch 2200 train loss: 0.0010 test loss: 0.0039
# Epoch 8 batch 2300 train loss: 0.0051 test loss: 0.0040
# Epoch 8 batch 2400 train loss: 0.0058 test loss: 0.0039
# Epoch 8 batch 2500 train loss: 0.0032 test loss: 0.0038
# Epoch 8 batch 2600 train loss: 0.0021 test loss: 0.0039
# Epoch 8 batch 2700 train loss: 0.0019 test loss: 0.0036
# Epoch 8 batch 2800 train loss: 0.0070 test loss: 0.0038
# Epoch 8 batch 2900 train loss: 0.0049 test loss: 0.0039
# Epoch 8 batch 3000 train loss: 0.0036 test loss: 0.0036
# Epoch 9 batch 0 train loss: 0.0018 test loss: 0.0036
# Epoch 9 batch 100 train loss: 0.0025 test loss: 0.0038
# Epoch 9 batch 200 train loss: 0.0018 test loss: 0.0039
# Epoch 9 batch 300 train loss: 0.0053 test loss: 0.0039
# Epoch 9 batch 400 train loss: 0.0022 test loss: 0.0040
# Epoch 9 batch 500 train loss: 0.0021 test loss: 0.0037
# Epoch 9 batch 600 train loss: 0.0059 test loss: 0.0037
# Epoch 9 batch 700 train loss: 0.0023 test loss: 0.0036
# Epoch 9 batch 800 train loss: 0.0046 test loss: 0.0039
# Epoch 9 batch 900 train loss: 0.0033 test loss: 0.0040
# Epoch 9 batch 1000 train loss: 0.0074 test loss: 0.0042
# Epoch 9 batch 1100 train loss: 0.0034 test loss: 0.0038
# Epoch 9 batch 1200 train loss: 0.0042 test loss: 0.0038
# Epoch 9 batch 1300 train loss: 0.0044 test loss: 0.0038
# Epoch 9 batch 1400 train loss: 0.0032 test loss: 0.0037
# Epoch 9 batch 1500 train loss: 0.0022 test loss: 0.0038
# Epoch 9 batch 1600 train loss: 0.0045 test loss: 0.0037
# Epoch 9 batch 1700 train loss: 0.0070 test loss: 0.0039
# Epoch 9 batch 1800 train loss: 0.0044 test loss: 0.0038
# Epoch 9 batch 1900 train loss: 0.0032 test loss: 0.0036
# Epoch 9 batch 2000 train loss: 0.0044 test loss: 0.0039
# Epoch 9 batch 2100 train loss: 0.0013 test loss: 0.0040
# Epoch 9 batch 2200 train loss: 0.0020 test loss: 0.0038
# Epoch 9 batch 2300 train loss: 0.0039 test loss: 0.0038
# Epoch 9 batch 2400 train loss: 0.0025 test loss: 0.0037
# Epoch 9 batch 2500 train loss: 0.0031 test loss: 0.0038
# Epoch 9 batch 2600 train loss: 0.0048 test loss: 0.0040
# Epoch 9 batch 2700 train loss: 0.0020 test loss: 0.0037
# Epoch 9 batch 2800 train loss: 0.0015 test loss: 0.0038
# Epoch 9 batch 2900 train loss: 0.0094 test loss: 0.0039
# Epoch 9 batch 3000 train loss: 0.0015 test loss: 0.0037
# Epoch 10 batch 0 train loss: 0.0029 test loss: 0.0036
# Epoch 10 batch 100 train loss: 0.0028 test loss: 0.0039
# Epoch 10 batch 200 train loss: 0.0012 test loss: 0.0037
# Epoch 10 batch 300 train loss: 0.0025 test loss: 0.0041
# Epoch 10 batch 400 train loss: 0.0073 test loss: 0.0036
# Epoch 10 batch 500 train loss: 0.0065 test loss: 0.0039
# Epoch 10 batch 600 train loss: 0.0068 test loss: 0.0037
# Epoch 10 batch 700 train loss: 0.0026 test loss: 0.0037
# Epoch 10 batch 800 train loss: 0.0015 test loss: 0.0039
# Epoch 10 batch 900 train loss: 0.0021 test loss: 0.0039
# Epoch 10 batch 1000 train loss: 0.0051 test loss: 0.0038
# Epoch 10 batch 1100 train loss: 0.0049 test loss: 0.0038
# Epoch 10 batch 1200 train loss: 0.0052 test loss: 0.0040
# Epoch 10 batch 1300 train loss: 0.0038 test loss: 0.0036
# Epoch 10 batch 1400 train loss: 0.0022 test loss: 0.0039
# Epoch 10 batch 1500 train loss: 0.0044 test loss: 0.0038
# Epoch 10 batch 1600 train loss: 0.0030 test loss: 0.0042
# Epoch 10 batch 1700 train loss: 0.0022 test loss: 0.0039
# Epoch 10 batch 1800 train loss: 0.0045 test loss: 0.0037
# Epoch 10 batch 1900 train loss: 0.0031 test loss: 0.0037
# Epoch 10 batch 2000 train loss: 0.0032 test loss: 0.0037
# Epoch 10 batch 2100 train loss: 0.0043 test loss: 0.0037
# Epoch 10 batch 2200 train loss: 0.0027 test loss: 0.0038
# Epoch 10 batch 2300 train loss: 0.0038 test loss: 0.0037
# Epoch 10 batch 2400 train loss: 0.0037 test loss: 0.0036
# Epoch 10 batch 2500 train loss: 0.0027 test loss: 0.0040
# Epoch 10 batch 2600 train loss: 0.0036 test loss: 0.0039
# Epoch 10 batch 2700 train loss: 0.0035 test loss: 0.0037
# Epoch 10 batch 2800 train loss: 0.0042 test loss: 0.0040
# Epoch 10 batch 2900 train loss: 0.0066 test loss: 0.0037
# Epoch 10 batch 3000 train loss: 0.0064 test loss: 0.0037
# Epoch 11 batch 0 train loss: 0.0038 test loss: 0.0038
# Epoch 11 batch 100 train loss: 0.0067 test loss: 0.0037
# Epoch 11 batch 200 train loss: 0.0069 test loss: 0.0038
# Epoch 11 batch 300 train loss: 0.0055 test loss: 0.0037
# Epoch 11 batch 400 train loss: 0.0065 test loss: 0.0037
# Epoch 11 batch 500 train loss: 0.0032 test loss: 0.0038
# Epoch 11 batch 600 train loss: 0.0048 test loss: 0.0040
# Epoch 11 batch 700 train loss: 0.0028 test loss: 0.0039
# Epoch 11 batch 800 train loss: 0.0040 test loss: 0.0038
# Epoch 11 batch 900 train loss: 0.0052 test loss: 0.0037
# Epoch 11 batch 1000 train loss: 0.0074 test loss: 0.0040
# Epoch 11 batch 1100 train loss: 0.0023 test loss: 0.0039
# Epoch 11 batch 1200 train loss: 0.0047 test loss: 0.0038
# Epoch 11 batch 1300 train loss: 0.0040 test loss: 0.0037
# Epoch 11 batch 1400 train loss: 0.0032 test loss: 0.0037
# Epoch 11 batch 1500 train loss: 0.0056 test loss: 0.0038
# Epoch 11 batch 1600 train loss: 0.0079 test loss: 0.0040
# Epoch 11 batch 1700 train loss: 0.0019 test loss: 0.0036
# Epoch 11 batch 1800 train loss: 0.0024 test loss: 0.0039
# Epoch 11 batch 1900 train loss: 0.0043 test loss: 0.0037
# Epoch 11 batch 2000 train loss: 0.0050 test loss: 0.0037
# Epoch 11 batch 2100 train loss: 0.0031 test loss: 0.0037
# Epoch 11 batch 2200 train loss: 0.0041 test loss: 0.0036
# Epoch 11 batch 2300 train loss: 0.0089 test loss: 0.0038
# Epoch 11 batch 2400 train loss: 0.0047 test loss: 0.0037
# Epoch 11 batch 2500 train loss: 0.0053 test loss: 0.0039
# Epoch 11 batch 2600 train loss: 0.0025 test loss: 0.0038
# Epoch 11 batch 2700 train loss: 0.0052 test loss: 0.0039
# Epoch 11 batch 2800 train loss: 0.0028 test loss: 0.0040
# Epoch 11 batch 2900 train loss: 0.0043 test loss: 0.0038
# Epoch 11 batch 3000 train loss: 0.0015 test loss: 0.0039
# Epoch 12 batch 0 train loss: 0.0046 test loss: 0.0038
# Epoch 12 batch 100 train loss: 0.0048 test loss: 0.0038
# Epoch 12 batch 200 train loss: 0.0011 test loss: 0.0037
# Epoch 12 batch 300 train loss: 0.0110 test loss: 0.0040
# Epoch 12 batch 400 train loss: 0.0051 test loss: 0.0038
# Epoch 12 batch 500 train loss: 0.0042 test loss: 0.0039
# Epoch 12 batch 600 train loss: 0.0034 test loss: 0.0040
# Epoch 12 batch 700 train loss: 0.0028 test loss: 0.0038
# Epoch 12 batch 800 train loss: 0.0074 test loss: 0.0039
# Epoch 12 batch 900 train loss: 0.0020 test loss: 0.0038
# Epoch 12 batch 1000 train loss: 0.0073 test loss: 0.0041
# Epoch 12 batch 1100 train loss: 0.0031 test loss: 0.0040
# Epoch 12 batch 1200 train loss: 0.0036 test loss: 0.0040
# Epoch 12 batch 1300 train loss: 0.0023 test loss: 0.0037
# Epoch 12 batch 1400 train loss: 0.0037 test loss: 0.0037
# Epoch 12 batch 1500 train loss: 0.0045 test loss: 0.0039
# Epoch 12 batch 1600 train loss: 0.0042 test loss: 0.0037
# Epoch 12 batch 1700 train loss: 0.0059 test loss: 0.0038
# Epoch 12 batch 1800 train loss: 0.0013 test loss: 0.0036
# Epoch 12 batch 1900 train loss: 0.0038 test loss: 0.0038
# Epoch 12 batch 2000 train loss: 0.0040 test loss: 0.0037
# Epoch 12 batch 2100 train loss: 0.0083 test loss: 0.0039
# Epoch 12 batch 2200 train loss: 0.0023 test loss: 0.0039
# Epoch 12 batch 2300 train loss: 0.0049 test loss: 0.0039
# Epoch 12 batch 2400 train loss: 0.0055 test loss: 0.0039
# Epoch 12 batch 2500 train loss: 0.0047 test loss: 0.0037
# Epoch 12 batch 2600 train loss: 0.0069 test loss: 0.0039
# Epoch 12 batch 2700 train loss: 0.0026 test loss: 0.0037
# Epoch 12 batch 2800 train loss: 0.0053 test loss: 0.0040
# Epoch 12 batch 2900 train loss: 0.0054 test loss: 0.0040
# Epoch 12 batch 3000 train loss: 0.0041 test loss: 0.0036
# Epoch 13 batch 0 train loss: 0.0021 test loss: 0.0035
# Epoch 13 batch 100 train loss: 0.0068 test loss: 0.0036
# Epoch 13 batch 200 train loss: 0.0032 test loss: 0.0037
# Epoch 13 batch 300 train loss: 0.0024 test loss: 0.0039
# Epoch 13 batch 400 train loss: 0.0068 test loss: 0.0038
# Epoch 13 batch 500 train loss: 0.0023 test loss: 0.0039
# Epoch 13 batch 600 train loss: 0.0011 test loss: 0.0039
# Epoch 13 batch 700 train loss: 0.0043 test loss: 0.0039
# Epoch 13 batch 800 train loss: 0.0066 test loss: 0.0039
# Epoch 13 batch 900 train loss: 0.0017 test loss: 0.0038
# Epoch 13 batch 1000 train loss: 0.0022 test loss: 0.0037
# Epoch 13 batch 1100 train loss: 0.0026 test loss: 0.0038
# Epoch 13 batch 1200 train loss: 0.0053 test loss: 0.0039
# Epoch 13 batch 1300 train loss: 0.0060 test loss: 0.0036
# Epoch 13 batch 1400 train loss: 0.0030 test loss: 0.0037
# Epoch 13 batch 1500 train loss: 0.0024 test loss: 0.0039
# Epoch 13 batch 1600 train loss: 0.0034 test loss: 0.0040
# Epoch 13 batch 1700 train loss: 0.0018 test loss: 0.0038
# Epoch 13 batch 1800 train loss: 0.0021 test loss: 0.0037
# Epoch 13 batch 1900 train loss: 0.0046 test loss: 0.0037
# Epoch 13 batch 2000 train loss: 0.0060 test loss: 0.0038
# Epoch 13 batch 2100 train loss: 0.0043 test loss: 0.0041
# Epoch 13 batch 2200 train loss: 0.0035 test loss: 0.0036
# Epoch 13 batch 2300 train loss: 0.0044 test loss: 0.0037
# Epoch 13 batch 2400 train loss: 0.0037 test loss: 0.0038
# Epoch 13 batch 2500 train loss: 0.0055 test loss: 0.0038
# Epoch 13 batch 2600 train loss: 0.0023 test loss: 0.0039
# Epoch 13 batch 2700 train loss: 0.0033 test loss: 0.0036
# Epoch 13 batch 2800 train loss: 0.0030 test loss: 0.0039
# Epoch 13 batch 2900 train loss: 0.0033 test loss: 0.0039
# Epoch 13 batch 3000 train loss: 0.0018 test loss: 0.0037
# Epoch 14 batch 0 train loss: 0.0031 test loss: 0.0037
# Epoch 14 batch 100 train loss: 0.0089 test loss: 0.0040
# Epoch 14 batch 200 train loss: 0.0034 test loss: 0.0038
# Epoch 14 batch 300 train loss: 0.0042 test loss: 0.0037
# Epoch 14 batch 400 train loss: 0.0037 test loss: 0.0038
# Epoch 14 batch 500 train loss: 0.0036 test loss: 0.0038
# Epoch 14 batch 600 train loss: 0.0024 test loss: 0.0039
# Epoch 14 batch 700 train loss: 0.0025 test loss: 0.0037
# Epoch 14 batch 800 train loss: 0.0032 test loss: 0.0037
# Epoch 14 batch 900 train loss: 0.0060 test loss: 0.0038
# Epoch 14 batch 1000 train loss: 0.0075 test loss: 0.0038
# Epoch 14 batch 1100 train loss: 0.0046 test loss: 0.0038
# Epoch 14 batch 1200 train loss: 0.0032 test loss: 0.0041
# Epoch 14 batch 1300 train loss: 0.0024 test loss: 0.0040
# Epoch 14 batch 1400 train loss: 0.0019 test loss: 0.0039
# Epoch 14 batch 1500 train loss: 0.0056 test loss: 0.0038
# Epoch 14 batch 1600 train loss: 0.0019 test loss: 0.0038
# Epoch 14 batch 1700 train loss: 0.0028 test loss: 0.0037
# Epoch 14 batch 1800 train loss: 0.0034 test loss: 0.0038
# Epoch 14 batch 1900 train loss: 0.0027 test loss: 0.0036
# Epoch 14 batch 2000 train loss: 0.0072 test loss: 0.0039
# Epoch 14 batch 2100 train loss: 0.0026 test loss: 0.0039
# Epoch 14 batch 2200 train loss: 0.0021 test loss: 0.0037
# Epoch 14 batch 2300 train loss: 0.0066 test loss: 0.0039
# Epoch 14 batch 2400 train loss: 0.0083 test loss: 0.0037
# Epoch 14 batch 2500 train loss: 0.0011 test loss: 0.0038
# Epoch 14 batch 2600 train loss: 0.0050 test loss: 0.0038
# Epoch 14 batch 2700 train loss: 0.0026 test loss: 0.0036
# Epoch 14 batch 2800 train loss: 0.0039 test loss: 0.0037
# Epoch 14 batch 2900 train loss: 0.0060 test loss: 0.0037
# Epoch 14 batch 3000 train loss: 0.0038 test loss: 0.0037
# Epoch 15 batch 0 train loss: 0.0034 test loss: 0.0038
# Epoch 15 batch 100 train loss: 0.0018 test loss: 0.0038
# Epoch 15 batch 200 train loss: 0.0023 test loss: 0.0037
# Epoch 15 batch 300 train loss: 0.0033 test loss: 0.0037
# Epoch 15 batch 400 train loss: 0.0056 test loss: 0.0037
# Epoch 15 batch 500 train loss: 0.0036 test loss: 0.0039
# Epoch 15 batch 600 train loss: 0.0049 test loss: 0.0039
# Epoch 15 batch 700 train loss: 0.0058 test loss: 0.0037
# Epoch 15 batch 800 train loss: 0.0058 test loss: 0.0038
# Epoch 15 batch 900 train loss: 0.0061 test loss: 0.0036
# Epoch 15 batch 1000 train loss: 0.0056 test loss: 0.0038
# Epoch 15 batch 1100 train loss: 0.0043 test loss: 0.0039
# Epoch 15 batch 1200 train loss: 0.0043 test loss: 0.0041
# Epoch 15 batch 1300 train loss: 0.0045 test loss: 0.0037
# Epoch 15 batch 1400 train loss: 0.0063 test loss: 0.0038
# Epoch 15 batch 1500 train loss: 0.0035 test loss: 0.0038
# Epoch 15 batch 1600 train loss: 0.0028 test loss: 0.0038
# Epoch 15 batch 1700 train loss: 0.0023 test loss: 0.0038
# Epoch 15 batch 1800 train loss: 0.0023 test loss: 0.0038
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-12
# Epoch 15 batch 1900 train loss: 0.0029 test loss: 0.0035
# Epoch 15 batch 2000 train loss: 0.0040 test loss: 0.0036
# Epoch 15 batch 2100 train loss: 0.0051 test loss: 0.0036
# Epoch 15 batch 2200 train loss: 0.0073 test loss: 0.0038
# Epoch 15 batch 2300 train loss: 0.0043 test loss: 0.0037
# Epoch 15 batch 2400 train loss: 0.0024 test loss: 0.0037
# Epoch 15 batch 2500 train loss: 0.0022 test loss: 0.0038
# Epoch 15 batch 2600 train loss: 0.0050 test loss: 0.0039
# Epoch 15 batch 2700 train loss: 0.0029 test loss: 0.0038
# Epoch 15 batch 2800 train loss: 0.0037 test loss: 0.0035
# Epoch 15 batch 2900 train loss: 0.0019 test loss: 0.0038
# Epoch 15 batch 3000 train loss: 0.0047 test loss: 0.0037
# Epoch 16 batch 0 train loss: 0.0064 test loss: 0.0039
# Epoch 16 batch 100 train loss: 0.0038 test loss: 0.0040
# Epoch 16 batch 200 train loss: 0.0031 test loss: 0.0037
# Epoch 16 batch 300 train loss: 0.0033 test loss: 0.0038
# Epoch 16 batch 400 train loss: 0.0064 test loss: 0.0036
# Epoch 16 batch 500 train loss: 0.0030 test loss: 0.0037
# Epoch 16 batch 600 train loss: 0.0022 test loss: 0.0037
# Epoch 16 batch 700 train loss: 0.0094 test loss: 0.0037
# Epoch 16 batch 800 train loss: 0.0035 test loss: 0.0038
# Epoch 16 batch 900 train loss: 0.0066 test loss: 0.0038
# Epoch 16 batch 1000 train loss: 0.0033 test loss: 0.0039
# Epoch 16 batch 1100 train loss: 0.0047 test loss: 0.0037
# Epoch 16 batch 1200 train loss: 0.0046 test loss: 0.0038
# Epoch 16 batch 1300 train loss: 0.0040 test loss: 0.0037
# Epoch 16 batch 1400 train loss: 0.0025 test loss: 0.0037
# Epoch 16 batch 1500 train loss: 0.0049 test loss: 0.0038
# Epoch 16 batch 1600 train loss: 0.0073 test loss: 0.0039
# Epoch 16 batch 1700 train loss: 0.0039 test loss: 0.0036
# Epoch 16 batch 1800 train loss: 0.0063 test loss: 0.0039
# Epoch 16 batch 1900 train loss: 0.0057 test loss: 0.0039
# Epoch 16 batch 2000 train loss: 0.0016 test loss: 0.0037
# Epoch 16 batch 2100 train loss: 0.0063 test loss: 0.0040
# Epoch 16 batch 2200 train loss: 0.0034 test loss: 0.0037
# Epoch 16 batch 2300 train loss: 0.0069 test loss: 0.0039
# Epoch 16 batch 2400 train loss: 0.0023 test loss: 0.0036
# Epoch 16 batch 2500 train loss: 0.0057 test loss: 0.0038
# Epoch 16 batch 2600 train loss: 0.0061 test loss: 0.0038
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-13
# Epoch 16 batch 2700 train loss: 0.0041 test loss: 0.0034
# Epoch 16 batch 2800 train loss: 0.0050 test loss: 0.0039
# Epoch 16 batch 2900 train loss: 0.0025 test loss: 0.0038
# Epoch 16 batch 3000 train loss: 0.0024 test loss: 0.0038
# Epoch 17 batch 0 train loss: 0.0027 test loss: 0.0038
# Epoch 17 batch 100 train loss: 0.0029 test loss: 0.0037
# Epoch 17 batch 200 train loss: 0.0053 test loss: 0.0037
# Epoch 17 batch 300 train loss: 0.0101 test loss: 0.0036
# Epoch 17 batch 400 train loss: 0.0029 test loss: 0.0037
# Epoch 17 batch 500 train loss: 0.0032 test loss: 0.0036
# Epoch 17 batch 600 train loss: 0.0044 test loss: 0.0039
# Epoch 17 batch 700 train loss: 0.0033 test loss: 0.0037
# Epoch 17 batch 800 train loss: 0.0022 test loss: 0.0038
# Epoch 17 batch 900 train loss: 0.0014 test loss: 0.0036
# Epoch 17 batch 1000 train loss: 0.0029 test loss: 0.0038
# Epoch 17 batch 1100 train loss: 0.0046 test loss: 0.0037
# Epoch 17 batch 1200 train loss: 0.0037 test loss: 0.0040
# Epoch 17 batch 1300 train loss: 0.0039 test loss: 0.0039
# Epoch 17 batch 1400 train loss: 0.0033 test loss: 0.0034
# Epoch 17 batch 1500 train loss: 0.0021 test loss: 0.0037
# Epoch 17 batch 1600 train loss: 0.0026 test loss: 0.0038
# Epoch 17 batch 1700 train loss: 0.0038 test loss: 0.0037
# Epoch 17 batch 1800 train loss: 0.0039 test loss: 0.0040
# Epoch 17 batch 1900 train loss: 0.0012 test loss: 0.0037
# Epoch 17 batch 2000 train loss: 0.0034 test loss: 0.0035
# Epoch 17 batch 2100 train loss: 0.0048 test loss: 0.0039
# Epoch 17 batch 2200 train loss: 0.0071 test loss: 0.0038
# Epoch 17 batch 2300 train loss: 0.0053 test loss: 0.0039
# Epoch 17 batch 2400 train loss: 0.0066 test loss: 0.0037
# Epoch 17 batch 2500 train loss: 0.0029 test loss: 0.0039
# Epoch 17 batch 2600 train loss: 0.0016 test loss: 0.0038
# Epoch 17 batch 2700 train loss: 0.0058 test loss: 0.0036
# Epoch 17 batch 2800 train loss: 0.0039 test loss: 0.0039
# Epoch 17 batch 2900 train loss: 0.0024 test loss: 0.0038
# Epoch 17 batch 3000 train loss: 0.0041 test loss: 0.0039
# Epoch 18 batch 0 train loss: 0.0058 test loss: 0.0039
# Epoch 18 batch 100 train loss: 0.0023 test loss: 0.0039
# Epoch 18 batch 200 train loss: 0.0054 test loss: 0.0037
# Epoch 18 batch 300 train loss: 0.0061 test loss: 0.0038
# Epoch 18 batch 400 train loss: 0.0021 test loss: 0.0038
# Epoch 18 batch 500 train loss: 0.0102 test loss: 0.0039
# Epoch 18 batch 600 train loss: 0.0018 test loss: 0.0036
# Epoch 18 batch 700 train loss: 0.0060 test loss: 0.0036
# Epoch 18 batch 800 train loss: 0.0059 test loss: 0.0039
# Epoch 18 batch 900 train loss: 0.0045 test loss: 0.0037
# Epoch 18 batch 1000 train loss: 0.0045 test loss: 0.0040
# Epoch 18 batch 1100 train loss: 0.0031 test loss: 0.0039
# Epoch 18 batch 1200 train loss: 0.0025 test loss: 0.0039
# Epoch 18 batch 1300 train loss: 0.0066 test loss: 0.0036
# Epoch 18 batch 1400 train loss: 0.0037 test loss: 0.0037
# Epoch 18 batch 1500 train loss: 0.0041 test loss: 0.0035
# Epoch 18 batch 1600 train loss: 0.0037 test loss: 0.0039
# Epoch 18 batch 1700 train loss: 0.0046 test loss: 0.0037
# Epoch 18 batch 1800 train loss: 0.0044 test loss: 0.0036
# Epoch 18 batch 1900 train loss: 0.0062 test loss: 0.0035
# Epoch 18 batch 2000 train loss: 0.0023 test loss: 0.0039
# Epoch 18 batch 2100 train loss: 0.0026 test loss: 0.0036
# Epoch 18 batch 2200 train loss: 0.0032 test loss: 0.0039
# Epoch 18 batch 2300 train loss: 0.0047 test loss: 0.0039
# Epoch 18 batch 2400 train loss: 0.0049 test loss: 0.0036
# Epoch 18 batch 2500 train loss: 0.0036 test loss: 0.0040
# Epoch 18 batch 2600 train loss: 0.0030 test loss: 0.0038
# Epoch 18 batch 2700 train loss: 0.0023 test loss: 0.0035
# Epoch 18 batch 2800 train loss: 0.0030 test loss: 0.0039
# Epoch 18 batch 2900 train loss: 0.0046 test loss: 0.0038
# Epoch 18 batch 3000 train loss: 0.0042 test loss: 0.0038
# Epoch 19 batch 0 train loss: 0.0054 test loss: 0.0038
# Epoch 19 batch 100 train loss: 0.0010 test loss: 0.0037
# Epoch 19 batch 200 train loss: 0.0043 test loss: 0.0036
# Epoch 19 batch 300 train loss: 0.0035 test loss: 0.0039
# Epoch 19 batch 400 train loss: 0.0039 test loss: 0.0036
# Epoch 19 batch 500 train loss: 0.0075 test loss: 0.0038
# Epoch 19 batch 600 train loss: 0.0025 test loss: 0.0037
# Epoch 19 batch 700 train loss: 0.0021 test loss: 0.0039
# Epoch 19 batch 800 train loss: 0.0042 test loss: 0.0037
# Epoch 19 batch 900 train loss: 0.0008 test loss: 0.0038
# Epoch 19 batch 1000 train loss: 0.0027 test loss: 0.0038
# Epoch 19 batch 1100 train loss: 0.0033 test loss: 0.0039
# Epoch 19 batch 1200 train loss: 0.0105 test loss: 0.0039
# Saving checkpoint at ./checkpoints/UNet_5x5/ckpt-14
# Epoch 19 batch 1300 train loss: 0.0037 test loss: 0.0033
# Epoch 19 batch 1400 train loss: 0.0025 test loss: 0.0039
# Epoch 19 batch 1500 train loss: 0.0030 test loss: 0.0038
# Epoch 19 batch 1600 train loss: 0.0015 test loss: 0.0040
# Epoch 19 batch 1700 train loss: 0.0057 test loss: 0.0036
# Epoch 19 batch 1800 train loss: 0.0065 test loss: 0.0038
# Epoch 19 batch 1900 train loss: 0.0043 test loss: 0.0036
# Epoch 19 batch 2000 train loss: 0.0044 test loss: 0.0038
# Epoch 19 batch 2100 train loss: 0.0026 test loss: 0.0038
# Epoch 19 batch 2200 train loss: 0.0031 test loss: 0.0037
# Epoch 19 batch 2300 train loss: 0.0021 test loss: 0.0037
# Epoch 19 batch 2400 train loss: 0.0042 test loss: 0.0037
# Epoch 19 batch 2500 train loss: 0.0083 test loss: 0.0039
# Epoch 19 batch 2600 train loss: 0.0034 test loss: 0.0040
# Epoch 19 batch 2700 train loss: 0.0029 test loss: 0.0038
# Epoch 19 batch 2800 train loss: 0.0039 test loss: 0.0037
# Epoch 19 batch 2900 train loss: 0.0047 test loss: 0.0038
# Epoch 19 batch 3000 train loss: 0.0086 test loss: 0.0037
# Epoch 20 batch 0 train loss: 0.0029 test loss: 0.0037
# Epoch 20 batch 100 train loss: 0.0035 test loss: 0.0037
# Epoch 20 batch 200 train loss: 0.0047 test loss: 0.0036
# Epoch 20 batch 300 train loss: 0.0016 test loss: 0.0037
# Epoch 20 batch 400 train loss: 0.0055 test loss: 0.0039
# Epoch 20 batch 500 train loss: 0.0054 test loss: 0.0036
# Epoch 20 batch 600 train loss: 0.0025 test loss: 0.0039
# Epoch 20 batch 700 train loss: 0.0030 test loss: 0.0037
# Epoch 20 batch 800 train loss: 0.0044 test loss: 0.0038
# Epoch 20 batch 900 train loss: 0.0049 test loss: 0.0037
# Epoch 20 batch 1000 train loss: 0.0016 test loss: 0.0038
# Epoch 20 batch 1100 train loss: 0.0033 test loss: 0.0038
# Epoch 20 batch 1200 train loss: 0.0041 test loss: 0.0041
# Epoch 20 batch 1300 train loss: 0.0059 test loss: 0.0037
# Epoch 20 batch 1400 train loss: 0.0007 test loss: 0.0036
# Epoch 20 batch 1500 train loss: 0.0025 test loss: 0.0037
# Epoch 20 batch 1600 train loss: 0.0027 test loss: 0.0039
# Epoch 20 batch 1700 train loss: 0.0046 test loss: 0.0039
# Epoch 20 batch 1800 train loss: 0.0046 test loss: 0.0037
# Epoch 20 batch 1900 train loss: 0.0018 test loss: 0.0037
# Epoch 20 batch 2000 train loss: 0.0014 test loss: 0.0037
# Epoch 20 batch 2100 train loss: 0.0031 test loss: 0.0039
# Epoch 20 batch 2200 train loss: 0.0026 test loss: 0.0039
# Epoch 20 batch 2300 train loss: 0.0040 test loss: 0.0039
# Epoch 20 batch 2400 train loss: 0.0046 test loss: 0.0038
# Epoch 20 batch 2500 train loss: 0.0036 test loss: 0.0039
# Epoch 20 batch 2600 train loss: 0.0010 test loss: 0.0039
# Epoch 20 batch 2700 train loss: 0.0042 test loss: 0.0037
# Epoch 20 batch 2800 train loss: 0.0052 test loss: 0.0037
# Epoch 20 batch 2900 train loss: 0.0029 test loss: 0.0040
# Epoch 20 batch 3000 train loss: 0.0031 test loss: 0.0039
# Epoch 21 batch 0 train loss: 0.0042 test loss: 0.0039
# Epoch 21 batch 100 train loss: 0.0029 test loss: 0.0036
# Epoch 21 batch 200 train loss: 0.0022 test loss: 0.0037
# Epoch 21 batch 300 train loss: 0.0085 test loss: 0.0038
# Epoch 21 batch 400 train loss: 0.0055 test loss: 0.0037
# Epoch 21 batch 500 train loss: 0.0032 test loss: 0.0038
# Epoch 21 batch 600 train loss: 0.0049 test loss: 0.0036
# Epoch 21 batch 700 train loss: 0.0040 test loss: 0.0038
# Epoch 21 batch 800 train loss: 0.0044 test loss: 0.0038
# Epoch 21 batch 900 train loss: 0.0040 test loss: 0.0039
# Epoch 21 batch 1000 train loss: 0.0028 test loss: 0.0037
# Epoch 21 batch 1100 train loss: 0.0046 test loss: 0.0042
# Epoch 21 batch 1200 train loss: 0.0046 test loss: 0.0038
# Epoch 21 batch 1300 train loss: 0.0028 test loss: 0.0039
# Epoch 21 batch 1400 train loss: 0.0024 test loss: 0.0036
# Epoch 21 batch 1500 train loss: 0.0054 test loss: 0.0040
# Epoch 21 batch 1600 train loss: 0.0043 test loss: 0.0039
# Epoch 21 batch 1700 train loss: 0.0024 test loss: 0.0037
# Epoch 21 batch 1800 train loss: 0.0043 test loss: 0.0036
# Epoch 21 batch 1900 train loss: 0.0051 test loss: 0.0038
# Epoch 21 batch 2000 train loss: 0.0063 test loss: 0.0038
# Epoch 21 batch 2100 train loss: 0.0039 test loss: 0.0037
# Epoch 21 batch 2200 train loss: 0.0057 test loss: 0.0037
# Epoch 21 batch 2300 train loss: 0.0072 test loss: 0.0040
# Epoch 21 batch 2400 train loss: 0.0075 test loss: 0.0039
# Epoch 21 batch 2500 train loss: 0.0043 test loss: 0.0038
# Epoch 21 batch 2600 train loss: 0.0023 test loss: 0.0038
# Epoch 21 batch 2700 train loss: 0.0036 test loss: 0.0038
# Epoch 21 batch 2800 train loss: 0.0024 test loss: 0.0040
# Epoch 21 batch 2900 train loss: 0.0042 test loss: 0.0038
# Epoch 21 batch 3000 train loss: 0.0028 test loss: 0.0038
# Epoch 22 batch 0 train loss: 0.0050 test loss: 0.0041
# Epoch 22 batch 100 train loss: 0.0046 test loss: 0.0039
# Epoch 22 batch 200 train loss: 0.0033 test loss: 0.0037
# Epoch 22 batch 300 train loss: 0.0033 test loss: 0.0038
# Epoch 22 batch 400 train loss: 0.0036 test loss: 0.0037
# Epoch 22 batch 500 train loss: 0.0026 test loss: 0.0037
# Epoch 22 batch 600 train loss: 0.0031 test loss: 0.0038
# Epoch 22 batch 700 train loss: 0.0018 test loss: 0.0038
# Epoch 22 batch 800 train loss: 0.0062 test loss: 0.0038
# Epoch 22 batch 900 train loss: 0.0037 test loss: 0.0039
# Epoch 22 batch 1000 train loss: 0.0048 test loss: 0.0038
# Epoch 22 batch 1100 train loss: 0.0039 test loss: 0.0038
# Epoch 22 batch 1200 train loss: 0.0061 test loss: 0.0039
# Epoch 22 batch 1300 train loss: 0.0062 test loss: 0.0036
# Epoch 22 batch 1400 train loss: 0.0059 test loss: 0.0036
# Epoch 22 batch 1500 train loss: 0.0032 test loss: 0.0038
# Epoch 22 batch 1600 train loss: 0.0044 test loss: 0.0039
# Epoch 22 batch 1700 train loss: 0.0049 test loss: 0.0037
# Epoch 22 batch 1800 train loss: 0.0071 test loss: 0.0037
# Epoch 22 batch 1900 train loss: 0.0049 test loss: 0.0035
# Epoch 22 batch 2000 train loss: 0.0029 test loss: 0.0036
# Epoch 22 batch 2100 train loss: 0.0043 test loss: 0.0038
# Epoch 22 batch 2200 train loss: 0.0044 test loss: 0.0039
# Epoch 22 batch 2300 train loss: 0.0017 test loss: 0.0036
# Epoch 22 batch 2400 train loss: 0.0055 test loss: 0.0040
# Epoch 22 batch 2500 train loss: 0.0064 test loss: 0.0038
# Epoch 22 batch 2600 train loss: 0.0031 test loss: 0.0037
# Epoch 22 batch 2700 train loss: 0.0052 test loss: 0.0037
# Epoch 22 batch 2800 train loss: 0.0024 test loss: 0.0040
# Epoch 22 batch 2900 train loss: 0.0054 test loss: 0.0038
# Epoch 22 batch 3000 train loss: 0.0036 test loss: 0.0037
# Epoch 23 batch 0 train loss: 0.0072 test loss: 0.0038
# Epoch 23 batch 100 train loss: 0.0101 test loss: 0.0036
# Epoch 23 batch 200 train loss: 0.0046 test loss: 0.0036
# Epoch 23 batch 300 train loss: 0.0066 test loss: 0.0036
# Epoch 23 batch 400 train loss: 0.0052 test loss: 0.0038
# Epoch 23 batch 500 train loss: 0.0039 test loss: 0.0036
# Epoch 23 batch 600 train loss: 0.0047 test loss: 0.0038
# Epoch 23 batch 700 train loss: 0.0049 test loss: 0.0038
# Epoch 23 batch 800 train loss: 0.0019 test loss: 0.0039
# Epoch 23 batch 900 train loss: 0.0031 test loss: 0.0037
# Epoch 23 batch 1000 train loss: 0.0028 test loss: 0.0038
# Epoch 23 batch 1100 train loss: 0.0039 test loss: 0.0038
# Epoch 23 batch 1200 train loss: 0.0059 test loss: 0.0036
# Epoch 23 batch 1300 train loss: 0.0022 test loss: 0.0036
# Epoch 23 batch 1400 train loss: 0.0016 test loss: 0.0035
# Epoch 23 batch 1500 train loss: 0.0023 test loss: 0.0039
# Epoch 23 batch 1600 train loss: 0.0026 test loss: 0.0037
# Epoch 23 batch 1700 train loss: 0.0052 test loss: 0.0038
# Epoch 23 batch 1800 train loss: 0.0030 test loss: 0.0039
# Epoch 23 batch 1900 train loss: 0.0043 test loss: 0.0036
# Epoch 23 batch 2000 train loss: 0.0023 test loss: 0.0037
# Epoch 23 batch 2100 train loss: 0.0022 test loss: 0.0039
# Epoch 23 batch 2200 train loss: 0.0040 test loss: 0.0038
# Epoch 23 batch 2300 train loss: 0.0045 test loss: 0.0040
# Epoch 23 batch 2400 train loss: 0.0026 test loss: 0.0037
# Epoch 23 batch 2500 train loss: 0.0042 test loss: 0.0037
# Epoch 23 batch 2600 train loss: 0.0053 test loss: 0.0038
# Epoch 23 batch 2700 train loss: 0.0049 test loss: 0.0036
# Epoch 23 batch 2800 train loss: 0.0058 test loss: 0.0038
# Epoch 23 batch 2900 train loss: 0.0057 test loss: 0.0037
# Epoch 23 batch 3000 train loss: 0.0025 test loss: 0.0037
# Epoch 24 batch 0 train loss: 0.0028 test loss: 0.0038
# Epoch 24 batch 100 train loss: 0.0028 test loss: 0.0039
# Epoch 24 batch 200 train loss: 0.0069 test loss: 0.0038
# Epoch 24 batch 300 train loss: 0.0045 test loss: 0.0039
# Epoch 24 batch 400 train loss: 0.0037 test loss: 0.0036
# Epoch 24 batch 500 train loss: 0.0035 test loss: 0.0037
# Epoch 24 batch 600 train loss: 0.0031 test loss: 0.0038
# Epoch 24 batch 700 train loss: 0.0051 test loss: 0.0038
# Epoch 24 batch 800 train loss: 0.0065 test loss: 0.0038
# Epoch 24 batch 900 train loss: 0.0028 test loss: 0.0039
# Epoch 24 batch 1000 train loss: 0.0043 test loss: 0.0039
# Epoch 24 batch 1100 train loss: 0.0053 test loss: 0.0039
# Epoch 24 batch 1200 train loss: 0.0062 test loss: 0.0037
# Epoch 24 batch 1300 train loss: 0.0027 test loss: 0.0037
# Epoch 24 batch 1400 train loss: 0.0071 test loss: 0.0037
# Epoch 24 batch 1500 train loss: 0.0046 test loss: 0.0039
# Epoch 24 batch 1600 train loss: 0.0050 test loss: 0.0039
# Epoch 24 batch 1700 train loss: 0.0030 test loss: 0.0037
# Epoch 24 batch 1800 train loss: 0.0044 test loss: 0.0039
# Epoch 24 batch 1900 train loss: 0.0025 test loss: 0.0037
# Epoch 24 batch 2000 train loss: 0.0047 test loss: 0.0036
# Epoch 24 batch 2100 train loss: 0.0033 test loss: 0.0038
# Epoch 24 batch 2200 train loss: 0.0023 test loss: 0.0037
# Epoch 24 batch 2300 train loss: 0.0040 test loss: 0.0037
# Epoch 24 batch 2400 train loss: 0.0025 test loss: 0.0037
# Epoch 24 batch 2500 train loss: 0.0038 test loss: 0.0038
# Epoch 24 batch 2600 train loss: 0.0036 test loss: 0.0038
# Epoch 24 batch 2700 train loss: 0.0060 test loss: 0.0037
# Epoch 24 batch 2800 train loss: 0.0019 test loss: 0.0037
# Epoch 24 batch 2900 train loss: 0.0035 test loss: 0.0037
# Epoch 24 batch 3000 train loss: 0.0042 test loss: 0.0037
# Epoch 25 batch 0 train loss: 0.0013 test loss: 0.0037
# Epoch 25 batch 100 train loss: 0.0036 test loss: 0.0040
# Epoch 25 batch 200 train loss: 0.0063 test loss: 0.0037
# Epoch 25 batch 300 train loss: 0.0028 test loss: 0.0039
# Epoch 25 batch 400 train loss: 0.0047 test loss: 0.0037
# Epoch 25 batch 500 train loss: 0.0051 test loss: 0.0038
# Epoch 25 batch 600 train loss: 0.0047 test loss: 0.0038
# Epoch 25 batch 700 train loss: 0.0049 test loss: 0.0036
# Epoch 25 batch 800 train loss: 0.0018 test loss: 0.0038
# Epoch 25 batch 900 train loss: 0.0026 test loss: 0.0036
# Epoch 25 batch 1000 train loss: 0.0049 test loss: 0.0038
# Epoch 25 batch 1100 train loss: 0.0026 test loss: 0.0039
# Epoch 25 batch 1200 train loss: 0.0028 test loss: 0.0038
# Epoch 25 batch 1300 train loss: 0.0031 test loss: 0.0034
# Epoch 25 batch 1400 train loss: 0.0053 test loss: 0.0039
# Epoch 25 batch 1500 train loss: 0.0066 test loss: 0.0038
# Epoch 25 batch 1600 train loss: 0.0040 test loss: 0.0040
# Epoch 25 batch 1700 train loss: 0.0022 test loss: 0.0037
# Epoch 25 batch 1800 train loss: 0.0044 test loss: 0.0037
# Epoch 25 batch 1900 train loss: 0.0061 test loss: 0.0036
# Epoch 25 batch 2000 train loss: 0.0027 test loss: 0.0037
# Epoch 25 batch 2100 train loss: 0.0026 test loss: 0.0039
# Epoch 25 batch 2200 train loss: 0.0030 test loss: 0.0038
# Epoch 25 batch 2300 train loss: 0.0039 test loss: 0.0039
# Epoch 25 batch 2400 train loss: 0.0036 test loss: 0.0037
# Epoch 25 batch 2500 train loss: 0.0032 test loss: 0.0036
# Epoch 25 batch 2600 train loss: 0.0019 test loss: 0.0037
# Epoch 25 batch 2700 train loss: 0.0041 test loss: 0.0034
# Epoch 25 batch 2800 train loss: 0.0067 test loss: 0.0038
# Epoch 25 batch 2900 train loss: 0.0024 test loss: 0.0038
# Epoch 25 batch 3000 train loss: 0.0028 test loss: 0.0037
# Epoch 26 batch 0 train loss: 0.0029 test loss: 0.0036
# Epoch 26 batch 100 train loss: 0.0031 test loss: 0.0038
# Epoch 26 batch 200 train loss: 0.0028 test loss: 0.0036
# Epoch 26 batch 300 train loss: 0.0059 test loss: 0.0038
# Epoch 26 batch 400 train loss: 0.0035 test loss: 0.0037
# Epoch 26 batch 500 train loss: 0.0062 test loss: 0.0037
# Epoch 26 batch 600 train loss: 0.0030 test loss: 0.0037
# Epoch 26 batch 700 train loss: 0.0022 test loss: 0.0037
# Epoch 26 batch 800 train loss: 0.0033 test loss: 0.0037
# Epoch 26 batch 900 train loss: 0.0060 test loss: 0.0039
# Epoch 26 batch 1000 train loss: 0.0125 test loss: 0.0038
# Epoch 26 batch 1100 train loss: 0.0027 test loss: 0.0039
# Epoch 26 batch 1200 train loss: 0.0029 test loss: 0.0039
# Epoch 26 batch 1300 train loss: 0.0047 test loss: 0.0037
# Epoch 26 batch 1400 train loss: 0.0026 test loss: 0.0037
# Epoch 26 batch 1500 train loss: 0.0049 test loss: 0.0038
# Epoch 26 batch 1600 train loss: 0.0030 test loss: 0.0037
# Epoch 26 batch 1700 train loss: 0.0087 test loss: 0.0037
# Epoch 26 batch 1800 train loss: 0.0025 test loss: 0.0038
# Epoch 26 batch 1900 train loss: 0.0067 test loss: 0.0036
# Epoch 26 batch 2000 train loss: 0.0019 test loss: 0.0037
# Epoch 26 batch 2100 train loss: 0.0021 test loss: 0.0038
# Epoch 26 batch 2200 train loss: 0.0055 test loss: 0.0037
# Epoch 26 batch 2300 train loss: 0.0047 test loss: 0.0039
# Epoch 26 batch 2400 train loss: 0.0033 test loss: 0.0038
# Epoch 26 batch 2500 train loss: 0.0050 test loss: 0.0039
# Epoch 26 batch 2600 train loss: 0.0041 test loss: 0.0037
# Epoch 26 batch 2700 train loss: 0.0029 test loss: 0.0037
# Epoch 26 batch 2800 train loss: 0.0037 test loss: 0.0038
# Epoch 26 batch 2900 train loss: 0.0040 test loss: 0.0038
# Epoch 26 batch 3000 train loss: 0.0052 test loss: 0.0039
# Epoch 27 batch 0 train loss: 0.0039 test loss: 0.0039
# Epoch 27 batch 100 train loss: 0.0036 test loss: 0.0039
# Epoch 27 batch 200 train loss: 0.0055 test loss: 0.0035
# ...
# Epoch 118 batch 2400 train loss: 0.0049 test loss: 0.0038
# Epoch 118 batch 2500 train loss: 0.0028 test loss: 0.0037
# Epoch 118 batch 2600 train loss: 0.0026 test loss: 0.0038
# Epoch 118 batch 2700 train loss: 0.0039 test loss: 0.0038
# Epoch 118 batch 2800 train loss: 0.0023 test loss: 0.0038
# Epoch 118 batch 2900 train loss: 0.0008 test loss: 0.0036
# Epoch 118 batch 3000 train loss: 0.0036 test loss: 0.0037
# Epoch 119 batch 0 train loss: 0.0031 test loss: 0.0037
# Epoch 119 batch 100 train loss: 0.0047 test loss: 0.0038
# Epoch 119 batch 200 train loss: 0.0025 test loss: 0.0038
# Epoch 119 batch 300 train loss: 0.0043 test loss: 0.0038
# Epoch 119 batch 400 train loss: 0.0032 test loss: 0.0039
# Epoch 119 batch 500 train loss: 0.0056 test loss: 0.0036
# Epoch 119 batch 600 train loss: 0.0028 test loss: 0.0038
# Epoch 119 batch 700 train loss: 0.0006 test loss: 0.0037
# Epoch 119 batch 800 train loss: 0.0024 test loss: 0.0038
# Epoch 119 batch 900 train loss: 0.0052 test loss: 0.0038
# Epoch 119 batch 1000 train loss: 0.0024 test loss: 0.0040
# Epoch 119 batch 1100 train loss: 0.0058 test loss: 0.0040
# Epoch 119 batch 1200 train loss: 0.0044 test loss: 0.0038
# Epoch 119 batch 1300 train loss: 0.0034 test loss: 0.0037
# Epoch 119 batch 1400 train loss: 0.0026 test loss: 0.0037
# Epoch 119 batch 1500 train loss: 0.0042 test loss: 0.0038
# Epoch 119 batch 1600 train loss: 0.0030 test loss: 0.0038
# Epoch 119 batch 1700 train loss: 0.0020 test loss: 0.0037
# Epoch 119 batch 1800 train loss: 0.0059 test loss: 0.0036
# Epoch 119 batch 1900 train loss: 0.0086 test loss: 0.0037
# Epoch 119 batch 2000 train loss: 0.0034 test loss: 0.0037
# Epoch 119 batch 2100 train loss: 0.0034 test loss: 0.0052
# Epoch 119 batch 2200 train loss: 0.0030 test loss: 0.0037
# Epoch 119 batch 2300 train loss: 0.0065 test loss: 0.0038
# Epoch 119 batch 2400 train loss: 0.0035 test loss: 0.0038
# Epoch 119 batch 2500 train loss: 0.0031 test loss: 0.0037
# Epoch 119 batch 2600 train loss: 0.0049 test loss: 0.0039
# Epoch 119 batch 2700 train loss: 0.0031 test loss: 0.0037
# Epoch 119 batch 2800 train loss: 0.0065 test loss: 0.0038
# Epoch 119 batch 2900 train loss: 0.0048 test loss: 0.0038
# Epoch 119 batch 3000 train loss: 0.0022 test loss: 0.0037
# Epoch 120 batch 0 train loss: 0.0021 test loss: 0.0037
# Epoch 120 batch 100 train loss: 0.0024 test loss: 0.0037
# Epoch 120 batch 200 train loss: 0.0040 test loss: 0.0036
# Epoch 120 batch 300 train loss: 0.0036 test loss: 0.0038
# Epoch 120 batch 400 train loss: 0.0016 test loss: 0.0037
# Epoch 120 batch 500 train loss: 0.0082 test loss: 0.0035
# Epoch 120 batch 600 train loss: 0.0021 test loss: 0.0038
# Epoch 120 batch 700 train loss: 0.0087 test loss: 0.0037
# Epoch 120 batch 800 train loss: 0.0032 test loss: 0.0039
# Epoch 120 batch 900 train loss: 0.0066 test loss: 0.0038
# Epoch 120 batch 1000 train loss: 0.0027 test loss: 0.0039
# Epoch 120 batch 1100 train loss: 0.0036 test loss: 0.0038
# Epoch 120 batch 1200 train loss: 0.0043 test loss: 0.0038
# Epoch 120 batch 1300 train loss: 0.0029 test loss: 0.0036
# Epoch 120 batch 1400 train loss: 0.0066 test loss: 0.0037
# Epoch 120 batch 1500 train loss: 0.0054 test loss: 0.0038
# Epoch 120 batch 1600 train loss: 0.0028 test loss: 0.0038
# Epoch 120 batch 1700 train loss: 0.0053 test loss: 0.0038
# Epoch 120 batch 1800 train loss: 0.0006 test loss: 0.0038
# Epoch 120 batch 1900 train loss: 0.0055 test loss: 0.0035
# Epoch 120 batch 2000 train loss: 0.0054 test loss: 0.0038
# Epoch 120 batch 2100 train loss: 0.0022 test loss: 0.0038
# Epoch 120 batch 2200 train loss: 0.0016 test loss: 0.0039
# Epoch 120 batch 2300 train loss: 0.0034 test loss: 0.0038
# Epoch 120 batch 2400 train loss: 0.0044 test loss: 0.0038
# Epoch 120 batch 2500 train loss: 0.0057 test loss: 0.0038
# Epoch 120 batch 2600 train loss: 0.0046 test loss: 0.0039
# Epoch 120 batch 2700 train loss: 0.0063 test loss: 0.0036
# Epoch 120 batch 2800 train loss: 0.0017 test loss: 0.0037
# Epoch 120 batch 2900 train loss: 0.0035 test loss: 0.0037
# Epoch 120 batch 3000 train loss: 0.0040 test loss: 0.0036
# Epoch 121 batch 0 train loss: 0.0044 test loss: 0.0036
# Epoch 121 batch 100 train loss: 0.0036 test loss: 0.0037
# Epoch 121 batch 200 train loss: 0.0025 test loss: 0.0038
# Epoch 121 batch 300 train loss: 0.0068 test loss: 0.0037
# Epoch 121 batch 400 train loss: 0.0028 test loss: 0.0037
# Epoch 121 batch 500 train loss: 0.0026 test loss: 0.0037
# Epoch 121 batch 600 train loss: 0.0047 test loss: 0.0038
# Epoch 121 batch 700 train loss: 0.0045 test loss: 0.0037
# Epoch 121 batch 800 train loss: 0.0030 test loss: 0.0038
# Epoch 121 batch 900 train loss: 0.0050 test loss: 0.0037
# Epoch 121 batch 1000 train loss: 0.0046 test loss: 0.0038
# Epoch 121 batch 1100 train loss: 0.0024 test loss: 0.0039
# Epoch 121 batch 1200 train loss: 0.0034 test loss: 0.0037
# Epoch 121 batch 1300 train loss: 0.0032 test loss: 0.0036
# Epoch 121 batch 1400 train loss: 0.0018 test loss: 0.0037
# Epoch 121 batch 1500 train loss: 0.0036 test loss: 0.0038
# Epoch 121 batch 1600 train loss: 0.0057 test loss: 0.0037
# Epoch 121 batch 1700 train loss: 0.0031 test loss: 0.0037
# Epoch 121 batch 1800 train loss: 0.0033 test loss: 0.0037
# Epoch 121 batch 1900 train loss: 0.0041 test loss: 0.0037
# Epoch 121 batch 2000 train loss: 0.0013 test loss: 0.0040
# Epoch 121 batch 2100 train loss: 0.0043 test loss: 0.0040
# Epoch 121 batch 2200 train loss: 0.0019 test loss: 0.0037
# Epoch 121 batch 2300 train loss: 0.0054 test loss: 0.0038
# Epoch 121 batch 2400 train loss: 0.0034 test loss: 0.0037
# Epoch 121 batch 2500 train loss: 0.0031 test loss: 0.0039
# Epoch 121 batch 2600 train loss: 0.0039 test loss: 0.0038
# Epoch 121 batch 2700 train loss: 0.0030 test loss: 0.0037
# Epoch 121 batch 2800 train loss: 0.0015 test loss: 0.0037
# Epoch 121 batch 2900 train loss: 0.0051 test loss: 0.0038
# Epoch 121 batch 3000 train loss: 0.0027 test loss: 0.0037
# Epoch 122 batch 0 train loss: 0.0043 test loss: 0.0037
# Epoch 122 batch 100 train loss: 0.0034 test loss: 0.0039
# Epoch 122 batch 200 train loss: 0.0033 test loss: 0.0037
# Epoch 122 batch 300 train loss: 0.0058 test loss: 0.0038
# Epoch 122 batch 400 train loss: 0.0066 test loss: 0.0037
# Epoch 122 batch 500 train loss: 0.0014 test loss: 0.0037
# Epoch 122 batch 600 train loss: 0.0017 test loss: 0.0038
# Epoch 122 batch 700 train loss: 0.0016 test loss: 0.0036
# Epoch 122 batch 800 train loss: 0.0013 test loss: 0.0038
# Epoch 122 batch 900 train loss: 0.0021 test loss: 0.0037
# Epoch 122 batch 1000 train loss: 0.0028 test loss: 0.0039
# Epoch 122 batch 1100 train loss: 0.0018 test loss: 0.0039
# Epoch 122 batch 1200 train loss: 0.0039 test loss: 0.0039
# Epoch 122 batch 1300 train loss: 0.0035 test loss: 0.0037
# Epoch 122 batch 1400 train loss: 0.0027 test loss: 0.0036
# Epoch 122 batch 1500 train loss: 0.0032 test loss: 0.0037
# Epoch 122 batch 1600 train loss: 0.0030 test loss: 0.0037
# Epoch 122 batch 1700 train loss: 0.0020 test loss: 0.0036
# Epoch 122 batch 1800 train loss: 0.0049 test loss: 0.0037
# Epoch 122 batch 1900 train loss: 0.0035 test loss: 0.0037
# Epoch 122 batch 2000 train loss: 0.0032 test loss: 0.0037
# Epoch 122 batch 2100 train loss: 0.0031 test loss: 0.0037
# Epoch 122 batch 2200 train loss: 0.0036 test loss: 0.0038
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     925         "explicit_paddings", explicit_paddings, "data_format", data_format,
# --> 926         "dilations", dilations)
#     927       return _result
#
# _FallbackException: This function does not handle the case of the path where all inputs are not already EagerTensors.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-47211aa7bf0c> in <module>()
#       5             for step, (inp, tar) in enumerate(train_dataset):
#       6                 train(loss_function, unet_model, opt, inp, tar)
# ----> 7                 loss_values = loss_function(unet_model, inp, tar)
#       8                 tf.summary.scalar('loss', loss_values, step=step)
#       9
#
# <ipython-input-16-0c459b9e369c> in loss_function(model, inp, tar)
#       4
#       5     masked_real = tar * (1 - inp[..., 1:2])
# ----> 6     masked_pred = model(inp) * (1 - inp[..., 1:2])
#       7
#       8     return loss_object(masked_real, masked_pred)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-15-b679f878c883> in call(self, inp)
#      34         deconv2 = self.padding(self.deconv_block2(deconv1))
#      35         deconv2 = layers.concatenate([deconv2, conv1])
# ---> 36         deconv2 = self.conv_block5(deconv2)
#      37
#      38         return self.output_conv(deconv2)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-13-8d2535a1455c> in call(self, inp)
#      16     def call(self, inp):
#      17
# ---> 18         inp = self.batch1(self.conv1(inp))
#      19         inp = self.drop(inp)
#      20         inp = self.batch2(self.conv2(inp))
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/layers/convolutional.py in call(self, inputs)
#     207       inputs = array_ops.pad(inputs, self._compute_causal_padding())
#     208
# --> 209     outputs = self._convolution_op(inputs, self.kernel)
#     210
#     211     if self.use_bias:
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py in __call__(self, inp, filter)
#    1133           call_from_convolution=False)
#    1134     else:
# -> 1135       return self.conv_op(inp, filter)
#    1136     # copybara:strip_end
#    1137     # copybara:insert return self.conv_op(inp, filter)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py in __call__(self, inp, filter)
#     638
#     639   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 640     return self.call(inp, filter)
#     641
#     642
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py in __call__(self, inp, filter)
#     237         padding=self.padding,
#     238         data_format=self.data_format,
# --> 239         name=self.name)
#     240
#     241
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name, filters)
#    2009                            data_format=data_format,
#    2010                            dilations=dilations,
# -> 2011                            name=name)
#    2012
#    2013
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     931             input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#     932             padding=padding, explicit_paddings=explicit_paddings,
# --> 933             data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#     934       except _core._SymbolicException:
#     935         pass  # Add nodes to the TensorFlow graph.
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1013         "'conv2d' Op, not %r." % dilations)
#    1014   dilations = [_execute.make_int(_i, "dilations") for _i in dilations]
# -> 1015   _attr_T, _inputs_T = _execute.args_to_matching_eager([input, filter], ctx)
#    1016   (input, filter) = _inputs_T
#    1017   _inputs_flat = [input, filter]
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in args_to_matching_eager(l, ctx, default_dtype)
#     265         dtype = ret[-1].dtype
#     266   else:
# --> 267     ret = [ops.convert_to_tensor(t, dtype, ctx=ctx) for t in l]
#     268
#     269   # TODO(slebedev): consider removing this as it leaks a Keras concept.
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in <listcomp>(.0)
#     265         dtype = ret[-1].dtype
#     266   else:
# --> 267     ret = [ops.convert_to_tensor(t, dtype, ctx=ctx) for t in l]
#     268
#     269   # TODO(slebedev): consider removing this as it leaks a Keras concept.
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1312
#    1313     if ret is None:
# -> 1314       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1315
#    1316     if ret is NotImplemented:
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py in _dense_var_to_tensor(var, dtype, name, as_ref)
#    1792
#    1793 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 1794   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)  # pylint: disable=protected-access
#    1795
#    1796
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py in _dense_var_to_tensor(***failed resolving arguments***)
#    1217       return self.read_value().op.inputs[0]
#    1218     else:
# -> 1219       return self.value()
#    1220
#    1221   def __iadd__(self, unused_other):
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py in value(self)
#     526     if self._cached_value is not None:
#     527       return self._cached_value
# --> 528     with ops.colocate_with(None, ignore_existing=True):
#     529       return self._read_variable_op()
#     530
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in colocate_with(op, ignore_existing)
#    5118 # only API for those uses to avoid deprecation warning.
#    5119 def colocate_with(op, ignore_existing=False):
# -> 5120   return _colocate_with_for_gradient(op, None, ignore_existing=ignore_existing)
#    5121
#    5122
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py in _colocate_with_for_gradient(op, gradient_uid, ignore_existing)
#    5101       return device(op.device)
#    5102     else:
# -> 5103       return NullContextmanager()
#    5104   else:
#    5105     default_graph = get_default_graph()
#
# KeyboardInterrupt:

# %% [markdown]
# # Model evaluation

# %%
i = -1
if ckpt_manager.checkpoints:
    ckpt.restore(ckpt_manager.checkpoints[i])
    print ('Checkpoint ' + ckpt_manager.checkpoints[i][-2:] +' restored!!')
# Out:
# Checkpoint 14 restored!!

# %%
unet_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
test_loss = unet_model.evaluate(test_dataset)
# Out:
# 2480/2480 [==============================] - 15s 6ms/step - loss: 0.0057

# %%
pred_result = unet_model.predict(test_dataset)

# %%
print(pred_result.shape)
print(test_label.shape)
# Out:
# (79343, 5, 5, 1)
# (79343, 5, 5, 1)

# %%
masking = test_input[..., 1]
avg_masking = masking[..., :5]

# %%
masked_pred = np.ma.array(pred_result[..., 0], mask=masking)
masked_label = np.ma.array(test_label[..., 0], mask=masking)

# %%
for _ in range(5):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_pred[..., _].reshape(-1))))
# Out:
# 0.07187087
# 0.08503802
# 0.07683666
# 0.0329214
# 0.09496596

# %%
r2 = RSquare()
for _ in range(5):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_pred[..., _][~masked_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.43959588, shape=(), dtype=float32)
# tf.Tensor(0.5491873, shape=(), dtype=float32)
# tf.Tensor(0.49094355, shape=(), dtype=float32)
# tf.Tensor(0.42951834, shape=(), dtype=float32)
# WARNING:tensorflow:5 out of the last 5 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f3faddb0a90>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.3647706, shape=(), dtype=float32)

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5]).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_pred = ((MAXS[:5]-MINS[:5])*masked_pred[..., :5] + MINS[:5]).reshape(-1, 1)
plot_pred = plot_pred[~plot_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_pred)))
# Out:
# tf.Tensor(0.7932104, shape=(), dtype=float32)
# 101.78049962902986

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (2):

        NUMBERS = np.arange(1, pred_result.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*8, (6/2.54)*8))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=1) #measured
            expect1 = plt.plot(x_t, masked_pred[NUMBER, :, i], 'o', c=cmap[5], alpha=1) #estimated
            expect2 = plt.plot(x_t, pred_result[NUMBER, :, i], c=cmap[2], alpha=1) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1

# %% [markdown]
# # Saving data

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5])
plot_label.fill_value = np.nan
plot_pred = ((MAXS[:5]-MINS[:5])*masked_pred[..., :5] + MINS[:5])
plot_pred.fill_value = np.nan

# %%
f = open('./results/UNet_%sx%s.npz' % (SCREEN_SIZE, SCREEN_SIZE), 'wb')
np.savez(f,
         test_label = plot_label.filled(),
         test_pred = plot_pred.filled()
        )
f.close()
