# %%
import time
import os

import pandas as pd
import numpy as np
np.set_printoptions(precision=6, suppress=True)

from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras import *
tf.__version__
# Out:
# '2.1.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %% [markdown]
# # Model training

# %% [markdown]
# ## hyperparameters

# %%
SIZE = 50
BEST_PATH = './checkpoints/UNet_%dx%d' % (SIZE, SIZE)
DISP_STEPS = 100
TRAINING_EPOCHS = 500
BATCH_SIZE = 32
LEARNING_RATE = 0.001

# %% [markdown]
# ## data loading

# %%
l = np.load('./data/tot_dataset_%dx%d.npz' % (SIZE, SIZE))
raw_input = l['raw_input']
raw_label = l['raw_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']

SCREEN_SIZE = l['SCREEN_SIZE']

# %%
print(raw_input.shape)
print(raw_label.shape)
# Out:
# (134993, 50, 50, 4)
# (134993, 50, 50, 1)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (78263, 50, 50, 4)
# (78263, 50, 50, 1)

# %%
raw_input = raw_input.astype(np.float32)
raw_label = raw_label.astype(np.float32)
test_input = test_input.astype(np.float32)
test_label = test_label.astype(np.float32)

# %%
num_train = int(raw_input.shape[0]*.7)
raw_input, raw_label = shuffle(raw_input, raw_label, random_state=4574)
train_input, train_label = raw_input[:num_train, ...], raw_label[:num_train, ...]
val_input, val_label = raw_input[num_train:, ...], raw_label[num_train:, ...]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
val_dataset = tf.data.Dataset.from_tensor_slices((val_input, val_label))
val_dataset = val_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices((test_input, test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
class ConvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, dropout_rate):
        super(ConvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.dropout_rate = dropout_rate
        
        self.conv1 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch1 = layers.BatchNormalization()
        self.drop = layers.Dropout(self.dropout_rate)
        self.conv2 = layers.Conv2D(self.filters, self.kernel_size,
                                   activation='relu', kernel_initializer='he_normal', padding='same')
        self.batch2 = layers.BatchNormalization()
        
    def call(self, inp):
        
        inp = self.batch1(self.conv1(inp))
        inp = self.drop(inp)
        inp = self.batch2(self.conv2(inp))
        
        return inp

# %%
class DeconvBlock(layers.Layer):
    def __init__(self, filters, kernel_size, strides):
        super(DeconvBlock, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        
        self.deconv1 = layers.Conv2DTranspose(self.filters, self.kernel_size, strides=self.strides, padding='same')
        
    def call(self, inp):
        
        inp = self.deconv1(inp)
        
        return inp

# %%
class UNet(Model):
    def __init__(self):
        super(UNet, self).__init__()
        
        self.conv_block1 = ConvBlock(64, (2, 2), 0.1)
        self.pool1 = layers.MaxPooling2D()
        
        self.conv_block2 = ConvBlock(128, (2, 2), 0.2)
        self.pool2 = layers.MaxPooling2D()
        
        self.conv_block3 = ConvBlock(256, (2, 2), 0.2)
        
        self.deconv_block1 = DeconvBlock(128, (2, 2), (2, 2))
        self.conv_block4 = ConvBlock(128, (2, 2), 0.2)
        
        self.deconv_block2 = DeconvBlock(32, (2, 2), (2, 2))
        self.padding = layers.ZeroPadding2D(((1, 0), (0, 1)))
        self.conv_block5 = ConvBlock(64, (2, 2), 0.1)
        
        self.output_conv = layers.Conv2D(1, (1, 1), activation='sigmoid')
        
    def call(self, inp):
        
        conv1 = self.conv_block1(inp)
        pooled1 = self.pool1(conv1)
        conv2 = self.conv_block2(pooled1)
        pooled2 = self.pool2(conv2)
        
        bottom = self.conv_block3(pooled2)
        
        deconv1 = self.padding(self.deconv_block1(bottom))
        deconv1 = layers.concatenate([deconv1, conv2])
        deconv1 = self.conv_block4(deconv1)
        deconv2 = self.deconv_block2(deconv1)
        deconv2 = layers.concatenate([deconv2, conv1])
        deconv2 = self.conv_block5(deconv2)
        
        return self.output_conv(deconv2)

# %%
#loss inputs should be masked.
loss_object = tf.keras.losses.MeanSquaredError()
def loss_function(model, inp, tar):
    
    masked_real = tar * (1 - inp[..., 1:2])
    masked_pred = model(inp) * (1 - inp[..., 1:2])
    
    return loss_object(masked_real, masked_pred)

# %%
unet_model = UNet()
opt = tf.optimizers.Adam(learning_rate=LEARNING_RATE)

# %%
@tf.function
def train(loss_function, model, opt, inp, tar):
    with tf.GradientTape() as tape:
        gradients = tape.gradient(loss_function(model, inp, tar), model.trainable_variables)
        gradient_variables = zip(gradients, model.trainable_variables)
        opt.apply_gradients(gradient_variables)

# %%
checkpoint_path = BEST_PATH

ckpt = tf.train.Checkpoint(unet_model=unet_model,
                           opt=opt)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=10)

# %%
writer = tf.summary.create_file_writer('tmp')

# %% [markdown]
# # Training

# %%
prev_test_loss = 100.0
with writer.as_default():
    with tf.summary.record_if(True):
        for epoch in range(TRAINING_EPOCHS):
            for step, (inp, tar) in enumerate(train_dataset):
                train(loss_function, unet_model, opt, inp, tar)
                loss_values = loss_function(unet_model, inp, tar)
                tf.summary.scalar('loss', loss_values, step=step)
                
                if step % DISP_STEPS == 0:
                    test_loss = 0
                    for step_, (inp_, tar_) in enumerate(test_dataset):
                        test_loss += loss_function(unet_model, inp_, tar_)
                        
                        if step_ > DISP_STEPS:
                            test_loss /= DISP_STEPS
                            break
                    if test_loss.numpy() < prev_test_loss:
                        ckpt_save_path = ckpt_manager.save()
                        prev_test_loss = test_loss.numpy()
                        print('Saving checkpoint at {}'.format(ckpt_save_path))
                    print('Epoch {} batch {} train loss: {:.4f} test loss: {:.4f}'
                          .format(epoch, step, loss_values.numpy(), test_loss.numpy()))
# Out:
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-19
# Epoch 0 batch 0 train loss: 0.0006 test loss: 0.0010
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-20
# Epoch 0 batch 100 train loss: 0.0005 test loss: 0.0009
# Epoch 0 batch 200 train loss: 0.0023 test loss: 0.0009
# Epoch 0 batch 300 train loss: 0.0017 test loss: 0.0011
# Epoch 0 batch 400 train loss: 0.0009 test loss: 0.0010
# Epoch 0 batch 500 train loss: 0.0008 test loss: 0.0010
# Epoch 0 batch 600 train loss: 0.0015 test loss: 0.0010
# Epoch 0 batch 700 train loss: 0.0006 test loss: 0.0010
# Epoch 0 batch 800 train loss: 0.0005 test loss: 0.0010
# Epoch 0 batch 900 train loss: 0.0007 test loss: 0.0010
# Epoch 0 batch 1000 train loss: 0.0012 test loss: 0.0010
# Epoch 0 batch 1100 train loss: 0.0005 test loss: 0.0010
# Epoch 0 batch 1200 train loss: 0.0005 test loss: 0.0009
# Epoch 0 batch 1300 train loss: 0.0009 test loss: 0.0010
# Epoch 0 batch 1400 train loss: 0.0006 test loss: 0.0009
# Epoch 0 batch 1500 train loss: 0.0016 test loss: 0.0011
# Epoch 0 batch 1600 train loss: 0.0008 test loss: 0.0010
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-21
# Epoch 0 batch 1700 train loss: 0.0004 test loss: 0.0009
# Epoch 0 batch 1800 train loss: 0.0005 test loss: 0.0010
# Epoch 0 batch 1900 train loss: 0.0009 test loss: 0.0011
# Epoch 0 batch 2000 train loss: 0.0011 test loss: 0.0010
# Epoch 0 batch 2100 train loss: 0.0005 test loss: 0.0010
# Epoch 0 batch 2200 train loss: 0.0006 test loss: 0.0010
# Epoch 0 batch 2300 train loss: 0.0009 test loss: 0.0010
# Epoch 0 batch 2400 train loss: 0.0012 test loss: 0.0010
# Epoch 0 batch 2500 train loss: 0.0004 test loss: 0.0010
# Epoch 0 batch 2600 train loss: 0.0005 test loss: 0.0009
# Epoch 0 batch 2700 train loss: 0.0005 test loss: 0.0009
# Epoch 0 batch 2800 train loss: 0.0020 test loss: 0.0010
# Epoch 0 batch 2900 train loss: 0.0009 test loss: 0.0010
# Epoch 1 batch 0 train loss: 0.0005 test loss: 0.0010
# Epoch 1 batch 100 train loss: 0.0005 test loss: 0.0010
# Epoch 1 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 1 batch 300 train loss: 0.0004 test loss: 0.0010
# Epoch 1 batch 400 train loss: 0.0010 test loss: 0.0010
# Epoch 1 batch 500 train loss: 0.0004 test loss: 0.0010
# Epoch 1 batch 600 train loss: 0.0004 test loss: 0.0010
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-22
# Epoch 1 batch 700 train loss: 0.0006 test loss: 0.0009
# Epoch 1 batch 800 train loss: 0.0003 test loss: 0.0009
# Epoch 1 batch 900 train loss: 0.0015 test loss: 0.0010
# Epoch 1 batch 1000 train loss: 0.0004 test loss: 0.0010
# Epoch 1 batch 1100 train loss: 0.0005 test loss: 0.0010
# Epoch 1 batch 1200 train loss: 0.0012 test loss: 0.0010
# Epoch 1 batch 1300 train loss: 0.0004 test loss: 0.0010
# Epoch 1 batch 1400 train loss: 0.0007 test loss: 0.0009
# Epoch 1 batch 1500 train loss: 0.0003 test loss: 0.0010
# Epoch 1 batch 1600 train loss: 0.0005 test loss: 0.0010
# Epoch 1 batch 1700 train loss: 0.0003 test loss: 0.0009
# Epoch 1 batch 1800 train loss: 0.0005 test loss: 0.0010
# Epoch 1 batch 1900 train loss: 0.0016 test loss: 0.0010
# Epoch 1 batch 2000 train loss: 0.0004 test loss: 0.0010
# Epoch 1 batch 2100 train loss: 0.0003 test loss: 0.0010
# Epoch 1 batch 2200 train loss: 0.0010 test loss: 0.0010
# Epoch 1 batch 2300 train loss: 0.0006 test loss: 0.0010
# Epoch 1 batch 2400 train loss: 0.0005 test loss: 0.0010
# Epoch 1 batch 2500 train loss: 0.0012 test loss: 0.0009
# Epoch 1 batch 2600 train loss: 0.0007 test loss: 0.0010
# Epoch 1 batch 2700 train loss: 0.0009 test loss: 0.0009
# Epoch 1 batch 2800 train loss: 0.0017 test loss: 0.0010
# Epoch 1 batch 2900 train loss: 0.0014 test loss: 0.0010
# Epoch 2 batch 0 train loss: 0.0006 test loss: 0.0009
# Epoch 2 batch 100 train loss: 0.0006 test loss: 0.0009
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-23
# Epoch 2 batch 200 train loss: 0.0011 test loss: 0.0009
# Epoch 2 batch 300 train loss: 0.0003 test loss: 0.0010
# Epoch 2 batch 400 train loss: 0.0005 test loss: 0.0009
# Epoch 2 batch 500 train loss: 0.0011 test loss: 0.0010
# Epoch 2 batch 600 train loss: 0.0005 test loss: 0.0010
# Epoch 2 batch 700 train loss: 0.0005 test loss: 0.0010
# Epoch 2 batch 800 train loss: 0.0005 test loss: 0.0010
# Epoch 2 batch 900 train loss: 0.0013 test loss: 0.0009
# Epoch 2 batch 1000 train loss: 0.0005 test loss: 0.0009
# Epoch 2 batch 1100 train loss: 0.0004 test loss: 0.0010
# Epoch 2 batch 1200 train loss: 0.0005 test loss: 0.0010
# Epoch 2 batch 1300 train loss: 0.0003 test loss: 0.0009
# Epoch 2 batch 1400 train loss: 0.0004 test loss: 0.0010
# Epoch 2 batch 1500 train loss: 0.0018 test loss: 0.0010
# Epoch 2 batch 1600 train loss: 0.0002 test loss: 0.0009
# Epoch 2 batch 1700 train loss: 0.0004 test loss: 0.0010
# Epoch 2 batch 1800 train loss: 0.0003 test loss: 0.0010
# Epoch 2 batch 1900 train loss: 0.0005 test loss: 0.0011
# Epoch 2 batch 2000 train loss: 0.0005 test loss: 0.0010
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-24
# Epoch 2 batch 2100 train loss: 0.0011 test loss: 0.0009
# Epoch 2 batch 2200 train loss: 0.0003 test loss: 0.0009
# Epoch 2 batch 2300 train loss: 0.0003 test loss: 0.0009
# Epoch 2 batch 2400 train loss: 0.0005 test loss: 0.0009
# Epoch 2 batch 2500 train loss: 0.0013 test loss: 0.0010
# Epoch 2 batch 2600 train loss: 0.0003 test loss: 0.0010
# Epoch 2 batch 2700 train loss: 0.0014 test loss: 0.0009
# Epoch 2 batch 2800 train loss: 0.0007 test loss: 0.0010
# Epoch 2 batch 2900 train loss: 0.0006 test loss: 0.0009
# Epoch 3 batch 0 train loss: 0.0005 test loss: 0.0010
# Epoch 3 batch 100 train loss: 0.0005 test loss: 0.0010
# Epoch 3 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 3 batch 300 train loss: 0.0005 test loss: 0.0010
# Epoch 3 batch 400 train loss: 0.0012 test loss: 0.0009
# Epoch 3 batch 500 train loss: 0.0010 test loss: 0.0010
# Epoch 3 batch 600 train loss: 0.0014 test loss: 0.0010
# Epoch 3 batch 700 train loss: 0.0014 test loss: 0.0009
# Epoch 3 batch 800 train loss: 0.0009 test loss: 0.0010
# Epoch 3 batch 900 train loss: 0.0014 test loss: 0.0009
# Epoch 3 batch 1000 train loss: 0.0020 test loss: 0.0010
# Epoch 3 batch 1100 train loss: 0.0003 test loss: 0.0010
# Epoch 3 batch 1200 train loss: 0.0003 test loss: 0.0010
# Epoch 3 batch 1300 train loss: 0.0003 test loss: 0.0009
# Epoch 3 batch 1400 train loss: 0.0015 test loss: 0.0010
# Epoch 3 batch 1500 train loss: 0.0003 test loss: 0.0009
# Epoch 3 batch 1600 train loss: 0.0023 test loss: 0.0010
# Epoch 3 batch 1700 train loss: 0.0004 test loss: 0.0010
# Epoch 3 batch 1800 train loss: 0.0015 test loss: 0.0010
# Epoch 3 batch 1900 train loss: 0.0004 test loss: 0.0010
# Epoch 3 batch 2000 train loss: 0.0003 test loss: 0.0010
# Epoch 3 batch 2100 train loss: 0.0004 test loss: 0.0009
# Epoch 3 batch 2200 train loss: 0.0004 test loss: 0.0010
# Epoch 3 batch 2300 train loss: 0.0004 test loss: 0.0009
# Epoch 3 batch 2400 train loss: 0.0015 test loss: 0.0010
# Epoch 3 batch 2500 train loss: 0.0002 test loss: 0.0009
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-25
# Epoch 3 batch 2600 train loss: 0.0005 test loss: 0.0009
# Epoch 3 batch 2700 train loss: 0.0002 test loss: 0.0010
# Epoch 3 batch 2800 train loss: 0.0018 test loss: 0.0010
# Epoch 3 batch 2900 train loss: 0.0003 test loss: 0.0010
# Epoch 4 batch 0 train loss: 0.0014 test loss: 0.0010
# Epoch 4 batch 100 train loss: 0.0017 test loss: 0.0009
# Epoch 4 batch 200 train loss: 0.0013 test loss: 0.0009
# Epoch 4 batch 300 train loss: 0.0012 test loss: 0.0010
# Epoch 4 batch 400 train loss: 0.0007 test loss: 0.0009
# Epoch 4 batch 500 train loss: 0.0003 test loss: 0.0010
# Epoch 4 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 4 batch 700 train loss: 0.0008 test loss: 0.0010
# Epoch 4 batch 800 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 900 train loss: 0.0025 test loss: 0.0010
# Epoch 4 batch 1000 train loss: 0.0004 test loss: 0.0010
# Epoch 4 batch 1100 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 1200 train loss: 0.0004 test loss: 0.0010
# Epoch 4 batch 1300 train loss: 0.0009 test loss: 0.0010
# Epoch 4 batch 1400 train loss: 0.0003 test loss: 0.0010
# Epoch 4 batch 1500 train loss: 0.0007 test loss: 0.0009
# Epoch 4 batch 1600 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 1700 train loss: 0.0002 test loss: 0.0009
# Epoch 4 batch 1800 train loss: 0.0005 test loss: 0.0009
# Epoch 4 batch 1900 train loss: 0.0002 test loss: 0.0009
# Epoch 4 batch 2000 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 4 batch 2200 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 2300 train loss: 0.0004 test loss: 0.0010
# Epoch 4 batch 2400 train loss: 0.0006 test loss: 0.0010
# Epoch 4 batch 2500 train loss: 0.0008 test loss: 0.0009
# Epoch 4 batch 2600 train loss: 0.0008 test loss: 0.0010
# Epoch 4 batch 2700 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 2800 train loss: 0.0003 test loss: 0.0009
# Epoch 4 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 5 batch 0 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 100 train loss: 0.0004 test loss: 0.0009
# Epoch 5 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 5 batch 300 train loss: 0.0014 test loss: 0.0009
# Epoch 5 batch 400 train loss: 0.0006 test loss: 0.0009
# Epoch 5 batch 500 train loss: 0.0007 test loss: 0.0010
# Epoch 5 batch 600 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 700 train loss: 0.0005 test loss: 0.0010
# Epoch 5 batch 800 train loss: 0.0007 test loss: 0.0010
# Epoch 5 batch 900 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 1000 train loss: 0.0002 test loss: 0.0010
# Epoch 5 batch 1100 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 1200 train loss: 0.0002 test loss: 0.0010
# Epoch 5 batch 1300 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 1400 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 1500 train loss: 0.0004 test loss: 0.0009
# Epoch 5 batch 1600 train loss: 0.0015 test loss: 0.0010
# Epoch 5 batch 1700 train loss: 0.0003 test loss: 0.0010
# Epoch 5 batch 1800 train loss: 0.0006 test loss: 0.0010
# Epoch 5 batch 1900 train loss: 0.0004 test loss: 0.0009
# Epoch 5 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 5 batch 2100 train loss: 0.0016 test loss: 0.0009
# Epoch 5 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 5 batch 2300 train loss: 0.0008 test loss: 0.0009
# Epoch 5 batch 2400 train loss: 0.0003 test loss: 0.0009
# Epoch 5 batch 2500 train loss: 0.0003 test loss: 0.0010
# Epoch 5 batch 2600 train loss: 0.0003 test loss: 0.0010
# Epoch 5 batch 2700 train loss: 0.0014 test loss: 0.0010
# Epoch 5 batch 2800 train loss: 0.0006 test loss: 0.0009
# Epoch 5 batch 2900 train loss: 0.0004 test loss: 0.0009
# Epoch 6 batch 0 train loss: 0.0005 test loss: 0.0009
# Epoch 6 batch 100 train loss: 0.0006 test loss: 0.0009
# Epoch 6 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 6 batch 300 train loss: 0.0011 test loss: 0.0009
# Epoch 6 batch 400 train loss: 0.0003 test loss: 0.0009
# Epoch 6 batch 500 train loss: 0.0002 test loss: 0.0009
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-26
# Epoch 6 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 6 batch 700 train loss: 0.0011 test loss: 0.0010
# Epoch 6 batch 800 train loss: 0.0016 test loss: 0.0009
# Epoch 6 batch 900 train loss: 0.0003 test loss: 0.0009
# Epoch 6 batch 1000 train loss: 0.0002 test loss: 0.0010
# Epoch 6 batch 1100 train loss: 0.0003 test loss: 0.0009
# Epoch 6 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 6 batch 1300 train loss: 0.0008 test loss: 0.0010
# Epoch 6 batch 1400 train loss: 0.0007 test loss: 0.0010
# Epoch 6 batch 1500 train loss: 0.0003 test loss: 0.0009
# Epoch 6 batch 1600 train loss: 0.0014 test loss: 0.0009
# Epoch 6 batch 1700 train loss: 0.0005 test loss: 0.0009
# Epoch 6 batch 1800 train loss: 0.0003 test loss: 0.0010
# Epoch 6 batch 1900 train loss: 0.0004 test loss: 0.0009
# Epoch 6 batch 2000 train loss: 0.0003 test loss: 0.0010
# Epoch 6 batch 2100 train loss: 0.0003 test loss: 0.0010
# Epoch 6 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 6 batch 2300 train loss: 0.0004 test loss: 0.0010
# Epoch 6 batch 2400 train loss: 0.0009 test loss: 0.0010
# Epoch 6 batch 2500 train loss: 0.0002 test loss: 0.0010
# Epoch 6 batch 2600 train loss: 0.0005 test loss: 0.0010
# Epoch 6 batch 2700 train loss: 0.0004 test loss: 0.0009
# Epoch 6 batch 2800 train loss: 0.0004 test loss: 0.0009
# Epoch 6 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 7 batch 0 train loss: 0.0009 test loss: 0.0009
# Epoch 7 batch 100 train loss: 0.0002 test loss: 0.0010
# Epoch 7 batch 200 train loss: 0.0011 test loss: 0.0009
# Epoch 7 batch 300 train loss: 0.0014 test loss: 0.0009
# Epoch 7 batch 400 train loss: 0.0008 test loss: 0.0009
# Epoch 7 batch 500 train loss: 0.0003 test loss: 0.0009
# Epoch 7 batch 600 train loss: 0.0007 test loss: 0.0010
# Epoch 7 batch 700 train loss: 0.0014 test loss: 0.0009
# Epoch 7 batch 800 train loss: 0.0007 test loss: 0.0010
# Epoch 7 batch 900 train loss: 0.0002 test loss: 0.0009
# Epoch 7 batch 1000 train loss: 0.0008 test loss: 0.0010
# Epoch 7 batch 1100 train loss: 0.0002 test loss: 0.0010
# Epoch 7 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 7 batch 1300 train loss: 0.0002 test loss: 0.0010
# Epoch 7 batch 1400 train loss: 0.0004 test loss: 0.0010
# Epoch 7 batch 1500 train loss: 0.0003 test loss: 0.0009
# Epoch 7 batch 1600 train loss: 0.0006 test loss: 0.0010
# Epoch 7 batch 1700 train loss: 0.0005 test loss: 0.0010
# Epoch 7 batch 1800 train loss: 0.0005 test loss: 0.0010
# Epoch 7 batch 1900 train loss: 0.0006 test loss: 0.0010
# Epoch 7 batch 2000 train loss: 0.0005 test loss: 0.0010
# Epoch 7 batch 2100 train loss: 0.0005 test loss: 0.0009
# Epoch 7 batch 2200 train loss: 0.0003 test loss: 0.0009
# Epoch 7 batch 2300 train loss: 0.0008 test loss: 0.0010
# Epoch 7 batch 2400 train loss: 0.0006 test loss: 0.0010
# Epoch 7 batch 2500 train loss: 0.0010 test loss: 0.0010
# Epoch 7 batch 2600 train loss: 0.0002 test loss: 0.0010
# Epoch 7 batch 2700 train loss: 0.0008 test loss: 0.0009
# Epoch 7 batch 2800 train loss: 0.0006 test loss: 0.0009
# Epoch 7 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 0 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 100 train loss: 0.0002 test loss: 0.0010
# Epoch 8 batch 200 train loss: 0.0006 test loss: 0.0009
# Epoch 8 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 400 train loss: 0.0012 test loss: 0.0009
# Epoch 8 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 600 train loss: 0.0004 test loss: 0.0009
# Epoch 8 batch 700 train loss: 0.0002 test loss: 0.0010
# Epoch 8 batch 800 train loss: 0.0003 test loss: 0.0009
# Epoch 8 batch 900 train loss: 0.0002 test loss: 0.0010
# Epoch 8 batch 1000 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 1100 train loss: 0.0003 test loss: 0.0009
# Epoch 8 batch 1200 train loss: 0.0006 test loss: 0.0009
# Epoch 8 batch 1300 train loss: 0.0004 test loss: 0.0009
# Epoch 8 batch 1400 train loss: 0.0004 test loss: 0.0010
# Epoch 8 batch 1500 train loss: 0.0003 test loss: 0.0010
# Epoch 8 batch 1600 train loss: 0.0002 test loss: 0.0010
# Epoch 8 batch 1700 train loss: 0.0002 test loss: 0.0010
# Epoch 8 batch 1800 train loss: 0.0007 test loss: 0.0010
# Epoch 8 batch 1900 train loss: 0.0005 test loss: 0.0009
# Epoch 8 batch 2000 train loss: 0.0003 test loss: 0.0009
# Epoch 8 batch 2100 train loss: 0.0003 test loss: 0.0010
# Epoch 8 batch 2200 train loss: 0.0008 test loss: 0.0010
# Epoch 8 batch 2300 train loss: 0.0003 test loss: 0.0010
# Epoch 8 batch 2400 train loss: 0.0008 test loss: 0.0009
# Epoch 8 batch 2500 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 8 batch 2700 train loss: 0.0009 test loss: 0.0010
# Epoch 8 batch 2800 train loss: 0.0012 test loss: 0.0009
# Epoch 8 batch 2900 train loss: 0.0008 test loss: 0.0009
# Epoch 9 batch 0 train loss: 0.0009 test loss: 0.0009
# Epoch 9 batch 100 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 400 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 700 train loss: 0.0002 test loss: 0.0010
# Epoch 9 batch 800 train loss: 0.0002 test loss: 0.0010
# Epoch 9 batch 900 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 1000 train loss: 0.0004 test loss: 0.0009
# Epoch 9 batch 1100 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 1300 train loss: 0.0009 test loss: 0.0009
# Epoch 9 batch 1400 train loss: 0.0003 test loss: 0.0009
# Epoch 9 batch 1500 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 1600 train loss: 0.0018 test loss: 0.0009
# Epoch 9 batch 1700 train loss: 0.0010 test loss: 0.0010
# Epoch 9 batch 1800 train loss: 0.0006 test loss: 0.0010
# Epoch 9 batch 1900 train loss: 0.0011 test loss: 0.0010
# Epoch 9 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 2100 train loss: 0.0004 test loss: 0.0009
# Epoch 9 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 2300 train loss: 0.0003 test loss: 0.0009
# Epoch 9 batch 2400 train loss: 0.0002 test loss: 0.0010
# Epoch 9 batch 2500 train loss: 0.0006 test loss: 0.0010
# Epoch 9 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 9 batch 2700 train loss: 0.0012 test loss: 0.0009
# Epoch 9 batch 2800 train loss: 0.0005 test loss: 0.0009
# Epoch 9 batch 2900 train loss: 0.0006 test loss: 0.0009
# Epoch 10 batch 0 train loss: 0.0002 test loss: 0.0009
# Epoch 10 batch 100 train loss: 0.0006 test loss: 0.0009
# Epoch 10 batch 200 train loss: 0.0004 test loss: 0.0009
# Epoch 10 batch 300 train loss: 0.0003 test loss: 0.0009
# Epoch 10 batch 400 train loss: 0.0004 test loss: 0.0009
# Epoch 10 batch 500 train loss: 0.0006 test loss: 0.0009
# Epoch 10 batch 600 train loss: 0.0014 test loss: 0.0010
# Epoch 10 batch 700 train loss: 0.0004 test loss: 0.0010
# Epoch 10 batch 800 train loss: 0.0015 test loss: 0.0009
# Epoch 10 batch 900 train loss: 0.0010 test loss: 0.0010
# Epoch 10 batch 1000 train loss: 0.0002 test loss: 0.0010
# Epoch 10 batch 1100 train loss: 0.0002 test loss: 0.0009
# Epoch 10 batch 1200 train loss: 0.0016 test loss: 0.0009
# Epoch 10 batch 1300 train loss: 0.0002 test loss: 0.0009
# Epoch 10 batch 1400 train loss: 0.0015 test loss: 0.0010
# Epoch 10 batch 1500 train loss: 0.0005 test loss: 0.0009
# Epoch 10 batch 1600 train loss: 0.0005 test loss: 0.0009
# Epoch 10 batch 1700 train loss: 0.0013 test loss: 0.0009
# Epoch 10 batch 1800 train loss: 0.0003 test loss: 0.0010
# Epoch 10 batch 1900 train loss: 0.0002 test loss: 0.0010
# Epoch 10 batch 2000 train loss: 0.0014 test loss: 0.0009
# Epoch 10 batch 2100 train loss: 0.0018 test loss: 0.0009
# Epoch 10 batch 2200 train loss: 0.0006 test loss: 0.0009
# Epoch 10 batch 2300 train loss: 0.0002 test loss: 0.0010
# Epoch 10 batch 2400 train loss: 0.0002 test loss: 0.0009
# Epoch 10 batch 2500 train loss: 0.0002 test loss: 0.0010
# Epoch 10 batch 2600 train loss: 0.0011 test loss: 0.0009
# Epoch 10 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 10 batch 2800 train loss: 0.0004 test loss: 0.0009
# Epoch 10 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 0 train loss: 0.0003 test loss: 0.0009
# Epoch 11 batch 100 train loss: 0.0007 test loss: 0.0009
# Epoch 11 batch 200 train loss: 0.0009 test loss: 0.0009
# Epoch 11 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 400 train loss: 0.0009 test loss: 0.0009
# Epoch 11 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 700 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 800 train loss: 0.0003 test loss: 0.0009
# Epoch 11 batch 900 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 1000 train loss: 0.0007 test loss: 0.0009
# Epoch 11 batch 1100 train loss: 0.0003 test loss: 0.0010
# Epoch 11 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 1300 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 1400 train loss: 0.0013 test loss: 0.0009
# Epoch 11 batch 1500 train loss: 0.0005 test loss: 0.0009
# Epoch 11 batch 1600 train loss: 0.0005 test loss: 0.0009
# Epoch 11 batch 1700 train loss: 0.0006 test loss: 0.0010
# Epoch 11 batch 1800 train loss: 0.0002 test loss: 0.0010
# Epoch 11 batch 1900 train loss: 0.0001 test loss: 0.0009
# Epoch 11 batch 2000 train loss: 0.0001 test loss: 0.0010
# Epoch 11 batch 2100 train loss: 0.0009 test loss: 0.0010
# Epoch 11 batch 2200 train loss: 0.0012 test loss: 0.0010
# Epoch 11 batch 2300 train loss: 0.0003 test loss: 0.0009
# Epoch 11 batch 2400 train loss: 0.0002 test loss: 0.0010
# Epoch 11 batch 2500 train loss: 0.0004 test loss: 0.0009
# Epoch 11 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 2700 train loss: 0.0002 test loss: 0.0009
# Epoch 11 batch 2800 train loss: 0.0003 test loss: 0.0010
# Epoch 11 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 0 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 100 train loss: 0.0004 test loss: 0.0009
# Epoch 12 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 300 train loss: 0.0004 test loss: 0.0009
# Epoch 12 batch 400 train loss: 0.0004 test loss: 0.0009
# Epoch 12 batch 500 train loss: 0.0004 test loss: 0.0009
# Epoch 12 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 700 train loss: 0.0011 test loss: 0.0009
# Epoch 12 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 900 train loss: 0.0019 test loss: 0.0009
# Epoch 12 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 12 batch 1100 train loss: 0.0010 test loss: 0.0010
# Epoch 12 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 12 batch 1400 train loss: 0.0012 test loss: 0.0010
# Epoch 12 batch 1500 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 1600 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 1700 train loss: 0.0001 test loss: 0.0009
# Epoch 12 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 1900 train loss: 0.0005 test loss: 0.0010
# Epoch 12 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 12 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 2300 train loss: 0.0003 test loss: 0.0010
# Epoch 12 batch 2400 train loss: 0.0002 test loss: 0.0010
# Epoch 12 batch 2500 train loss: 0.0014 test loss: 0.0010
# Epoch 12 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 12 batch 2700 train loss: 0.0012 test loss: 0.0010
# Epoch 12 batch 2800 train loss: 0.0011 test loss: 0.0009
# Epoch 12 batch 2900 train loss: 0.0008 test loss: 0.0009
# Epoch 13 batch 0 train loss: 0.0007 test loss: 0.0009
# Epoch 13 batch 100 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 200 train loss: 0.0002 test loss: 0.0010
# Epoch 13 batch 300 train loss: 0.0014 test loss: 0.0009
# Epoch 13 batch 400 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 700 train loss: 0.0002 test loss: 0.0010
# Epoch 13 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 13 batch 900 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1000 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1100 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1200 train loss: 0.0002 test loss: 0.0010
# Epoch 13 batch 1300 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1400 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1500 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1600 train loss: 0.0005 test loss: 0.0009
# Epoch 13 batch 1700 train loss: 0.0004 test loss: 0.0010
# Epoch 13 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 1900 train loss: 0.0001 test loss: 0.0010
# Epoch 13 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 2100 train loss: 0.0006 test loss: 0.0009
# Epoch 13 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 2300 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 2400 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 2500 train loss: 0.0007 test loss: 0.0009
# Epoch 13 batch 2600 train loss: 0.0007 test loss: 0.0009
# Epoch 13 batch 2700 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 2800 train loss: 0.0002 test loss: 0.0009
# Epoch 13 batch 2900 train loss: 0.0006 test loss: 0.0009
# Epoch 14 batch 0 train loss: 0.0002 test loss: 0.0009
# Epoch 14 batch 100 train loss: 0.0004 test loss: 0.0010
# Epoch 14 batch 200 train loss: 0.0008 test loss: 0.0009
# Epoch 14 batch 300 train loss: 0.0004 test loss: 0.0009
# Epoch 14 batch 400 train loss: 0.0005 test loss: 0.0009
# Epoch 14 batch 500 train loss: 0.0007 test loss: 0.0009
# Epoch 14 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 14 batch 700 train loss: 0.0005 test loss: 0.0009
# Epoch 14 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 14 batch 900 train loss: 0.0002 test loss: 0.0009
# Epoch 14 batch 1000 train loss: 0.0006 test loss: 0.0009
# Epoch 14 batch 1100 train loss: 0.0005 test loss: 0.0009
# Epoch 14 batch 1200 train loss: 0.0005 test loss: 0.0009
# Epoch 14 batch 1300 train loss: 0.0005 test loss: 0.0010
# Epoch 14 batch 1400 train loss: 0.0006 test loss: 0.0010
# Epoch 14 batch 1500 train loss: 0.0001 test loss: 0.0010
# Epoch 14 batch 1600 train loss: 0.0002 test loss: 0.0009
# Epoch 14 batch 1700 train loss: 0.0003 test loss: 0.0009
# Epoch 14 batch 1800 train loss: 0.0003 test loss: 0.0009
# Epoch 14 batch 1900 train loss: 0.0004 test loss: 0.0009
# Epoch 14 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 14 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 14 batch 2200 train loss: 0.0015 test loss: 0.0009
# Epoch 14 batch 2300 train loss: 0.0015 test loss: 0.0009
# Epoch 14 batch 2400 train loss: 0.0007 test loss: 0.0009
# Epoch 14 batch 2500 train loss: 0.0007 test loss: 0.0009
# Epoch 14 batch 2600 train loss: 0.0002 test loss: 0.0010
# Epoch 14 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 14 batch 2800 train loss: 0.0009 test loss: 0.0009
# Epoch 14 batch 2900 train loss: 0.0003 test loss: 0.0009
# Epoch 15 batch 0 train loss: 0.0017 test loss: 0.0009
# Epoch 15 batch 100 train loss: 0.0003 test loss: 0.0009
# Epoch 15 batch 200 train loss: 0.0007 test loss: 0.0009
# Epoch 15 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 400 train loss: 0.0007 test loss: 0.0010
# Epoch 15 batch 500 train loss: 0.0009 test loss: 0.0009
# Epoch 15 batch 600 train loss: 0.0005 test loss: 0.0009
# Epoch 15 batch 700 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 800 train loss: 0.0003 test loss: 0.0009
# Epoch 15 batch 900 train loss: 0.0004 test loss: 0.0010
# Epoch 15 batch 1000 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 1100 train loss: 0.0008 test loss: 0.0009
# Epoch 15 batch 1200 train loss: 0.0006 test loss: 0.0009
# Epoch 15 batch 1300 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 1400 train loss: 0.0009 test loss: 0.0009
# Epoch 15 batch 1500 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 1600 train loss: 0.0004 test loss: 0.0010
# Epoch 15 batch 1700 train loss: 0.0002 test loss: 0.0010
# Epoch 15 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 15 batch 1900 train loss: 0.0002 test loss: 0.0010
# Epoch 15 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 2200 train loss: 0.0003 test loss: 0.0009
# Epoch 15 batch 2300 train loss: 0.0002 test loss: 0.0010
# Epoch 15 batch 2400 train loss: 0.0016 test loss: 0.0010
# Epoch 15 batch 2500 train loss: 0.0002 test loss: 0.0009
# Epoch 15 batch 2600 train loss: 0.0009 test loss: 0.0009
# Epoch 15 batch 2700 train loss: 0.0009 test loss: 0.0009
# Epoch 15 batch 2800 train loss: 0.0003 test loss: 0.0009
# Epoch 15 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 0 train loss: 0.0005 test loss: 0.0010
# Epoch 16 batch 100 train loss: 0.0010 test loss: 0.0009
# Epoch 16 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 300 train loss: 0.0002 test loss: 0.0009
# Saving checkpoint at ./checkpoints/UNet_50x50/ckpt-27
# Epoch 16 batch 400 train loss: 0.0011 test loss: 0.0009
# Epoch 16 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 16 batch 800 train loss: 0.0007 test loss: 0.0009
# Epoch 16 batch 900 train loss: 0.0005 test loss: 0.0010
# Epoch 16 batch 1000 train loss: 0.0017 test loss: 0.0009
# Epoch 16 batch 1100 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 1200 train loss: 0.0004 test loss: 0.0009
# Epoch 16 batch 1300 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 1400 train loss: 0.0005 test loss: 0.0009
# Epoch 16 batch 1500 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 1600 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 1700 train loss: 0.0005 test loss: 0.0009
# Epoch 16 batch 1800 train loss: 0.0002 test loss: 0.0010
# Epoch 16 batch 1900 train loss: 0.0019 test loss: 0.0009
# Epoch 16 batch 2000 train loss: 0.0008 test loss: 0.0009
# Epoch 16 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 2200 train loss: 0.0006 test loss: 0.0009
# Epoch 16 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 16 batch 2400 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 16 batch 2600 train loss: 0.0004 test loss: 0.0009
# Epoch 16 batch 2700 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 2800 train loss: 0.0002 test loss: 0.0009
# Epoch 16 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 0 train loss: 0.0003 test loss: 0.0009
# Epoch 17 batch 100 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 17 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 400 train loss: 0.0004 test loss: 0.0009
# Epoch 17 batch 500 train loss: 0.0007 test loss: 0.0009
# Epoch 17 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 700 train loss: 0.0007 test loss: 0.0009
# Epoch 17 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 900 train loss: 0.0004 test loss: 0.0009
# Epoch 17 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 17 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 17 batch 1200 train loss: 0.0004 test loss: 0.0009
# Epoch 17 batch 1300 train loss: 0.0001 test loss: 0.0010
# Epoch 17 batch 1400 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 1500 train loss: 0.0015 test loss: 0.0009
# Epoch 17 batch 1600 train loss: 0.0004 test loss: 0.0009
# Epoch 17 batch 1700 train loss: 0.0002 test loss: 0.0010
# Epoch 17 batch 1800 train loss: 0.0007 test loss: 0.0009
# Epoch 17 batch 1900 train loss: 0.0011 test loss: 0.0009
# Epoch 17 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 2200 train loss: 0.0008 test loss: 0.0009
# Epoch 17 batch 2300 train loss: 0.0007 test loss: 0.0009
# Epoch 17 batch 2400 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 2500 train loss: 0.0003 test loss: 0.0009
# Epoch 17 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 17 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 17 batch 2800 train loss: 0.0009 test loss: 0.0009
# Epoch 17 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 300 train loss: 0.0006 test loss: 0.0009
# Epoch 18 batch 400 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 500 train loss: 0.0010 test loss: 0.0009
# Epoch 18 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 900 train loss: 0.0005 test loss: 0.0009
# Epoch 18 batch 1000 train loss: 0.0011 test loss: 0.0009
# Epoch 18 batch 1100 train loss: 0.0007 test loss: 0.0009
# Epoch 18 batch 1200 train loss: 0.0006 test loss: 0.0009
# Epoch 18 batch 1300 train loss: 0.0003 test loss: 0.0009
# Epoch 18 batch 1400 train loss: 0.0005 test loss: 0.0009
# Epoch 18 batch 1500 train loss: 0.0007 test loss: 0.0009
# Epoch 18 batch 1600 train loss: 0.0006 test loss: 0.0009
# Epoch 18 batch 1700 train loss: 0.0004 test loss: 0.0009
# Epoch 18 batch 1800 train loss: 0.0009 test loss: 0.0010
# Epoch 18 batch 1900 train loss: 0.0003 test loss: 0.0009
# Epoch 18 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 2100 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 2200 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 2400 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 2500 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 2600 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 18 batch 2800 train loss: 0.0002 test loss: 0.0009
# Epoch 18 batch 2900 train loss: 0.0003 test loss: 0.0009
# Epoch 19 batch 0 train loss: 0.0005 test loss: 0.0009
# Epoch 19 batch 100 train loss: 0.0005 test loss: 0.0009
# Epoch 19 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 19 batch 300 train loss: 0.0007 test loss: 0.0009
# Epoch 19 batch 400 train loss: 0.0011 test loss: 0.0009
# Epoch 19 batch 500 train loss: 0.0010 test loss: 0.0009
# Epoch 19 batch 600 train loss: 0.0011 test loss: 0.0009
# Epoch 19 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 19 batch 900 train loss: 0.0003 test loss: 0.0009
# Epoch 19 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 1200 train loss: 0.0005 test loss: 0.0009
# Epoch 19 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 1400 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 1500 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 1600 train loss: 0.0004 test loss: 0.0009
# Epoch 19 batch 1700 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 1800 train loss: 0.0002 test loss: 0.0010
# Epoch 19 batch 1900 train loss: 0.0002 test loss: 0.0009
# Epoch 19 batch 2000 train loss: 0.0008 test loss: 0.0009
# Epoch 19 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 2200 train loss: 0.0004 test loss: 0.0009
# Epoch 19 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 2400 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 2500 train loss: 0.0012 test loss: 0.0009
# Epoch 19 batch 2600 train loss: 0.0020 test loss: 0.0009
# Epoch 19 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 19 batch 2800 train loss: 0.0012 test loss: 0.0009
# Epoch 19 batch 2900 train loss: 0.0010 test loss: 0.0009
# Epoch 20 batch 0 train loss: 0.0012 test loss: 0.0009
# Epoch 20 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 20 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 20 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 20 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 20 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 20 batch 600 train loss: 0.0010 test loss: 0.0009
# Epoch 20 batch 700 train loss: 0.0002 test loss: 0.0009
# Epoch 20 batch 800 train loss: 0.0002 test loss: 0.0010
# Epoch 20 batch 900 train loss: 0.0002 test loss: 0.0010
# Epoch 20 batch 1000 train loss: 0.0004 test loss: 0.0009
# Epoch 20 batch 1100 train loss: 0.0008 test loss: 0.0009
# Epoch 20 batch 1200 train loss: 0.0005 test loss: 0.0010
# Epoch 20 batch 1300 train loss: 0.0002 test loss: 0.0010
# Epoch 20 batch 1400 train loss: 0.0012 test loss: 0.0009
# Epoch 20 batch 1500 train loss: 0.0001 test loss: 0.0009
# Epoch 20 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 20 batch 1700 train loss: 0.0004 test loss: 0.0009
# Epoch 20 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 20 batch 1900 train loss: 0.0003 test loss: 0.0010
# Epoch 20 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 20 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 20 batch 2200 train loss: 0.0003 test loss: 0.0009
# Epoch 20 batch 2300 train loss: 0.0002 test loss: 0.0009
# Epoch 20 batch 2400 train loss: 0.0003 test loss: 0.0009
# Epoch 20 batch 2500 train loss: 0.0021 test loss: 0.0009
# Epoch 20 batch 2600 train loss: 0.0013 test loss: 0.0009
# Epoch 20 batch 2700 train loss: 0.0005 test loss: 0.0009
# Epoch 20 batch 2800 train loss: 0.0006 test loss: 0.0009
# Epoch 20 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 0 train loss: 0.0005 test loss: 0.0009
# Epoch 21 batch 100 train loss: 0.0010 test loss: 0.0009
# Epoch 21 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 300 train loss: 0.0004 test loss: 0.0009
# Epoch 21 batch 400 train loss: 0.0007 test loss: 0.0009
# Epoch 21 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 700 train loss: 0.0009 test loss: 0.0009
# Epoch 21 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 900 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 1100 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 1400 train loss: 0.0002 test loss: 0.0010
# Epoch 21 batch 1500 train loss: 0.0011 test loss: 0.0009
# Epoch 21 batch 1600 train loss: 0.0013 test loss: 0.0009
# Epoch 21 batch 1700 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 1800 train loss: 0.0002 test loss: 0.0010
# Epoch 21 batch 1900 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 2000 train loss: 0.0004 test loss: 0.0009
# Epoch 21 batch 2100 train loss: 0.0016 test loss: 0.0009
# Epoch 21 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 2400 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 21 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 21 batch 2700 train loss: 0.0005 test loss: 0.0009
# Epoch 21 batch 2800 train loss: 0.0007 test loss: 0.0009
# Epoch 21 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 0 train loss: 0.0018 test loss: 0.0009
# Epoch 22 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 400 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 500 train loss: 0.0009 test loss: 0.0009
# Epoch 22 batch 600 train loss: 0.0006 test loss: 0.0009
# Epoch 22 batch 700 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 900 train loss: 0.0004 test loss: 0.0009
# Epoch 22 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 1100 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 1400 train loss: 0.0005 test loss: 0.0009
# Epoch 22 batch 1500 train loss: 0.0006 test loss: 0.0009
# Epoch 22 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 1700 train loss: 0.0006 test loss: 0.0009
# Epoch 22 batch 1800 train loss: 0.0022 test loss: 0.0009
# Epoch 22 batch 1900 train loss: 0.0003 test loss: 0.0009
# Epoch 22 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 2100 train loss: 0.0003 test loss: 0.0009
# Epoch 22 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 22 batch 2300 train loss: 0.0004 test loss: 0.0010
# Epoch 22 batch 2400 train loss: 0.0004 test loss: 0.0009
# Epoch 22 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 22 batch 2600 train loss: 0.0006 test loss: 0.0010
# Epoch 22 batch 2700 train loss: 0.0017 test loss: 0.0009
# Epoch 22 batch 2800 train loss: 0.0004 test loss: 0.0009
# Epoch 22 batch 2900 train loss: 0.0013 test loss: 0.0009
# Epoch 23 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 100 train loss: 0.0002 test loss: 0.0009
# Epoch 23 batch 200 train loss: 0.0011 test loss: 0.0009
# Epoch 23 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 23 batch 400 train loss: 0.0016 test loss: 0.0009
# Epoch 23 batch 500 train loss: 0.0003 test loss: 0.0009
# Epoch 23 batch 600 train loss: 0.0004 test loss: 0.0009
# Epoch 23 batch 700 train loss: 0.0009 test loss: 0.0009
# Epoch 23 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 23 batch 900 train loss: 0.0005 test loss: 0.0009
# Epoch 23 batch 1000 train loss: 0.0005 test loss: 0.0009
# Epoch 23 batch 1100 train loss: 0.0006 test loss: 0.0009
# Epoch 23 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 1300 train loss: 0.0006 test loss: 0.0009
# Epoch 23 batch 1400 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 1500 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 1600 train loss: 0.0002 test loss: 0.0009
# Epoch 23 batch 1700 train loss: 0.0013 test loss: 0.0009
# Epoch 23 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 23 batch 1900 train loss: 0.0004 test loss: 0.0009
# Epoch 23 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 2200 train loss: 0.0005 test loss: 0.0009
# Epoch 23 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 2400 train loss: 0.0003 test loss: 0.0009
# Epoch 23 batch 2500 train loss: 0.0002 test loss: 0.0010
# Epoch 23 batch 2600 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 2800 train loss: 0.0001 test loss: 0.0009
# Epoch 23 batch 2900 train loss: 0.0003 test loss: 0.0009
# Epoch 24 batch 0 train loss: 0.0008 test loss: 0.0009
# Epoch 24 batch 100 train loss: 0.0006 test loss: 0.0009
# Epoch 24 batch 200 train loss: 0.0010 test loss: 0.0009
# Epoch 24 batch 300 train loss: 0.0003 test loss: 0.0009
# Epoch 24 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 500 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 600 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 800 train loss: 0.0002 test loss: 0.0009
# Epoch 24 batch 900 train loss: 0.0003 test loss: 0.0009
# Epoch 24 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 1100 train loss: 0.0011 test loss: 0.0009
# Epoch 24 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 1300 train loss: 0.0010 test loss: 0.0009
# Epoch 24 batch 1400 train loss: 0.0007 test loss: 0.0009
# Epoch 24 batch 1500 train loss: 0.0009 test loss: 0.0009
# Epoch 24 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 1700 train loss: 0.0003 test loss: 0.0009
# Epoch 24 batch 1800 train loss: 0.0007 test loss: 0.0009
# Epoch 24 batch 1900 train loss: 0.0008 test loss: 0.0009
# Epoch 24 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 2100 train loss: 0.0012 test loss: 0.0009
# Epoch 24 batch 2200 train loss: 0.0001 test loss: 0.0010
# Epoch 24 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 2400 train loss: 0.0005 test loss: 0.0009
# Epoch 24 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 24 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 24 batch 2700 train loss: 0.0007 test loss: 0.0009
# Epoch 24 batch 2800 train loss: 0.0018 test loss: 0.0009
# Epoch 24 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 0 train loss: 0.0005 test loss: 0.0009
# Epoch 25 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 25 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 400 train loss: 0.0008 test loss: 0.0009
# Epoch 25 batch 500 train loss: 0.0004 test loss: 0.0009
# Epoch 25 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 700 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 800 train loss: 0.0013 test loss: 0.0009
# Epoch 25 batch 900 train loss: 0.0007 test loss: 0.0009
# Epoch 25 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 1200 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 1400 train loss: 0.0006 test loss: 0.0009
# Epoch 25 batch 1500 train loss: 0.0009 test loss: 0.0009
# Epoch 25 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 1700 train loss: 0.0003 test loss: 0.0009
# Epoch 25 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 1900 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 2100 train loss: 0.0011 test loss: 0.0009
# Epoch 25 batch 2200 train loss: 0.0001 test loss: 0.0009
# Epoch 25 batch 2300 train loss: 0.0013 test loss: 0.0009
# Epoch 25 batch 2400 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 2500 train loss: 0.0006 test loss: 0.0009
# Epoch 25 batch 2600 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 2700 train loss: 0.0002 test loss: 0.0009
# Epoch 25 batch 2800 train loss: 0.0003 test loss: 0.0009
# Epoch 25 batch 2900 train loss: 0.0017 test loss: 0.0009
# Epoch 26 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 100 train loss: 0.0005 test loss: 0.0009
# Epoch 26 batch 200 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 26 batch 400 train loss: 0.0043 test loss: 0.0009
# Epoch 26 batch 500 train loss: 0.0002 test loss: 0.0009
# Epoch 26 batch 600 train loss: 0.0007 test loss: 0.0009
# Epoch 26 batch 700 train loss: 0.0002 test loss: 0.0009
# Epoch 26 batch 800 train loss: 0.0009 test loss: 0.0009
# Epoch 26 batch 900 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 1000 train loss: 0.0002 test loss: 0.0009
# Epoch 26 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 1200 train loss: 0.0016 test loss: 0.0009
# Epoch 26 batch 1300 train loss: 0.0005 test loss: 0.0009
# Epoch 26 batch 1400 train loss: 0.0010 test loss: 0.0009
# Epoch 26 batch 1500 train loss: 0.0002 test loss: 0.0009
# Epoch 26 batch 1600 train loss: 0.0015 test loss: 0.0009
# Epoch 26 batch 1700 train loss: 0.0003 test loss: 0.0009
# Epoch 26 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 1900 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 2100 train loss: 0.0007 test loss: 0.0009
# Epoch 26 batch 2200 train loss: 0.0028 test loss: 0.0010
# Epoch 26 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 2400 train loss: 0.0004 test loss: 0.0009
# Epoch 26 batch 2500 train loss: 0.0002 test loss: 0.0009
# Epoch 26 batch 2600 train loss: 0.0003 test loss: 0.0010
# Epoch 26 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 26 batch 2800 train loss: 0.0005 test loss: 0.0009
# Epoch 26 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 100 train loss: 0.0002 test loss: 0.0009
# Epoch 27 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 27 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 400 train loss: 0.0004 test loss: 0.0009
# Epoch 27 batch 500 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 27 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 900 train loss: 0.0019 test loss: 0.0009
# Epoch 27 batch 1000 train loss: 0.0002 test loss: 0.0009
# Epoch 27 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 1200 train loss: 0.0004 test loss: 0.0009
# Epoch 27 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 1400 train loss: 0.0006 test loss: 0.0009
# Epoch 27 batch 1500 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 1600 train loss: 0.0007 test loss: 0.0009
# Epoch 27 batch 1700 train loss: 0.0006 test loss: 0.0009
# Epoch 27 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 1900 train loss: 0.0006 test loss: 0.0009
# Epoch 27 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 27 batch 2100 train loss: 0.0003 test loss: 0.0009
# Epoch 27 batch 2200 train loss: 0.0002 test loss: 0.0010
# Epoch 27 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 2400 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 2600 train loss: 0.0004 test loss: 0.0009
# Epoch 27 batch 2700 train loss: 0.0012 test loss: 0.0009
# Epoch 27 batch 2800 train loss: 0.0001 test loss: 0.0009
# Epoch 27 batch 2900 train loss: 0.0003 test loss: 0.0009
# Epoch 28 batch 0 train loss: 0.0002 test loss: 0.0009
# Epoch 28 batch 100 train loss: 0.0002 test loss: 0.0009
# Epoch 28 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 28 batch 300 train loss: 0.0001 test loss: 0.0009
# ...
# Epoch 49 batch 2800 train loss: 0.0012 test loss: 0.0009
# Epoch 49 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 100 train loss: 0.0013 test loss: 0.0009
# Epoch 50 batch 200 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 300 train loss: 0.0002 test loss: 0.0009
# Epoch 50 batch 400 train loss: 0.0003 test loss: 0.0009
# Epoch 50 batch 500 train loss: 0.0007 test loss: 0.0009
# Epoch 50 batch 600 train loss: 0.0009 test loss: 0.0009
# Epoch 50 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 900 train loss: 0.0012 test loss: 0.0009
# Epoch 50 batch 1000 train loss: 0.0006 test loss: 0.0009
# Epoch 50 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 1300 train loss: 0.0006 test loss: 0.0009
# Epoch 50 batch 1400 train loss: 0.0006 test loss: 0.0009
# Epoch 50 batch 1500 train loss: 0.0005 test loss: 0.0009
# Epoch 50 batch 1600 train loss: 0.0016 test loss: 0.0009
# Epoch 50 batch 1700 train loss: 0.0011 test loss: 0.0009
# Epoch 50 batch 1800 train loss: 0.0005 test loss: 0.0009
# Epoch 50 batch 1900 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2200 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2400 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2600 train loss: 0.0005 test loss: 0.0009
# Epoch 50 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2800 train loss: 0.0001 test loss: 0.0009
# Epoch 50 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 0 train loss: 0.0013 test loss: 0.0009
# Epoch 51 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 200 train loss: 0.0014 test loss: 0.0009
# Epoch 51 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 500 train loss: 0.0003 test loss: 0.0009
# Epoch 51 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 51 batch 700 train loss: 0.0005 test loss: 0.0009
# Epoch 51 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 900 train loss: 0.0016 test loss: 0.0009
# Epoch 51 batch 1000 train loss: 0.0018 test loss: 0.0009
# Epoch 51 batch 1100 train loss: 0.0008 test loss: 0.0009
# Epoch 51 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 1300 train loss: 0.0002 test loss: 0.0009
# Epoch 51 batch 1400 train loss: 0.0011 test loss: 0.0009
# Epoch 51 batch 1500 train loss: 0.0003 test loss: 0.0009
# Epoch 51 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 1700 train loss: 0.0003 test loss: 0.0009
# Epoch 51 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 1900 train loss: 0.0016 test loss: 0.0009
# Epoch 51 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 51 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 2400 train loss: 0.0004 test loss: 0.0009
# Epoch 51 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 2600 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 51 batch 2800 train loss: 0.0004 test loss: 0.0009
# Epoch 51 batch 2900 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 100 train loss: 0.0008 test loss: 0.0009
# Epoch 52 batch 200 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 300 train loss: 0.0005 test loss: 0.0009
# Epoch 52 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 500 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 600 train loss: 0.0002 test loss: 0.0009
# Epoch 52 batch 700 train loss: 0.0003 test loss: 0.0009
# Epoch 52 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 900 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 1000 train loss: 0.0005 test loss: 0.0009
# Epoch 52 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 1200 train loss: 0.0010 test loss: 0.0009
# Epoch 52 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 1400 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 1500 train loss: 0.0013 test loss: 0.0009
# Epoch 52 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 1700 train loss: 0.0004 test loss: 0.0009
# Epoch 52 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 52 batch 1900 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 2000 train loss: 0.0009 test loss: 0.0009
# Epoch 52 batch 2100 train loss: 0.0004 test loss: 0.0009
# Epoch 52 batch 2200 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 2400 train loss: 0.0003 test loss: 0.0009
# Epoch 52 batch 2500 train loss: 0.0005 test loss: 0.0009
# Epoch 52 batch 2600 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 52 batch 2800 train loss: 0.0008 test loss: 0.0009
# Epoch 52 batch 2900 train loss: 0.0008 test loss: 0.0009
# Epoch 53 batch 0 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 100 train loss: 0.0012 test loss: 0.0009
# Epoch 53 batch 200 train loss: 0.0005 test loss: 0.0009
# Epoch 53 batch 300 train loss: 0.0003 test loss: 0.0009
# Epoch 53 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 500 train loss: 0.0006 test loss: 0.0009
# Epoch 53 batch 600 train loss: 0.0010 test loss: 0.0009
# Epoch 53 batch 700 train loss: 0.0009 test loss: 0.0009
# Epoch 53 batch 800 train loss: 0.0006 test loss: 0.0009
# Epoch 53 batch 900 train loss: 0.0006 test loss: 0.0009
# Epoch 53 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 1300 train loss: 0.0004 test loss: 0.0009
# Epoch 53 batch 1400 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 1500 train loss: 0.0004 test loss: 0.0009
# Epoch 53 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 1700 train loss: 0.0014 test loss: 0.0009
# Epoch 53 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 1900 train loss: 0.0012 test loss: 0.0009
# Epoch 53 batch 2000 train loss: 0.0002 test loss: 0.0009
# Epoch 53 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 2200 train loss: 0.0002 test loss: 0.0009
# Epoch 53 batch 2300 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 2400 train loss: 0.0004 test loss: 0.0009
# Epoch 53 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 2600 train loss: 0.0005 test loss: 0.0009
# Epoch 53 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 2800 train loss: 0.0001 test loss: 0.0009
# Epoch 53 batch 2900 train loss: 0.0009 test loss: 0.0009
# Epoch 54 batch 0 train loss: 0.0004 test loss: 0.0009
# Epoch 54 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 200 train loss: 0.0003 test loss: 0.0009
# Epoch 54 batch 300 train loss: 0.0003 test loss: 0.0009
# Epoch 54 batch 400 train loss: 0.0019 test loss: 0.0009
# Epoch 54 batch 500 train loss: 0.0005 test loss: 0.0009
# Epoch 54 batch 600 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 700 train loss: 0.0004 test loss: 0.0009
# Epoch 54 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 900 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 1100 train loss: 0.0018 test loss: 0.0009
# Epoch 54 batch 1200 train loss: 0.0013 test loss: 0.0009
# Epoch 54 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 1400 train loss: 0.0008 test loss: 0.0009
# Epoch 54 batch 1500 train loss: 0.0003 test loss: 0.0009
# Epoch 54 batch 1600 train loss: 0.0022 test loss: 0.0009
# Epoch 54 batch 1700 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 1900 train loss: 0.0004 test loss: 0.0009
# Epoch 54 batch 2000 train loss: 0.0005 test loss: 0.0009
# Epoch 54 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 2200 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 2300 train loss: 0.0003 test loss: 0.0009
# Epoch 54 batch 2400 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 2500 train loss: 0.0006 test loss: 0.0009
# Epoch 54 batch 2600 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 2700 train loss: 0.0008 test loss: 0.0009
# Epoch 54 batch 2800 train loss: 0.0001 test loss: 0.0009
# Epoch 54 batch 2900 train loss: 0.0009 test loss: 0.0009
# Epoch 55 batch 0 train loss: 0.0014 test loss: 0.0009
# Epoch 55 batch 100 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 200 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 500 train loss: 0.0013 test loss: 0.0009
# Epoch 55 batch 600 train loss: 0.0005 test loss: 0.0009
# Epoch 55 batch 700 train loss: 0.0008 test loss: 0.0009
# Epoch 55 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 900 train loss: 0.0010 test loss: 0.0009
# Epoch 55 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 1100 train loss: 0.0006 test loss: 0.0009
# Epoch 55 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 1400 train loss: 0.0012 test loss: 0.0009
# Epoch 55 batch 1500 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 1600 train loss: 0.0007 test loss: 0.0009
# Epoch 55 batch 1700 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 1800 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 1900 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 2000 train loss: 0.0005 test loss: 0.0009
# Epoch 55 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 2200 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 2300 train loss: 0.0013 test loss: 0.0009
# Epoch 55 batch 2400 train loss: 0.0012 test loss: 0.0009
# Epoch 55 batch 2500 train loss: 0.0001 test loss: 0.0009
# Epoch 55 batch 2600 train loss: 0.0003 test loss: 0.0009
# Epoch 55 batch 2700 train loss: 0.0002 test loss: 0.0009
# Epoch 55 batch 2800 train loss: 0.0005 test loss: 0.0009
# Epoch 55 batch 2900 train loss: 0.0002 test loss: 0.0009
# Epoch 56 batch 0 train loss: 0.0004 test loss: 0.0009
# Epoch 56 batch 100 train loss: 0.0003 test loss: 0.0009
# Epoch 56 batch 200 train loss: 0.0022 test loss: 0.0009
# Epoch 56 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 400 train loss: 0.0006 test loss: 0.0009
# Epoch 56 batch 500 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 600 train loss: 0.0007 test loss: 0.0009
# Epoch 56 batch 700 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 800 train loss: 0.0005 test loss: 0.0009
# Epoch 56 batch 900 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1000 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1100 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1200 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1400 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1500 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 1600 train loss: 0.0004 test loss: 0.0009
# Epoch 56 batch 1700 train loss: 0.0008 test loss: 0.0009
# Epoch 56 batch 1800 train loss: 0.0002 test loss: 0.0009
# Epoch 56 batch 1900 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 2000 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 2100 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 2200 train loss: 0.0005 test loss: 0.0009
# Epoch 56 batch 2300 train loss: 0.0008 test loss: 0.0009
# Epoch 56 batch 2400 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 2500 train loss: 0.0008 test loss: 0.0009
# Epoch 56 batch 2600 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 2700 train loss: 0.0001 test loss: 0.0009
# Epoch 56 batch 2800 train loss: 0.0013 test loss: 0.0009
# Epoch 56 batch 2900 train loss: 0.0005 test loss: 0.0009
# Epoch 57 batch 0 train loss: 0.0006 test loss: 0.0009
# Epoch 57 batch 100 train loss: 0.0004 test loss: 0.0009
# Epoch 57 batch 200 train loss: 0.0002 test loss: 0.0009
# Epoch 57 batch 300 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 400 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 500 train loss: 0.0009 test loss: 0.0009
# Epoch 57 batch 600 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 700 train loss: 0.0003 test loss: 0.0009
# Epoch 57 batch 800 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 900 train loss: 0.0004 test loss: 0.0009
# Epoch 57 batch 1000 train loss: 0.0006 test loss: 0.0009
# Epoch 57 batch 1100 train loss: 0.0013 test loss: 0.0009
# Epoch 57 batch 1200 train loss: 0.0003 test loss: 0.0009
# Epoch 57 batch 1300 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 1400 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 1500 train loss: 0.0005 test loss: 0.0009
# Epoch 57 batch 1600 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 1700 train loss: 0.0001 test loss: 0.0009
# Epoch 57 batch 1800 train loss: 0.0001 test loss: 0.0009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-47211aa7bf0c> in <module>()
#      10                 if step % DISP_STEPS == 0:
#      11                     test_loss = 0
# ---> 12                     for step_, (inp_, tar_) in enumerate(test_dataset):
#      13                         test_loss += loss_function(unet_model, inp_, tar_)
#      14
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __iter__(self)
#     416     if (context.executing_eagerly()
#     417         or ops.get_default_graph()._building_function):  # pylint: disable=protected-access
# --> 418       return iterator_ops.OwnedIterator(self)
#     419     else:
#     420       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     592           context.context().device_spec.device_type != "CPU"):
#     593         with ops.device("/cpu:0"):
# --> 594           self._create_iterator(dataset)
#     595       else:
#     596         self._create_iterator(dataset)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     598   def _create_iterator(self, dataset):
#     599     # pylint: disable=protected-access
# --> 600     dataset = dataset._apply_options()
#     601
#     602     # Store dataset reference to ensure that dataset is alive when this iterator
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in _apply_options(self)
#     379       else:
#     380         dataset = _OptimizeDataset(dataset, static_optimizations,
# --> 381                                    static_optimization_configs)
#     382
#     383     autotune = True
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations, optimization_configs)
#    4211         self._optimizations,
#    4212         optimization_configs=optimization_configs,
# -> 4213         **self._flat_structure)
#    4214     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#    4215
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_dataset_ops.py in optimize_dataset(input_dataset, optimizations, output_types, output_shapes, optimization_configs, name)
#    3625         tld.op_callbacks, input_dataset, optimizations, "output_types",
#    3626         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 3627         optimization_configs)
#    3628       return _result
#    3629     except _core._FallbackException:
#
# KeyboardInterrupt:

# %% [markdown]
# # Model evaluation

# %%
i = -1
if ckpt_manager.checkpoints:
    ckpt.restore(ckpt_manager.checkpoints[i])
    print ('Checkpoint ' + ckpt_manager.checkpoints[i][-2:] +' restored!!')
# Out:
# Checkpoint 27 restored!!

# %%
unet_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
test_loss = unet_model.evaluate(test_dataset)
# Out:
# 2446/2446 [==============================] - 22s 9ms/step - loss: 0.0035

# %%
pred_result = unet_model.predict(test_dataset)

# %%
print(pred_result.shape)
print(test_label.shape)
# Out:
# (78263, 50, 50, 1)
# (78263, 50, 50, 1)

# %%
avg_pred = []
OUTLIER = 1
for __ in range(5):
    temp = []
    for _ in range(int(pred_result.shape[1]/5)):
        temp.append(pred_result[..., _*5:(_+1)*5, 0][..., __])
    temp = np.stack(temp, axis=2)
    temp.sort(axis=2)
    avg_pred.append(temp[..., OUTLIER:-OUTLIER].mean(axis=2))
avg_pred = np.stack(avg_pred, axis=2)

# %%
masking = test_input[..., 1]
avg_masking = masking[..., :5]

# %%
masked_pred = np.ma.array(pred_result[..., 0], mask=masking)
masked_avg_pred = np.ma.array(avg_pred, mask=avg_masking)
masked_label = np.ma.array(test_label[..., 0], mask=masking)

# %%
for _ in range(5):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_pred[..., _].reshape(-1))))
# Out:
# 0.057955153
# 0.059412017
# 0.07997784
# 0.032864057
# 0.05826172

# %%
for _ in range(5):
    print(np.sqrt(mean_squared_error(masked_label[..., _].reshape(-1), masked_avg_pred[..., _].reshape(-1))))
# Out:
# 0.05683392
# 0.057139277
# 0.07656718
# 0.02673967
# 0.05463069

# %%
r2 = RSquare()
for _ in range(5):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_pred[..., _][~masked_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.67015886, shape=(), dtype=float32)
# tf.Tensor(0.8916229, shape=(), dtype=float32)
# tf.Tensor(0.72411764, shape=(), dtype=float32)
# tf.Tensor(0.37867212, shape=(), dtype=float32)
# WARNING:tensorflow:5 out of the last 5 calls to <bound method RSquare.update_state of <__main__.RSquare object at 0x7f6be94243c8>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# tf.Tensor(0.72256464, shape=(), dtype=float32)

# %%
for _ in range(5):
    r2.reset_states()
    print(r2(masked_label[..., _][~masked_label[..., _].mask].data.reshape(-1),
             masked_avg_pred[..., _][~masked_avg_pred[..., _].mask].data.reshape(-1)))
# Out:
# tf.Tensor(0.6841542, shape=(), dtype=float32)
# tf.Tensor(0.9092302, shape=(), dtype=float32)
# tf.Tensor(0.77722895, shape=(), dtype=float32)
# tf.Tensor(0.6302897, shape=(), dtype=float32)
# tf.Tensor(0.7592382, shape=(), dtype=float32)

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5]).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_pred = ((MAXS[:5]-MINS[:5])*masked_pred[..., :5] + MINS[:5]).reshape(-1, 1)
plot_pred = plot_pred[~plot_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_pred)))
# Out:
# tf.Tensor(0.8712946, shape=(), dtype=float32)
# 80.29999545752071

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5]).reshape(-1, 1)
plot_label = plot_label[~plot_label.mask]
plot_avg_pred = ((MAXS[:5]-MINS[:5])*masked_avg_pred[..., :5] + MINS[:5]).reshape(-1, 1)
plot_avg_pred = plot_avg_pred[~plot_avg_pred.mask]
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
plt.scatter(plot_label, plot_avg_pred, c=cmap[0], s=2, alpha=0.1)
plt.show()

r2 = RSquare()
r2.reset_states()
print(r2(plot_label, plot_pred))
print(np.sqrt(mean_squared_error(plot_label, plot_avg_pred)))
# Out:
# tf.Tensor(0.8712946, shape=(), dtype=float32)
# 68.69273611528472

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (2):

        NUMBERS = np.arange(1, pred_result.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*8, (6/2.54)*8))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=1) #measured
            expect1 = plt.plot(x_t, masked_pred[NUMBER, :, i], 'o', c=cmap[5], alpha=1) #estimated
            expect1 = plt.plot(x_t, masked_avg_pred[NUMBER, :, i], 'o', c=cmap[0], alpha=1) #estimated
            expect2 = plt.plot(x_t, pred_result[NUMBER, :, i], c=cmap[2], alpha=1) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1

# %% [markdown]
# # Saving data

# %%
plot_label = ((MAXS[:5]-MINS[:5])*masked_label[..., :5] + MINS[:5])
plot_label.fill_value = np.nan
plot_avg_pred = ((MAXS[:5]-MINS[:5])*masked_avg_pred[..., :5] + MINS[:5])
plot_avg_pred.fill_value = np.nan

# %%
f = open('./results/UNet_%sx%s.npz' % (SCREEN_SIZE, SCREEN_SIZE), 'wb')
np.savez(f,
         test_label = plot_label.filled(),
         test_pred = plot_avg_pred.filled()
        )
f.close()
